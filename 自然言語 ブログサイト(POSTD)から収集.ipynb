# %%
import os
import requests
import urllib
import time
import glob
import json
import urllib.parse
import re
import unicodedata
import json
import datetime
# 構文解析
import CaboCha
# スクレピング
from bs4 import BeautifulSoup
# 機械学習
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### パラメーターの設定

# %%
# 保存先ディレクトリ
save_directory = f"./postd"

# %%
def write_file(url, file_path):
    r = requests.get(url, stream=True)
    
    if r.status_code == 200:
        with open(file_path, "wb") as f:
            f.write(r.content)
    else:
        print(f"HTTP STATUS ERROR {r.status_code}")

# %% [markdown]
# ### 記事一覧ページから各ページをテキストに保存する

# %%
'''
for i in range(69, -1, -1):
    if i == 0:
        page_url = f"https://postd.cc"
    else:
        page_url = f"https://postd.cc/page/{i}/"
    # 負荷をかけすぎないように待機
    time.sleep(1)
    # 一覧ページへのリクエスト
    rlist = requests.get(page_url)
    soup = BeautifulSoup(rlist.text, features="html.parser")
    section = soup.find_all("section", attrs={"id":"block-container"})
    for block in section:
        ablocks = block.find_all("a", attrs={"class": "a-transition", "rel": "bookmark"})
        for ablock in ablocks:
            # 負荷をかけすぎないように待機
            time.sleep(1)
            blog_name = os.path.basename(os.path.dirname(ablock['href']))
            blog_url = f"https://postd.cc/{blog_name}"

            file_name = "{}.html".format(blog_name)
            html_path = os.path.join(save_directory, file_name)
            write_file(url=blog_url, file_path=html_path)
            print(blog_url)
'''

# %% [markdown]
# ### MySQLクラス

# %%
import MySQLdb

class MysqlClass:
    connection = None
    cursor = None
    
    def connect(self):
        # データベースへの接続
        self.connection = MySQLdb.connect(
        user='root',
        passwd='',
        host='192.168.1.44',
        db='postd',
        charset='utf8')
        # カーソルの作成
        self.cursor = self.connection.cursor()

    def disconnect(self):
        # 接続を閉じる
        self.connection.close()

    def add_article (self, entry_title, post_date, tag, content, meta_info):
        self.connect()
        sql = 'INSERT INTO article (entry_title, post_date, tag, content, meta_info) VALUES (%s, %s, %s, %s, %s)'
        self.cursor.execute(sql, (entry_title, post_date, tag, content, meta_info))
        self.connection.commit()
        self.disconnect()
        
    def set_article_by_id(self, column, id, value):
        self.connect()
        
        sql = 'UPDATE article SET {0} = %s where id = %s'.format(column)
        self.cursor.execute(sql, (json.dumps(value), id))
        self.connection.commit()
        self.disconnect()
        
    def find_all(self, columns='*'):
        self.connect()
        if columns == '*':
            sql = 'SELECT {0} FROM article ORDER BY post_date DESC'.format(columns)
        else:
            sql = 'SELECT {0} FROM article ORDER BY post_date DESC'.format(','.join(columns))
        self.cursor.execute(sql)
        rows = self.cursor.fetchall()
        self.disconnect()  
        return rows

    def find_ids(self, limit, offset=0):
        self.connect()
        sql = 'SELECT id FROM article ORDER BY post_date DESC LIMIT %s OFFSET %s'
        self.cursor.execute(sql, (limit, offset))
        rows = self.cursor.fetchall()
        self.disconnect()  
        return rows

    def find_article_by_id(self, columns, id ):
        self.connect()
        sql = 'SELECT {0} FROM article WHERE id = %s'.format(','.join(columns))
        self.cursor.execute(sql, (id,))
        row = self.cursor.fetchone()
        self.disconnect()  
        return row

    def find_article_by_entry_title(self, columns, entry_title):
        self.connect()
        sql = 'SELECT {0} FROM article WHERE entry_title LIKE %s'.format(','.join(columns))
        self.cursor.execute(sql, ('%' + entry_title + '%',))
        rows = self.cursor.fetchone()
        self.disconnect()
        return rows

mysql_class = MysqlClass()

# %% [markdown]
# ### 記事ファイルから抽出処理

# %%
#　全角文字に変換
translation_table = str.maketrans(dict(zip('()!', '（）！')))

def cleanse(text):
    # Normalization Form Compatibility Composition
    text = unicodedata.normalize('NFKC', text).translate(translation_table)
    # スペースを半角スペースに統一
    text = re.sub(r'\s+', ' ', text)
    return text

def scrape(soup):
    
    # 見出しの抽出
    entry_title = soup.find('div', attrs={'class': 'block-titles'}).find('h1', attrs={'class': 'block-entry-title'}).get_text()
        
    # 日付の抽出
    post_date = soup.find('div', attrs={'class': 'block-titles'}).find('div', attrs={'class': 'block-date'}).get_text()
    post_date = datetime.datetime.strptime(post_date, '%Y年%m月%d日').strftime('%Y-%m-%d')
    
    # カテゴリの抽出
    tag_block = soup.find('div', attrs={'class': 'tagcloud', 'itemprop': 'keywords'})
    if(tag_block != None):
        tag = ','.join(cleanse(taga.text.strip())
                      for taga in tag_block.find_all(['a'])
                      if len(taga.text.strip()) > 0)
    else:
        tag = None
        
    # 本文の抽出
    honbun = soup.find('div', attrs={'class': 'block-text-content'}).find('div', attrs={'class': 'markdown-content'})

    # __EOS__ の挿入
    for block in honbun.find_all(['br', 'p', 'h1', 'h2', 'h3', 'h4', 'li', 'strong']):
        if len(block.text.strip()) > 0 and block.text.strip()[-1] not in ['。', '！']:
            block.append('<__EOS__>')
    # 本文の抽出
    text = '\n'.join([cleanse(block.text.strip())
                      for block in honbun.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'li'])
                      if len(block.text.strip()) > 0])
    # タイトルの抽出
    title = cleanse(soup.title.text.replace(' | POSTD', ''))
    return entry_title, post_date, tag, text, title

# %% [markdown]
# ### htmlデータをDBに登録

# %%
for filename in glob.glob('./postd/*.html'):
    soup = BeautifulSoup(open(filename, encoding="utf-8"), features="html.parser")
    entry_title, post_date, tag, content, title = scrape(soup)
    url = 'https://postd.cc/{0}'.format(urllib.parse.quote(os.path.basename(filename).replace('.html', '/')))
    meta_info = json.dumps({'url': url, 'title': title})
    try:
        mysql_class.add_article(entry_title, post_date, tag, content, meta_info)
    except:
        import traceback
        traceback.print_exc()
        mysql_class.disconnect()

# %% [markdown]
# ### 単一実行用

# %%
filename = './postd/q-and-a.html'
soup = BeautifulSoup(open(filename, encoding="utf-8"), features="html.parser")
entry_title, post_date, tag, content, title = scrape(soup)
url = 'https://postd.cc/{0}'.format(urllib.parse.quote(os.path.basename(filename).replace('.html', '/')))
meta_info = json.dumps({'url': url, 'title': title})
print(content)
# Out:
# 近い将来、AIが人間社会に与える影響とは?<__EOS__> 近い将来、いくつかの大きなイノベーションが起こる可能性は非常に高いでしょう。自動運転車は既に本格的な開発および試験段階にあり、近いうちに販売を開始すると公約した自動車メーカーもあります（一方で困難を認識し、より慎重になっているメーカーもあります）。また、コンピュータビジョンや脚式移動の改善により、農業やその他の事業の基盤作り、あるいは（特に高齢者や病人に対する）家の雑用サポートなどを含む、非構造化環境向けのロボットも実用的になっています。そして、機械が言語の理解を向上させるにつれて、検索エンジンや携帯電話の “パーソナルアシスタント” は、その力点をWebページのインデクス作成からWebページの理解へとシフトさせており、それが質問の回答や新しい情報の統合、あるいはアドバイスの提供や複数情報からの結論の導出というような性能の質的な向上につながっています。AIはまた、情報の量と複雑さが人間の能力にとって壁となっていた、システム生物学のような科学分野にも大きな影響を与えるかもしれません。 一般的な誤解 ロボットが “支配する力” を握ろうとしている。 AIのシステムが人間よりも知能が高くなるのはいつか?をご覧ください。AIの進歩の大部分はコンピュータとロボットをより有用にするためのものであり、その歩みは段階的です。ただし、人間による制御を維持するという問題は、長期的には重要になるでしょう。
# 近い将来、いくつかの大きなイノベーションが起こる可能性は非常に高いでしょう。自動運転車は既に本格的な開発および試験段階にあり、近いうちに販売を開始すると公約した自動車メーカーもあります（一方で困難を認識し、より慎重になっているメーカーもあります）。また、コンピュータビジョンや脚式移動の改善により、農業やその他の事業の基盤作り、あるいは（特に高齢者や病人に対する）家の雑用サポートなどを含む、非構造化環境向けのロボットも実用的になっています。そして、機械が言語の理解を向上させるにつれて、検索エンジンや携帯電話の “パーソナルアシスタント” は、その力点をWebページのインデクス作成からWebページの理解へとシフトさせており、それが質問の回答や新しい情報の統合、あるいはアドバイスの提供や複数情報からの結論の導出というような性能の質的な向上につながっています。AIはまた、情報の量と複雑さが人間の能力にとって壁となっていた、システム生物学のような科学分野にも大きな影響を与えるかもしれません。
# 一般的な誤解 ロボットが “支配する力” を握ろうとしている。 AIのシステムが人間よりも知能が高くなるのはいつか?をご覧ください。AIの進歩の大部分はコンピュータとロボットをより有用にするためのものであり、その歩みは段階的です。ただし、人間による制御を維持するという問題は、長期的には重要になるでしょう。
# ロボットが “支配する力” を握ろうとしている。 AIのシステムが人間よりも知能が高くなるのはいつか?をご覧ください。AIの進歩の大部分はコンピュータとロボットをより有用にするためのものであり、その歩みは段階的です。ただし、人間による制御を維持するという問題は、長期的には重要になるでしょう。
# AIやロボット工学の進歩は、現在、人間が従事している仕事の大部分を奪うか?<__EOS__> 一部の研究、例えばFreyとOsborneの研究（2013）は、近い将来、米国の雇用の約半分が自動化により消滅する可能性があると指摘しています。また、例えばBrynjolfssonとMcAfee（2011）による別の研究では、そのプロセスは既に始まっていると主張しており、2008年の不況後、完全雇用の回復が非常に緩やかなことや単純作業における自動化の割合の高まりによって生産性は向上している反面、賃金は停滞していることなどを指摘しています。AIやロボティクスの進歩が今後も続くと仮定すると、より多くの職業に影響が出ることは必至です。このことは必ずしも大規模な失業の発生を意味するわけではありません。しかし、経済構造に大きな変化をもたらす可能性があり、仕事と報酬の構造を確立するための新たなアイデアが必要になってくるでしょう。 一般的な誤解 ロボットが仕事をすることで、人間の仕事が減る。仕事は、ゼロサム和ではありません。ロボットチームによる支援を受けた人は、生産性がはるかに向上し、それゆえに要求される仕事はますます増えることもあるかもしれません。逆にロボットの助けがない場合、ある試みを実行に移す際、経済的な観点からその仕事が実行不可能になることもあるでしょう。そうなれば人にもロボットにも仕事は発生しません。これは、ブラシやローラーが使えるからこそ、塗装工の仕事が発生するのと同じことです。針の先端を使って一滴ずつ塗料を滴下しなければならないような場合、家の塗装に塗装工を雇うのは経済的に難しくなるはずです。
# 一部の研究、例えばFreyとOsborneの研究（2013）は、近い将来、米国の雇用の約半分が自動化により消滅する可能性があると指摘しています。また、例えばBrynjolfssonとMcAfee（2011）による別の研究では、そのプロセスは既に始まっていると主張しており、2008年の不況後、完全雇用の回復が非常に緩やかなことや単純作業における自動化の割合の高まりによって生産性は向上している反面、賃金は停滞していることなどを指摘しています。AIやロボティクスの進歩が今後も続くと仮定すると、より多くの職業に影響が出ることは必至です。このことは必ずしも大規模な失業の発生を意味するわけではありません。しかし、経済構造に大きな変化をもたらす可能性があり、仕事と報酬の構造を確立するための新たなアイデアが必要になってくるでしょう。
# 一般的な誤解 ロボットが仕事をすることで、人間の仕事が減る。仕事は、ゼロサム和ではありません。ロボットチームによる支援を受けた人は、生産性がはるかに向上し、それゆえに要求される仕事はますます増えることもあるかもしれません。逆にロボットの助けがない場合、ある試みを実行に移す際、経済的な観点からその仕事が実行不可能になることもあるでしょう。そうなれば人にもロボットにも仕事は発生しません。これは、ブラシやローラーが使えるからこそ、塗装工の仕事が発生するのと同じことです。針の先端を使って一滴ずつ塗料を滴下しなければならないような場合、家の塗装に塗装工を雇うのは経済的に難しくなるはずです。
# ロボットが仕事をすることで、人間の仕事が減る。仕事は、ゼロサム和ではありません。ロボットチームによる支援を受けた人は、生産性がはるかに向上し、それゆえに要求される仕事はますます増えることもあるかもしれません。逆にロボットの助けがない場合、ある試みを実行に移す際、経済的な観点からその仕事が実行不可能になることもあるでしょう。そうなれば人にもロボットにも仕事は発生しません。これは、ブラシやローラーが使えるからこそ、塗装工の仕事が発生するのと同じことです。針の先端を使って一滴ずつ塗料を滴下しなければならないような場合、家の塗装に塗装工を雇うのは経済的に難しくなるはずです。
# ドローン、自律型兵器、キラーロボットとは?<__EOS__> ドローンは遠隔操作が可能な無人飛行機で、その一部は人間による制御で発射可能な武器（通常はミサイル）を装備しています。自律型兵器とは、ターゲットを自動的に選択して “狙いを定める” （つまり、破壊しようとする）装置全般を指します。最新のシステムには、韓国のDMZ（非武装地帯）で使用されている据え置き式の自動照準マシンガンや船舶用のミサイル防御システムなどがあります。人間によるドローン制御を完全な自動システムで置き換えることは、技術的に見ると急速なペースで実現可能になってきており、それがCCW（ “特定通常兵器” に関するジュネーブでの国連会議）において争点にもなった自律型致死兵器システム（LAWS:Lethal Autonomous Weapon Systems）へとつながっていきます。 “キラーロボット” という用語はこのクラスの兵器のことを指しており、車輪付きまたは脚式の車両、船舶、飛行機、潜水艦、さらには飛行型の人工 “昆虫” なども含むことがあります。 一般的な誤解 完全な自律型兵器の実現は20~30年先の話である。ジュネーブでのLAWSの議論について書かれた多くの記事では、この主張が繰り返されています。その論拠は不明ですが、時間を多く見積もりすぎているように思われてなりません。自律型兵器を配備する技術は大方整っており、技術的には自動運転車を作るよりも容易に思えます（兵器の信頼性要件が自動運転車よりはるかに低いのもその一因です）。英国国防省によると、海戦などのような隊列を組む配置では、完全な自律型兵器は “恐らく今すぐにでも実現可能である” とのことです。 自律型兵器があれば、人間が戦争で命を落とす必要はない。戦争は通常、どちらか一方が持続不可能な損失に陥るか、その人民を守る能力を失い降伏するまで続けられます。その時国家は、 “我々はおはじきに負けたから降伏する。私たちを奴隷にするがいい” とは言わないのと同様、 “我々のロボットが負けたから降伏する。私たちを奴隷にするがいい” とは言わないでしょう。 機械は人間よりもうまく戦闘員と非戦闘員を区別できる、あるいはじきにできるようになるため、戦争の際には機械を使うべきである。まず、国際人道法（IHL）の下では、攻撃の際に要求されるのは区別する能力だけではなく、軍事的な必要性と（軍事目的の価値と予想される付随的損害の間の）割合を判断する能力も必要となります。次に、IHLへの順守だけが問題ではありません。自律型兵器においては、発射される兵器の数とそれらを制御するのに必要な人員の数は全く別物のため、自律型兵器が拡張可能な大量破壊兵器として機能することもあり得ます。大規模な対人兵器群には特にそういった懸念があり、核攻撃の犠牲者に匹敵する死傷者をもたらす可能性さえあります。
# ドローンは遠隔操作が可能な無人飛行機で、その一部は人間による制御で発射可能な武器（通常はミサイル）を装備しています。自律型兵器とは、ターゲットを自動的に選択して “狙いを定める” （つまり、破壊しようとする）装置全般を指します。最新のシステムには、韓国のDMZ（非武装地帯）で使用されている据え置き式の自動照準マシンガンや船舶用のミサイル防御システムなどがあります。人間によるドローン制御を完全な自動システムで置き換えることは、技術的に見ると急速なペースで実現可能になってきており、それがCCW（ “特定通常兵器” に関するジュネーブでの国連会議）において争点にもなった自律型致死兵器システム（LAWS:Lethal Autonomous Weapon Systems）へとつながっていきます。 “キラーロボット” という用語はこのクラスの兵器のことを指しており、車輪付きまたは脚式の車両、船舶、飛行機、潜水艦、さらには飛行型の人工 “昆虫” なども含むことがあります。
# 一般的な誤解 完全な自律型兵器の実現は20~30年先の話である。ジュネーブでのLAWSの議論について書かれた多くの記事では、この主張が繰り返されています。その論拠は不明ですが、時間を多く見積もりすぎているように思われてなりません。自律型兵器を配備する技術は大方整っており、技術的には自動運転車を作るよりも容易に思えます（兵器の信頼性要件が自動運転車よりはるかに低いのもその一因です）。英国国防省によると、海戦などのような隊列を組む配置では、完全な自律型兵器は “恐らく今すぐにでも実現可能である” とのことです。 自律型兵器があれば、人間が戦争で命を落とす必要はない。戦争は通常、どちらか一方が持続不可能な損失に陥るか、その人民を守る能力を失い降伏するまで続けられます。その時国家は、 “我々はおはじきに負けたから降伏する。私たちを奴隷にするがいい” とは言わないのと同様、 “我々のロボットが負けたから降伏する。私たちを奴隷にするがいい” とは言わないでしょう。 機械は人間よりもうまく戦闘員と非戦闘員を区別できる、あるいはじきにできるようになるため、戦争の際には機械を使うべきである。まず、国際人道法（IHL）の下では、攻撃の際に要求されるのは区別する能力だけではなく、軍事的な必要性と（軍事目的の価値と予想される付随的損害の間の）割合を判断する能力も必要となります。次に、IHLへの順守だけが問題ではありません。自律型兵器においては、発射される兵器の数とそれらを制御するのに必要な人員の数は全く別物のため、自律型兵器が拡張可能な大量破壊兵器として機能することもあり得ます。大規模な対人兵器群には特にそういった懸念があり、核攻撃の犠牲者に匹敵する死傷者をもたらす可能性さえあります。
# 完全な自律型兵器の実現は20~30年先の話である。ジュネーブでのLAWSの議論について書かれた多くの記事では、この主張が繰り返されています。その論拠は不明ですが、時間を多く見積もりすぎているように思われてなりません。自律型兵器を配備する技術は大方整っており、技術的には自動運転車を作るよりも容易に思えます（兵器の信頼性要件が自動運転車よりはるかに低いのもその一因です）。英国国防省によると、海戦などのような隊列を組む配置では、完全な自律型兵器は “恐らく今すぐにでも実現可能である” とのことです。
# 自律型兵器があれば、人間が戦争で命を落とす必要はない。戦争は通常、どちらか一方が持続不可能な損失に陥るか、その人民を守る能力を失い降伏するまで続けられます。その時国家は、 “我々はおはじきに負けたから降伏する。私たちを奴隷にするがいい” とは言わないのと同様、 “我々のロボットが負けたから降伏する。私たちを奴隷にするがいい” とは言わないでしょう。
# 機械は人間よりもうまく戦闘員と非戦闘員を区別できる、あるいはじきにできるようになるため、戦争の際には機械を使うべきである。まず、国際人道法（IHL）の下では、攻撃の際に要求されるのは区別する能力だけではなく、軍事的な必要性と（軍事目的の価値と予想される付随的損害の間の）割合を判断する能力も必要となります。次に、IHLへの順守だけが問題ではありません。自律型兵器においては、発射される兵器の数とそれらを制御するのに必要な人員の数は全く別物のため、自律型兵器が拡張可能な大量破壊兵器として機能することもあり得ます。大規模な対人兵器群には特にそういった懸念があり、核攻撃の犠牲者に匹敵する死傷者をもたらす可能性さえあります。
# キラーロボットの暴走やキラーロボットによる世界の支配を不安視する必要はあるか?<__EOS__> 自律型兵器が配備されたとしても、敵と味方、戦闘員と民間人を区別することについては、人間の兵士が直面するのと同程度の難しさが生じます。民間人に死をもたらす戦術的な事故があるかもしれませんし、ジャミングやサイバー攻撃によってロボットが危険にさらされるかもしれません。後者の問題に対して、一部の軍事専門家は、自律型兵器に電子通信なしで動作するクローズドシステムが必要かもしれないということを予見していますが、そうなれば万が一システムが正しく動作しない場合、自律コントローラを無効にすることが困難になります。しかしいずれにしろ、近い将来には自律型兵器は限定された範囲の任務において戦術的な性格を持ちながら使われるようになっていくと思います。世界的な流れとして、任務計画を独自に構築するようなプログラムを施される可能性は極めて低いはずです。 一般的な誤解 “off”スイッチを押せば事は済む。 “off”スイッチを押してしまうと、その自律型兵器はサイバー攻撃に対して脆弱になってしまいます。そうした通信経路は、戦時下においては無効になっている場合がほとんどでしょう。さらに、インテリジェントなシステムは通常、実行する任務が与えられた場合、 “off” スイッチが押されるのを回避しようとします。
# 自律型兵器が配備されたとしても、敵と味方、戦闘員と民間人を区別することについては、人間の兵士が直面するのと同程度の難しさが生じます。民間人に死をもたらす戦術的な事故があるかもしれませんし、ジャミングやサイバー攻撃によってロボットが危険にさらされるかもしれません。後者の問題に対して、一部の軍事専門家は、自律型兵器に電子通信なしで動作するクローズドシステムが必要かもしれないということを予見していますが、そうなれば万が一システムが正しく動作しない場合、自律コントローラを無効にすることが困難になります。しかしいずれにしろ、近い将来には自律型兵器は限定された範囲の任務において戦術的な性格を持ちながら使われるようになっていくと思います。世界的な流れとして、任務計画を独自に構築するようなプログラムを施される可能性は極めて低いはずです。
# 一般的な誤解 “off”スイッチを押せば事は済む。 “off”スイッチを押してしまうと、その自律型兵器はサイバー攻撃に対して脆弱になってしまいます。そうした通信経路は、戦時下においては無効になっている場合がほとんどでしょう。さらに、インテリジェントなシステムは通常、実行する任務が与えられた場合、 “off” スイッチが押されるのを回避しようとします。
# “off”スイッチを押せば事は済む。 “off”スイッチを押してしまうと、その自律型兵器はサイバー攻撃に対して脆弱になってしまいます。そうした通信経路は、戦時下においては無効になっている場合がほとんどでしょう。さらに、インテリジェントなシステムは通常、実行する任務が与えられた場合、 “off” スイッチが押されるのを回避しようとします。
# AIの “存在リスク” とは? それは真実か?<__EOS__> AIのリスクに関する警告は、初期の頃は比較的あいまいなものでした。Turingは1951年のラジオ講演で、スーパーインテリジェントAIのリスクを指摘する必要性を次のように述べています。 “機械が考えることができる場合、恐らく私たち人間よりも知的に考えるでしょう。そうなった場合、私たちの居場所はどこにあるでしょうか? 仮に私たちが機械を、例えば戦略的に重要な瞬間に電源を切るなどして、従属的な位置に維持できたとしても、私たちは人類として大いに恥じ入るべきです。...この新たな危険性...が、私たちを不安にします。” また、I. J. Goodは、情報爆発の利点についての彼の予測に、 “ただし、機械が制御可能なほどに従順な場合に限る” という但し書きを加えました。私たちは、この地球上におけるスーパーインテリジェントな要素の存在が私たちの懸念の原因になっているという漠然とした感覚を持ってはいますが、一方で、よりスマートな機械がより有用であることにも気付いているため、機械の知的向上が悪であると、はっきり言い切ることもできません。実際のところ、この議論の内容は単純明快です。 スーパーインテリジェントシステムが、特定の目的を達成するために人間の設計者によって設計されたとしましょう。しかし、その目的が、人類の価値とは完全に一致していないと仮定します。その場合、目的を明確に定義することは（どれだけ頑張っても）非常に困難です。 十分な能力を持つ知的システムは、自身のためにではなく、割り当てられた仕事を成就するために、それ自身の存続を確保しながら物理的および計算的な資源を獲得しようとします。 ここで問題なのは、上記は本質的に『Genie in the Lamp（ランプの魔神）』や『魔法使いの弟子』、あるいは『ミダース』といった古い物語と同じであり、自分の希望ではなく、必要とするものを確実に理解する必要があるということです。1960年、自動化と制御理論のパイオニアであるNorbert Wienerは、 “目的の達成のために私たちが干渉できない機械エージェンシーを使う場合、機械に入力する目的事項は、私たちが本当に望むものでなければならない” と書きました。Marvin Minskyは、機械にパイの桁数を可能な限り多く計算させるという例を挙げ、Nick Bostromは、たくさんのペーパークリップを要求するという例を挙げています。このような目的が人間に与えられた場合、人間はそれを一般的な目的の文脈において解釈し、地球全体を計算サーバやペーパークリップで覆うことは得策ではないと判断するはずです。しかし高度に知的な機械、特にネットを通じて世界中の情報、膨大な数のスクリーン、そして我々人間が利用しているインフラストラクチャの大半に接続された機械は、その目的を通じて人類に不可逆的な影響を与える可能性を持っているのです。幸いにも問題の性質がやや明確になってきたため、解決策への取り組みを始められるようになってきました。 一般的な誤解 スーパーインテリジェントな機械は自ら意志を持つようになる、あるいは本質的に悪であり人間を憎んでいる。 SF作家は機械と人間の対立を描くために、こうした背景を設定する傾向にありますが、このような設定には意味がなく、何の根拠もありません。 AIシステムを開発した人間が、自分自身を破壊するわけがない。一部のAI “擁護者” は、AIシステムを構築したのは人間なのだから、自身を破滅に追い込むためにそれを構築したと仮定する理由はないと論じます。これは、設計者やエージェントの意図的な悪意が脅威の存在の前提条件であることを見過ごした意見と言えるでしょう。問題は、方向を誤った目的の指定によって生じるのです。 問題は決して起こらない。 “AIのシステムが人間よりも知能が高くなるのはいつか?” をご覧ください。
# AIのリスクに関する警告は、初期の頃は比較的あいまいなものでした。Turingは1951年のラジオ講演で、スーパーインテリジェントAIのリスクを指摘する必要性を次のように述べています。 “機械が考えることができる場合、恐らく私たち人間よりも知的に考えるでしょう。そうなった場合、私たちの居場所はどこにあるでしょうか? 仮に私たちが機械を、例えば戦略的に重要な瞬間に電源を切るなどして、従属的な位置に維持できたとしても、私たちは人類として大いに恥じ入るべきです。...この新たな危険性...が、私たちを不安にします。” また、I. J. Goodは、情報爆発の利点についての彼の予測に、 “ただし、機械が制御可能なほどに従順な場合に限る” という但し書きを加えました。私たちは、この地球上におけるスーパーインテリジェントな要素の存在が私たちの懸念の原因になっているという漠然とした感覚を持ってはいますが、一方で、よりスマートな機械がより有用であることにも気付いているため、機械の知的向上が悪であると、はっきり言い切ることもできません。実際のところ、この議論の内容は単純明快です。 スーパーインテリジェントシステムが、特定の目的を達成するために人間の設計者によって設計されたとしましょう。しかし、その目的が、人類の価値とは完全に一致していないと仮定します。その場合、目的を明確に定義することは（どれだけ頑張っても）非常に困難です。 十分な能力を持つ知的システムは、自身のためにではなく、割り当てられた仕事を成就するために、それ自身の存続を確保しながら物理的および計算的な資源を獲得しようとします。 ここで問題なのは、上記は本質的に『Genie in the Lamp（ランプの魔神）』や『魔法使いの弟子』、あるいは『ミダース』といった古い物語と同じであり、自分の希望ではなく、必要とするものを確実に理解する必要があるということです。1960年、自動化と制御理論のパイオニアであるNorbert Wienerは、 “目的の達成のために私たちが干渉できない機械エージェンシーを使う場合、機械に入力する目的事項は、私たちが本当に望むものでなければならない” と書きました。Marvin Minskyは、機械にパイの桁数を可能な限り多く計算させるという例を挙げ、Nick Bostromは、たくさんのペーパークリップを要求するという例を挙げています。このような目的が人間に与えられた場合、人間はそれを一般的な目的の文脈において解釈し、地球全体を計算サーバやペーパークリップで覆うことは得策ではないと判断するはずです。しかし高度に知的な機械、特にネットを通じて世界中の情報、膨大な数のスクリーン、そして我々人間が利用しているインフラストラクチャの大半に接続された機械は、その目的を通じて人類に不可逆的な影響を与える可能性を持っているのです。幸いにも問題の性質がやや明確になってきたため、解決策への取り組みを始められるようになってきました。
# スーパーインテリジェントシステムが、特定の目的を達成するために人間の設計者によって設計されたとしましょう。しかし、その目的が、人類の価値とは完全に一致していないと仮定します。その場合、目的を明確に定義することは（どれだけ頑張っても）非常に困難です。
# 十分な能力を持つ知的システムは、自身のためにではなく、割り当てられた仕事を成就するために、それ自身の存続を確保しながら物理的および計算的な資源を獲得しようとします。 ここで問題なのは、上記は本質的に『Genie in the Lamp（ランプの魔神）』や『魔法使いの弟子』、あるいは『ミダース』といった古い物語と同じであり、自分の希望ではなく、必要とするものを確実に理解する必要があるということです。1960年、自動化と制御理論のパイオニアであるNorbert Wienerは、 “目的の達成のために私たちが干渉できない機械エージェンシーを使う場合、機械に入力する目的事項は、私たちが本当に望むものでなければならない” と書きました。Marvin Minskyは、機械にパイの桁数を可能な限り多く計算させるという例を挙げ、Nick Bostromは、たくさんのペーパークリップを要求するという例を挙げています。このような目的が人間に与えられた場合、人間はそれを一般的な目的の文脈において解釈し、地球全体を計算サーバやペーパークリップで覆うことは得策ではないと判断するはずです。しかし高度に知的な機械、特にネットを通じて世界中の情報、膨大な数のスクリーン、そして我々人間が利用しているインフラストラクチャの大半に接続された機械は、その目的を通じて人類に不可逆的な影響を与える可能性を持っているのです。幸いにも問題の性質がやや明確になってきたため、解決策への取り組みを始められるようになってきました。
# 一般的な誤解 スーパーインテリジェントな機械は自ら意志を持つようになる、あるいは本質的に悪であり人間を憎んでいる。 SF作家は機械と人間の対立を描くために、こうした背景を設定する傾向にありますが、このような設定には意味がなく、何の根拠もありません。 AIシステムを開発した人間が、自分自身を破壊するわけがない。一部のAI “擁護者” は、AIシステムを構築したのは人間なのだから、自身を破滅に追い込むためにそれを構築したと仮定する理由はないと論じます。これは、設計者やエージェントの意図的な悪意が脅威の存在の前提条件であることを見過ごした意見と言えるでしょう。問題は、方向を誤った目的の指定によって生じるのです。 問題は決して起こらない。 “AIのシステムが人間よりも知能が高くなるのはいつか?” をご覧ください。
# スーパーインテリジェントな機械は自ら意志を持つようになる、あるいは本質的に悪であり人間を憎んでいる。 SF作家は機械と人間の対立を描くために、こうした背景を設定する傾向にありますが、このような設定には意味がなく、何の根拠もありません。
# AIシステムを開発した人間が、自分自身を破壊するわけがない。一部のAI “擁護者” は、AIシステムを構築したのは人間なのだから、自身を破滅に追い込むためにそれを構築したと仮定する理由はないと論じます。これは、設計者やエージェントの意図的な悪意が脅威の存在の前提条件であることを見過ごした意見と言えるでしょう。問題は、方向を誤った目的の指定によって生じるのです。
# 問題は決して起こらない。 “AIのシステムが人間よりも知能が高くなるのはいつか?” をご覧ください。
# なぜ人々はAIに突然、懸念を抱くようになったのか?<__EOS__> 2014年以降、メディアはStephen HawkingやElon Musk、Steve Wozniak、あるいはBill Gatesといった著名人の言葉を借りながら、AIについての懸念を定期的に報道するようになりました。こうした報道で目立つのは差し迫る破滅を暗示するようなキャッチフレーズの引用のみで、AIの “存在リスク” とは? それは真実か?で述べたような懸念の根底にある理由とその本質についての説明は省略されることがほとんどです。なお、多くの場合において、これらの懸念はNick Bostromの著書『Superintelligence: Paths, Dangers, Strategies（スーパーインテリジェンス:方向性、危険性、戦略）』が元になっています。この話題が興味を集めるようになったもう1つの理由として、AIの発展が急速に進んでいるように見えるという事実が挙げられます。この加速度的な進歩は、AIの様々な分野の統合が進んだことで論理的な基盤が固まってきたということ、そしてAI研究における商業的な投資が急激に増加し、研究室における試行錯誤の成果が実世界の問題解決に応用できるようになったことに起因していると言えるでしょう。 一般的な誤解 人々が望めば、スーパーインテリジェントAIはすぐに完成するはずである。もしいたとしても、スーパーインテリジェントな機械がすぐに完成形態に至ると考える研究者はごく少数でしょう（ “AIのシステムが人間よりも知能が高くなるのはいつか?” をご覧ください）。これは、問題に真剣に取り組めるようになるまで手をこまねいて待つべきだ、という意味ではありません。例えば50年後に地球に衝突する軌道に乗った直径16キロ前後の小惑星を発見したとして、 “衝突の5年前になったら警戒するよ” とは言わないですよね。
# 2014年以降、メディアはStephen HawkingやElon Musk、Steve Wozniak、あるいはBill Gatesといった著名人の言葉を借りながら、AIについての懸念を定期的に報道するようになりました。こうした報道で目立つのは差し迫る破滅を暗示するようなキャッチフレーズの引用のみで、AIの “存在リスク” とは? それは真実か?で述べたような懸念の根底にある理由とその本質についての説明は省略されることがほとんどです。なお、多くの場合において、これらの懸念はNick Bostromの著書『Superintelligence: Paths, Dangers, Strategies（スーパーインテリジェンス:方向性、危険性、戦略）』が元になっています。この話題が興味を集めるようになったもう1つの理由として、AIの発展が急速に進んでいるように見えるという事実が挙げられます。この加速度的な進歩は、AIの様々な分野の統合が進んだことで論理的な基盤が固まってきたということ、そしてAI研究における商業的な投資が急激に増加し、研究室における試行錯誤の成果が実世界の問題解決に応用できるようになったことに起因していると言えるでしょう。
# 一般的な誤解 人々が望めば、スーパーインテリジェントAIはすぐに完成するはずである。もしいたとしても、スーパーインテリジェントな機械がすぐに完成形態に至ると考える研究者はごく少数でしょう（ “AIのシステムが人間よりも知能が高くなるのはいつか?” をご覧ください）。これは、問題に真剣に取り組めるようになるまで手をこまねいて待つべきだ、という意味ではありません。例えば50年後に地球に衝突する軌道に乗った直径16キロ前後の小惑星を発見したとして、 “衝突の5年前になったら警戒するよ” とは言わないですよね。
# 人々が望めば、スーパーインテリジェントAIはすぐに完成するはずである。もしいたとしても、スーパーインテリジェントな機械がすぐに完成形態に至ると考える研究者はごく少数でしょう（ “AIのシステムが人間よりも知能が高くなるのはいつか?” をご覧ください）。これは、問題に真剣に取り組めるようになるまで手をこまねいて待つべきだ、という意味ではありません。例えば50年後に地球に衝突する軌道に乗った直径16キロ前後の小惑星を発見したとして、 “衝突の5年前になったら警戒するよ” とは言わないですよね。
# AIは今後数十年でどのように進歩するのか?<__EOS__> 人間レベルの一般的な知識を必要としない領域は恐らく次の10年で成熟し、信頼性の高い製品が生み出されることになると思われます。この領域に含まれるのは、音声認識や単純な事実関係を示す資料からの情報抽出、物体および行動の視覚認識、日常的な物体のロボット操作、そして自動運転などの技術です。文書や映像に対する解読システムの適用範囲拡大や質の向上、あるいは家庭用ロボットの汎用性を高め安定性を向上させるといった努力は、常識を記憶したシステムへとつながり、全ての様相にわたって学習とパフォーマンスを結び付けることになると思います。そして、科学的な知識の獲得や構造化、そして複雑な仮説を扱うための特別なシステムについては、恐らく分子生物学、システム生物学、および医学において非常に重要な影響を及ぼすことになるでしょう。また、特に人間の活動に関する機械可読データが大幅に増加し、それらが人間の価値に確かな有用性を持っているかどうかを理解する必要性を考慮した場合、社会科学や政策形成においても同様の影響を見ることになるかもしれません。単なるデータのリポジトリとは違う、現実世界を知り、推論するシステムとしての公的および私的な知識のソースは、社会の不可欠な部分になるはずです。
# 人間レベルの一般的な知識を必要としない領域は恐らく次の10年で成熟し、信頼性の高い製品が生み出されることになると思われます。この領域に含まれるのは、音声認識や単純な事実関係を示す資料からの情報抽出、物体および行動の視覚認識、日常的な物体のロボット操作、そして自動運転などの技術です。文書や映像に対する解読システムの適用範囲拡大や質の向上、あるいは家庭用ロボットの汎用性を高め安定性を向上させるといった努力は、常識を記憶したシステムへとつながり、全ての様相にわたって学習とパフォーマンスを結び付けることになると思います。そして、科学的な知識の獲得や構造化、そして複雑な仮説を扱うための特別なシステムについては、恐らく分子生物学、システム生物学、および医学において非常に重要な影響を及ぼすことになるでしょう。また、特に人間の活動に関する機械可読データが大幅に増加し、それらが人間の価値に確かな有用性を持っているかどうかを理解する必要性を考慮した場合、社会科学や政策形成においても同様の影響を見ることになるかもしれません。単なるデータのリポジトリとは違う、現実世界を知り、推論するシステムとしての公的および私的な知識のソースは、社会の不可欠な部分になるはずです。
# “価値の整合”とは? これがなぜ重要なのか?<__EOS__> 価値の整合とは、大ざっぱに言えば、機械の最適な選択が、何であれ人間を幸せにするようなものになるように、機械の価値観（目的）を人間のそれに合わせることです。こうしておかないと、スーパーインテリジェントな機械が人間の制御を超える存在になるという、無視できないリスクがあるからです。 一般的な誤解 アシモフのロボット三原則があれば十分である。アシモフのロボット三原則は、 “ロボットは絶対的に人間に服従” という趣旨に基づいています。この原則は、さまざまなものごとの筋書きの基礎を成すものとして、人間からみると十分合理的ですが、ロボットにとっては、もっと詳細な説明をしない限り、ほとんど意味のない情報しか含まれていません。三原則の基本構造を、機械の機能ではなく一連の規則として捉えると、定義の仕方に問題が数多く含まれています（例えば、人間にとって少しでも害のあるものは、いかなる場合でも、ロボットにとって全く有害でしかないものよりも重要だとすること）。つまり、この原則には不確実性やトレードオフの余地がありません。そのうち人間の血を吸うかもしれない蚊を捕まえるため、ロボットは自分自身が壊れる危険性が分かっていても崖から飛び降りなければならないのです。また一方では、人間が自動車に乗り込もうとすると必ず阻止します。人間は車に乗ると、危険に遭遇するリスクが高まるからです。さらには、人間の利益を最大化するアプローチに基づくとすれば、3番目の原則（ロボットの自己防衛）は不要になります。自己防衛をしないロボットは人間の利益と相反し、所有者を失望させるからです。
# 価値の整合とは、大ざっぱに言えば、機械の最適な選択が、何であれ人間を幸せにするようなものになるように、機械の価値観（目的）を人間のそれに合わせることです。こうしておかないと、スーパーインテリジェントな機械が人間の制御を超える存在になるという、無視できないリスクがあるからです。
# 一般的な誤解 アシモフのロボット三原則があれば十分である。アシモフのロボット三原則は、 “ロボットは絶対的に人間に服従” という趣旨に基づいています。この原則は、さまざまなものごとの筋書きの基礎を成すものとして、人間からみると十分合理的ですが、ロボットにとっては、もっと詳細な説明をしない限り、ほとんど意味のない情報しか含まれていません。三原則の基本構造を、機械の機能ではなく一連の規則として捉えると、定義の仕方に問題が数多く含まれています（例えば、人間にとって少しでも害のあるものは、いかなる場合でも、ロボットにとって全く有害でしかないものよりも重要だとすること）。つまり、この原則には不確実性やトレードオフの余地がありません。そのうち人間の血を吸うかもしれない蚊を捕まえるため、ロボットは自分自身が壊れる危険性が分かっていても崖から飛び降りなければならないのです。また一方では、人間が自動車に乗り込もうとすると必ず阻止します。人間は車に乗ると、危険に遭遇するリスクが高まるからです。さらには、人間の利益を最大化するアプローチに基づくとすれば、3番目の原則（ロボットの自己防衛）は不要になります。自己防衛をしないロボットは人間の利益と相反し、所有者を失望させるからです。
# アシモフのロボット三原則があれば十分である。アシモフのロボット三原則は、 “ロボットは絶対的に人間に服従” という趣旨に基づいています。この原則は、さまざまなものごとの筋書きの基礎を成すものとして、人間からみると十分合理的ですが、ロボットにとっては、もっと詳細な説明をしない限り、ほとんど意味のない情報しか含まれていません。三原則の基本構造を、機械の機能ではなく一連の規則として捉えると、定義の仕方に問題が数多く含まれています（例えば、人間にとって少しでも害のあるものは、いかなる場合でも、ロボットにとって全く有害でしかないものよりも重要だとすること）。つまり、この原則には不確実性やトレードオフの余地がありません。そのうち人間の血を吸うかもしれない蚊を捕まえるため、ロボットは自分自身が壊れる危険性が分かっていても崖から飛び降りなければならないのです。また一方では、人間が自動車に乗り込もうとすると必ず阻止します。人間は車に乗ると、危険に遭遇するリスクが高まるからです。さらには、人間の利益を最大化するアプローチに基づくとすれば、3番目の原則（ロボットの自己防衛）は不要になります。自己防衛をしないロボットは人間の利益と相反し、所有者を失望させるからです。
# AIの存在リスクに対して、AIのコミュニティはどのような取り組みをしているのか?<__EOS__> AIの存在リスクについての議論はほとんど、AIコミュニティの主流以外の場所で行われています。AIの研究者たちがこの話題に関して否定的な反応を示すのは、このことが大きな原因となっています。2008年、アメリカ人工知能学会（AAAI）でこの問題を研究するパネルが結成されました。このパネルの中間報告書では、このリスクがある程度長期的な問題となる可能性にも触れていましたが、AIが人類にとってのリスクとなるという概念はあまり強調されませんでした。もっと最近の例としては、2015年1月、ボランティア団体のFuture of Life Institute（FLI）がスポンサーとなり、プエルトリコでAIに関する会議が開催され、出席者の署名付きの公開質問状が公開されました。この質問状は結果的に8700名もの署名を集めましたが、その内容は、この問題を非常に重視した研究の実施と、その研究計画の詳細情報の報告を要求するものでした。この質問状の公開直後、Elon Muskはこの分野の研究を支援する資金として1000万ドルを寄付しました。さらにEric Horvitzは、この問題を追跡し、必要に応じて政策的な提言をまとめるための長期研究に資金を提供しました。大手ハイテク企業5社はAIに関する提携を結び、AIの倫理と安全性に関して、直近の問題と長期的な問題の両方への対処を進めています。そしてAAAIは、AIの影響と倫理的な問題に関する委員会を発足させました。またIEEEは、AIの安全性および自律型兵器についての規約を制定するためのプロセスを開始しました。 一般的な誤解 研究を規制したり制御を加えたりするのは不可能である。一部の人々は、研究の進化は止められず規制もできないため、否定的な事態の発生を回避する方法はないと主張しています。1975年に開催された、DNA組み換えに関するアシロマ会議では、組み換えによって新しいヒト遺伝子を作る研究について、自主的な一時停止期間を課すという決議に至りました。以来、この一時停止期間は現在に至るまで継続しており、国際的な規範となっています。さらに、仮に人間と同等の知能を持つAIを作り出す研究が何の審査も受けないとすれば（将来これが実現する可能性は十分あります）、AIシステムが人間の制御できる範囲を超えていないことを保証する方法についての綿密な研究が、なおさら重要になります。
# AIの存在リスクについての議論はほとんど、AIコミュニティの主流以外の場所で行われています。AIの研究者たちがこの話題に関して否定的な反応を示すのは、このことが大きな原因となっています。2008年、アメリカ人工知能学会（AAAI）でこの問題を研究するパネルが結成されました。このパネルの中間報告書では、このリスクがある程度長期的な問題となる可能性にも触れていましたが、AIが人類にとってのリスクとなるという概念はあまり強調されませんでした。もっと最近の例としては、2015年1月、ボランティア団体のFuture of Life Institute（FLI）がスポンサーとなり、プエルトリコでAIに関する会議が開催され、出席者の署名付きの公開質問状が公開されました。この質問状は結果的に8700名もの署名を集めましたが、その内容は、この問題を非常に重視した研究の実施と、その研究計画の詳細情報の報告を要求するものでした。この質問状の公開直後、Elon Muskはこの分野の研究を支援する資金として1000万ドルを寄付しました。さらにEric Horvitzは、この問題を追跡し、必要に応じて政策的な提言をまとめるための長期研究に資金を提供しました。大手ハイテク企業5社はAIに関する提携を結び、AIの倫理と安全性に関して、直近の問題と長期的な問題の両方への対処を進めています。そしてAAAIは、AIの影響と倫理的な問題に関する委員会を発足させました。またIEEEは、AIの安全性および自律型兵器についての規約を制定するためのプロセスを開始しました。
# 一般的な誤解 研究を規制したり制御を加えたりするのは不可能である。一部の人々は、研究の進化は止められず規制もできないため、否定的な事態の発生を回避する方法はないと主張しています。1975年に開催された、DNA組み換えに関するアシロマ会議では、組み換えによって新しいヒト遺伝子を作る研究について、自主的な一時停止期間を課すという決議に至りました。以来、この一時停止期間は現在に至るまで継続しており、国際的な規範となっています。さらに、仮に人間と同等の知能を持つAIを作り出す研究が何の審査も受けないとすれば（将来これが実現する可能性は十分あります）、AIシステムが人間の制御できる範囲を超えていないことを保証する方法についての綿密な研究が、なおさら重要になります。
# 研究を規制したり制御を加えたりするのは不可能である。一部の人々は、研究の進化は止められず規制もできないため、否定的な事態の発生を回避する方法はないと主張しています。1975年に開催された、DNA組み換えに関するアシロマ会議では、組み換えによって新しいヒト遺伝子を作る研究について、自主的な一時停止期間を課すという決議に至りました。以来、この一時停止期間は現在に至るまで継続しており、国際的な規範となっています。さらに、仮に人間と同等の知能を持つAIを作り出す研究が何の審査も受けないとすれば（将来これが実現する可能性は十分あります）、AIシステムが人間の制御できる範囲を超えていないことを保証する方法についての綿密な研究が、なおさら重要になります。
# 私に何かできることは?<__EOS__> もしあなたがAIの研究者、経済学者、倫理学者、政治学者、未来学者、AIが抱える問題に関心のある弁護士であれば、2015年にプエルトリコで開催された、AIに関する国際会議で提起された研究計画は、新しいアイデアやさらに提起したい問題をかき立てるものだったことでしょう。また今後、大規模なAI関連の国際会議やAAAIの春季・秋季シンポジウムなどと連携したワークショップが開催される可能性も大いにあります。詳しくは、オックスフォード大学の”人類の未来研究所”（FHI）、ケンブリッジ大学絶滅リスク研究センター（CSER）、カリフォルニア大学バークレー校のCenter for Human-Compatible AI、FLI、非営利団体Machine Intelligence Research Institute（MIRI）などのWebサイトを参照してください。 一般的な誤解 人間には手の打ちようがない。ここまで挙げてきたことは実現するだろうし、将来を変えるために人間が実行できる対策はない。 真実を超えるものは存在しません。将来は 予測する ものではなく、私たちが作り出すもの、つまり人類という集団による意思決定です。
# もしあなたがAIの研究者、経済学者、倫理学者、政治学者、未来学者、AIが抱える問題に関心のある弁護士であれば、2015年にプエルトリコで開催された、AIに関する国際会議で提起された研究計画は、新しいアイデアやさらに提起したい問題をかき立てるものだったことでしょう。また今後、大規模なAI関連の国際会議やAAAIの春季・秋季シンポジウムなどと連携したワークショップが開催される可能性も大いにあります。詳しくは、オックスフォード大学の”人類の未来研究所”（FHI）、ケンブリッジ大学絶滅リスク研究センター（CSER）、カリフォルニア大学バークレー校のCenter for Human-Compatible AI、FLI、非営利団体Machine Intelligence Research Institute（MIRI）などのWebサイトを参照してください。
# 一般的な誤解 人間には手の打ちようがない。ここまで挙げてきたことは実現するだろうし、将来を変えるために人間が実行できる対策はない。 真実を超えるものは存在しません。将来は 予測する ものではなく、私たちが作り出すもの、つまり人類という集団による意思決定です。
# 人間には手の打ちようがない。ここまで挙げてきたことは実現するだろうし、将来を変えるために人間が実行できる対策はない。 真実を超えるものは存在しません。将来は 予測する ものではなく、私たちが作り出すもの、つまり人類という集団による意思決定です。

# %% [markdown]
# ### 構文解析 係り受け解析

# %%
cabocha = CaboCha.Parser('-n1')
# 「。」「！」「__EOS__」を文の末尾みなすための正規表現オブジェクトの作成
ptn_sentence = re.compile(r'(^|。|！|<__EOS__>)\s*(.+?)(?=(。|！|<__EOS__>))', re.M)

# 文章の分割を行う
def split_into_sentences(text):
    sentences = []
    for m in ptn_sentence.finditer(text):
        sentences.append((m.group(2), m.start(2)))
    return sentences

def parse_sentence(sentence_str, sentence_begin, chunks, tokens):
    # 係り受けきの取得
    tree = cabocha.parse(sentence_str)

    offset = sentence_begin
    chunk_id_offset = len(chunks)
    text = sentence_str
    
    # chunkサイズごとにループ
    for i in range(tree.chunk_size()):
        chunk = tree.chunk(i)
        chunk_begin = None
        # tokenごとにループ
        for j in range(chunk.token_pos, chunk.token_pos + chunk.token_size):
            token = tree.token(j)
            features = token.feature.split(',')
            token_begin = text.find(token.surface) + offset
            token_end = token_begin + len(token.surface)
            if chunk_begin is None:
                chunk_begin = token_begin

            tokens.append({
                'begin': token_begin,
                'end':   token_end,
                'lemma': features[-3], # 単語の原型
                'POS':   features[0], # 単語の品詞
                'POS2':  features[1], # 品詞の詳細
                'NE':    token.ne, # 固有表現か（0は固有表現ではない）
            })

            text = text[token_end-offset:]
            offset = token_end

        chunk_end = token_end
        if chunk.link == -1:
            link = -1
        else:
            # チャンクのIDを手前に出現したチャンス数だけずらす
            link = chunk.link + chunk_id_offset
        chunks.append({
            'begin':    chunk_begin,
            'end':      chunk_end,
            'link':     ('chunk', link),
        })

def parse(text):
    sentences = []
    chunks = []
    tokens = []
    sentence_begin = 0
    
    for sentence_str, sentence_begin in split_into_sentences(text):
        parse_sentence(sentence_str, sentence_begin, chunks, tokens)
        sentence_end = chunks[-1]['end']

        sentences.append({
            'begin':    sentence_begin,
            'end':      sentence_end,
        })

    return sentences, chunks, tokens

# %% [markdown]
# ### sentense, chunk, tokenの登録を行う

# %%
columns = ['id', 'content']
try:
    all_data = mysql_class.find_all(['id', 'content'])
    for data in all_data:
        sentence, chunks, tokens = parse(data[columns.index('content')])
        mysql_class.set_article_by_id('sentence', data[columns.index('id')], sentence)
        mysql_class.set_article_by_id('chunk', data[columns.index('id')], chunks)
        mysql_class.set_article_by_id('token', data[columns.index('id')], tokens)
except:
    import traceback
    traceback.print_exc()
    mysql_class.disconnect()

# %% [markdown]
# ### sentense, chunk, tokenの参照

# %%
for id_row in mysql_class.find_ids(limit=1):
        columns = ['content', 'token', 'chunk', 'sentence']
        row = mysql_class.find_article_by_id(columns, id_row[0])
        content = row[columns.index('content')]
        tokens = json.loads(row[columns.index('token')])
        chunks = json.loads(row[columns.index('chunk')])
        sentences = json.loads(row[columns.index('sentence')])

        print('tokens:')
        for token in tokens:
            print('  ', token['POS'], '\t', content[token['begin']:token['end']])

        print('chunks:')
        for chunk in chunks:
            _, link = chunk['link']
            print('  ', content[chunk['begin']:chunk['end']])
            if link != -1:
                parent = chunks[link]
                print('\t-->', content[parent['begin']:parent['end']])
            else:
                print('\t-->', 'None')

        print('sentences:')
        for sentence in sentences:
            print('  ', content[sentence['begin']:sentence['end']])
# Out:
# tokens:
#    名詞 	 Gutenberg
#    助詞 	 と
#    名詞 	 WordPress
#    助詞 	 に関する
#    名詞 	 騒動
#    助詞 	 は
#    記号 	 、
#    名詞 	 PHP
#    助詞 	 の
#    名詞 	 終焉
#    助詞 	 に
#    動詞 	 つながる
#    名詞 	 最新
#    名詞 	 記事
#    助動詞 	 です
#    名詞 	 深呼吸
#    助詞 	 を
#    動詞 	 し
#    助詞 	 て
#    動詞 	 ください
#    記号 	 、
#    名詞 	 みなさん
#    名詞 	 トロール
#    助詞 	 は
#    名詞 	 無視
#    動詞 	 し
#    記号 	 、
#    名詞 	 Mark
#    名詞 	 Twain
#    助詞 	 と
#    名詞 	 Fidel
#    名詞 	 Castro
#    助詞 	 と
#    名詞 	 PHP
#    助詞 	 と
#    助詞 	 の
#    名詞 	 共通
#    名詞 	 点
#    助詞 	 を
#    動詞 	 見
#    助詞 	 て
#    動詞 	 いき
#    助動詞 	 ましょ
#    助動詞 	 う
#    接続詞 	 そして
#    記号 	 、
#    副詞 	 もっと
#    名詞 	 重要
#    助動詞 	 な
#    名詞 	 の
#    助詞 	 は
#    記号 	 、
#    名詞 	 スタート
#    名詞 	 アップ
#    助詞 	 や
#    名詞 	 スモール
#    名詞 	 ビジネス
#    助詞 	 にとって
#    記号 	 、
#    名詞 	 PHP
#    助詞 	 が
#    名詞 	 今
#    助詞 	 でも
#    名詞 	 合理
#    名詞 	 的
#    助動詞 	 な
#    名詞 	 選択
#    助動詞 	 で
#    助動詞 	 ある
#    名詞 	 理由
#    助動詞 	 です
#    名詞 	 PHP
#    助詞 	 は
#    動詞 	 い
#    助動詞 	 つ
#    助詞 	 から
#    動詞 	 廃れ
#    動詞 	 始め
#    助動詞 	 た
#    名詞 	 の
#    助詞 	 か
#    記号 	 “
#    名詞 	 PHP
#    助詞 	 は
#    副詞 	 もう
#    名詞 	 ダメ
#    助動詞 	 だ
#    記号 	 ”
#    助詞 	 といった
#    名詞 	 ブログ
#    助詞 	 の
#    名詞 	 投稿
#    助詞 	 が
#    記号 	 、
#    名詞 	 登場
#    動詞 	 し
#    動詞 	 始め
#    助動詞 	 た
#    名詞 	 の
#    助詞 	 は
#    名詞 	 2011
#    名詞 	 年
#    助詞 	 の
#    名詞 	 よう
#    助動詞 	 です
#    記号 	 （
#    名詞 	 これ
#    助詞 	 より
#    形容詞 	 古い
#    名詞 	 もの
#    助詞 	 を
#    動詞 	 見つけ
#    助動詞 	 たら
#    記号 	 、
#    名詞 	 お知らせ
#    動詞 	 ください
#    記号 	 ）
#    名詞 	 Medium
#    助詞 	 や
#    記号 	 、
#    名詞 	 mushrooms
#    助詞 	 の
#    名詞 	 よう
#    助詞 	 に
#    副詞 	 突然
#    名詞 	 出現
#    動詞 	 し
#    助動詞 	 た
#    名詞 	 coding
#    名詞 	 bootcamps
#    助詞 	 を
#    動詞 	 探し回れ
#    助詞 	 ば
#    記号 	 、
#    連体詞 	 その
#    名詞 	 唯一
#    助詞 	 の
#    名詞 	 共通
#    名詞 	 点
#    助詞 	 は
#    記号 	 、
#    名詞 	 みんな
#    助詞 	 が
#    名詞 	 PHP
#    助詞 	 を
#    動詞 	 嫌っ
#    助詞 	 て
#    動詞 	 いる
#    助詞 	 か
#    記号 	 、
#    接続詞 	 あるいは
#    副詞 	 単に
#    名詞 	 無視
#    動詞 	 し
#    助詞 	 て
#    動詞 	 いる
#    助詞 	 か
#    助動詞 	 です
#    副詞 	 どうやら
#    記号 	 、
#    名詞 	 法外
#    助動詞 	 な
#    名詞 	 値段
#    助詞 	 の
#    名詞 	 コーヒー
#    助詞 	 を
#    動詞 	 飲み
#    助詞 	 ながら
#    記号 	 、
#    名詞 	 油
#    名詞 	 まみれ
#    助詞 	 の
#    名詞 	 ヒゲ
#    助詞 	 と
#    名詞 	 皮肉
#    名詞 	 たっぷり
#    助詞 	 の
#    名詞 	 Tシャツ
#    助詞 	 と
#    名詞 	 一緒
#    助詞 	 に
#    記号 	 、
#    名詞 	 PHP
#    助詞 	 で
#    名詞 	 コーディング
#    動詞 	 する
#    名詞 	 の
#    助詞 	 は
#    名詞 	 不可能
#    助詞 	 の
#    名詞 	 よう
#    助動詞 	 です
#    名詞 	 ばか
#    助動詞 	 な
#    副詞 	 もう
#    名詞 	 たくさん
#    助動詞 	 です
#    接頭詞 	 反
#    名詞 	 PHP
#    助詞 	 の
#    名詞 	 エコーチェンバー
#    名詞 	 現象
#    助詞 	 の
#    名詞 	 せい
#    助動詞 	 で
#    記号 	 、
#    形容詞 	 疑わしい
#    名詞 	 ビジネス
#    名詞 	 上
#    助詞 	 の
#    名詞 	 決断
#    助詞 	 を
#    動詞 	 下そ
#    助動詞 	 う
#    助詞 	 と
#    動詞 	 し
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 創設
#    名詞 	 者
#    助詞 	 に
#    名詞 	 私
#    助詞 	 は
#    副詞 	 いつも
#    動詞 	 話しかけ
#    助詞 	 て
#    動詞 	 い
#    助動詞 	 ます
#    名詞 	 これ
#    助詞 	 が
#    名詞 	 現実
#    助動詞 	 です
#    名詞 	 2018
#    名詞 	 年
#    名詞 	 現在
#    記号 	 、
#    名詞 	 Web
#    名詞 	 サイト
#    助詞 	 の
#    接頭詞 	 約
#    名詞 	 80
#    名詞 	 パーセント
#    助詞 	 が
#    名詞 	 PHP
#    助詞 	 が
#    名詞 	 使用
#    動詞 	 し
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 PHP
#    助詞 	 は
#    記号 	 、
#    副詞 	 なんだかんだ
#    動詞 	 言っ
#    助詞 	 て
#    助詞 	 も
#    記号 	 、
#    副詞 	 それほど
#    動詞 	 廃れ
#    助詞 	 て
#    動詞 	 い
#    助動詞 	 ない
#    助詞 	 と
#    動詞 	 思い
#    助動詞 	 ます
#    名詞 	 神話
#    名詞 	 PHP
#    助詞 	 は
#    名詞 	 スケーラブル
#    助詞 	 で
#    助詞 	 は
#    形容詞 	 ない
#    副詞 	 まったく
#    連体詞 	 その
#    名詞 	 通り
#    助動詞 	 です
#    名詞 	 Wikipedia
#    助詞 	 は
#    名詞 	 完全
#    助詞 	 に
#    名詞 	 PHP
#    助詞 	 によって
#    動詞 	 動い
#    助詞 	 て
#    動詞 	 おり
#    記号 	 、
#    名詞 	 インターネット
#    助詞 	 で
#    名詞 	 5
#    名詞 	 番目
#    助詞 	 に
#    名詞 	 アクセス
#    名詞 	 件数
#    助詞 	 の
#    形容詞 	 多い
#    名詞 	 サイト
#    助動詞 	 です
#    名詞 	 PHP
#    助詞 	 を
#    動詞 	 使っ
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 Facebook
#    助詞 	 と
#    動詞 	 呼ば
#    動詞 	 れる
#    連体詞 	 この
#    動詞 	 取る
#    助詞 	 に
#    動詞 	 足ら
#    助動詞 	 ない
#    名詞 	 サイト
#    助詞 	 も
#    動詞 	 あり
#    助動詞 	 ます
#    動詞 	 聞い
#    助動詞 	 た
#    名詞 	 こと
#    助詞 	 が
#    動詞 	 あり
#    助動詞 	 ます
#    助詞 	 か
#    名詞 	 ?
#    名詞 	 PHP
#    助詞 	 は
#    形容詞 	 遅い
#    副詞 	 もちろん
#    記号 	 、
#    名詞 	 旧来
#    助詞 	 の
#    名詞 	 PHP
#    助詞 	 は
#    形容詞 	 遅く
#    動詞 	 なる
#    名詞 	 こと
#    助詞 	 が
#    動詞 	 あり
#    助動詞 	 ます
#    名詞 	 私
#    助詞 	 の
#    名詞 	 最初
#    助詞 	 の
#    名詞 	 Apple
#    名詞 	 IIe
#    助詞 	 が
#    形容詞 	 遅かっ
#    助動詞 	 た
#    助詞 	 から
#    記号 	 、
#    名詞 	 OS
#    名詞 	 10
#    助詞 	 は
#    形容詞 	 ひどい
#    名詞 	 OS
#    助動詞 	 だ
#    助詞 	 と
#    動詞 	 聞こえ
#    助詞 	 て
#    動詞 	 くる
#    名詞 	 の
#    助詞 	 と
#    副詞 	 ほぼ
#    連体詞 	 同じ
#    名詞 	 よう
#    助動詞 	 な
#    名詞 	 議論
#    助動詞 	 です
#    名詞 	 PHP
#    名詞 	 7
#    助詞 	 は
#    名詞 	 十分
#    形容詞 	 速い
#    助動詞 	 です
#    副詞 	 実に
#    名詞 	 Python
#    助詞 	 より
#    名詞 	 3
#    名詞 	 倍
#    助詞 	 も
#    形容詞 	 速い
#    助動詞 	 です
#    名詞 	 PHP
#    助詞 	 が
#    動詞 	 輝く
#    名詞 	 プロジェクト
#    名詞 	 私
#    助詞 	 が
#    名詞 	 事業
#    名詞 	 主
#    助詞 	 に
#    名詞 	 Web
#    名詞 	 サイト
#    助詞 	 が
#    名詞 	 必要
#    助動詞 	 だ
#    助詞 	 という
#    名詞 	 話
#    助詞 	 を
#    動詞 	 する
#    名詞 	 とき
#    記号 	 、
#    名詞 	 PHP
#    名詞 	 ベース
#    助詞 	 の
#    名詞 	 CMS
#    記号 	 、
#    接続詞 	 例えば
#    名詞 	 Drupal
#    助詞 	 など
#    助詞 	 を
#    名詞 	 検討
#    動詞 	 する
#    名詞 	 こと
#    助詞 	 を
#    副詞 	 まず
#    名詞 	 提案
#    動詞 	 し
#    助動詞 	 ます
#    名詞 	 PHP
#    助詞 	 で
#    名詞 	 カスタム
#    名詞 	 CMS
#    助詞 	 を
#    名詞 	 構築
#    動詞 	 する
#    名詞 	 際
#    助詞 	 でも
#    記号 	 、
#    接頭詞 	 大
#    名詞 	 部分
#    助詞 	 の
#    名詞 	 スモール
#    名詞 	 ビジネス
#    助詞 	 の
#    名詞 	 予算
#    助詞 	 の
#    名詞 	 範囲
#    名詞 	 内
#    助詞 	 に
#    名詞 	 十分
#    動詞 	 収まり
#    助動詞 	 ます
#    記号 	 ”
#    助詞 	 で
#    助詞 	 も
#    記号 	 、
#    記号 	 「
#    副詞 	 とても
#    名詞 	 高価
#    助動詞 	 で
#    名詞 	 ニッチ
#    助動詞 	 な
#    名詞 	 Technology
#    名詞 	 X
#    記号 	 」
#    助詞 	 は
#    副詞 	 どう
#    助動詞 	 です
#    助詞 	 か
#    記号 	 ”
#    助詞 	 と
#    動詞 	 つぶやく
#    名詞 	 よう
#    助動詞 	 な
#    名詞 	 返事
#    助詞 	 を
#    動詞 	 もらう
#    名詞 	 こと
#    助詞 	 が
#    形容詞 	 多い
#    助動詞 	 です
#    名詞 	 誤解
#    動詞 	 し
#    助動詞 	 ない
#    助詞 	 で
#    動詞 	 ください
#    名詞 	 私
#    助詞 	 は
#    名詞 	 機械
#    名詞 	 学習
#    記号 	 、
#    接頭詞 	 高
#    名詞 	 負荷
#    助詞 	 の
#    名詞 	 システム
#    記号 	 、
#    名詞 	 最先端
#    助詞 	 の
#    名詞 	 Java
#    助詞 	 を
#    動詞 	 使っ
#    助詞 	 て
#    名詞 	 プロジェクト
#    助詞 	 を
#    名詞 	 管理
#    動詞 	 し
#    助詞 	 て
#    動詞 	 き
#    助動詞 	 まし
#    助動詞 	 た
#    名詞 	 私
#    助詞 	 は
#    記号 	 、
#    名詞 	 技術
#    名詞 	 革新
#    名詞 	 反対
#    名詞 	 主義
#    名詞 	 者
#    助詞 	 で
#    助詞 	 は
#    動詞 	 あり
#    助動詞 	 ませ
#    助動詞 	 ん
#    名詞 	 私
#    助詞 	 は
#    名詞 	 実業
#    名詞 	 家
#    助動詞 	 です
#    接続詞 	 そして
#    記号 	 、
#    名詞 	 それ
#    助詞 	 が
#    副詞 	 共に
#    動詞 	 働く
#    名詞 	 企業
#    名詞 	 ごと
#    助詞 	 に
#    名詞 	 完全
#    助詞 	 に
#    名詞 	 適切
#    助動詞 	 な
#    名詞 	 技術
#    助詞 	 を
#    動詞 	 見つける
#    名詞 	 こと
#    助詞 	 に
#    名詞 	 固執
#    動詞 	 し
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 理由
#    助動詞 	 です
#    名詞 	 PHP
#    助詞 	 は
#    名詞 	 コンテンツ
#    名詞 	 主導
#    名詞 	 型
#    助詞 	 の
#    名詞 	 Web
#    名詞 	 サイト
#    助詞 	 を
#    名詞 	 構成
#    動詞 	 する
#    名詞 	 の
#    助詞 	 に
#    動詞 	 優れ
#    助詞 	 て
#    動詞 	 い
#    助動詞 	 ます
#    名詞 	 私
#    助詞 	 が
#    副詞 	 共に
#    動詞 	 働く
#    名詞 	 ビジネス
#    助詞 	 の
#    副詞 	 ほとんど
#    助詞 	 は
#    記号 	 、
#    名詞 	 アップデート
#    助詞 	 や
#    名詞 	 コピー
#    助詞 	 の
#    名詞 	 変更
#    記号 	 、
#    名詞 	 ブログ
#    名詞 	 投稿
#    助詞 	 の
#    名詞 	 追加
#    記号 	 、
#    名詞 	 テンプレート
#    助詞 	 で
#    助詞 	 の
#    名詞 	 運用
#    助詞 	 が
#    名詞 	 容易
#    助動詞 	 な
#    名詞 	 サイト
#    助詞 	 が
#    名詞 	 必要
#    助動詞 	 です
#    接続詞 	 また
#    記号 	 、
#    連体詞 	 こうした
#    連体詞 	 あらゆる
#    名詞 	 もの
#    助詞 	 が
#    記号 	 、
#    名詞 	 専門
#    名詞 	 技能
#    助詞 	 を
#    動詞 	 持た
#    助動詞 	 ない
#    名詞 	 職員
#    助詞 	 が
#    名詞 	 状況
#    助詞 	 を
#    動詞 	 壊す
#    名詞 	 こと
#    形容詞 	 なく
#    名詞 	 実行
#    動詞 	 できる
#    助詞 	 ほど
#    名詞 	 簡単
#    助動詞 	 な
#    名詞 	 の
#    助動詞 	 です
#    連体詞 	 同じ
#    名詞 	 こと
#    助詞 	 が
#    名詞 	 電子
#    名詞 	 商
#    名詞 	 取引
#    助詞 	 に
#    助詞 	 も
#    動詞 	 当てはまり
#    助動詞 	 ます
#    名詞 	 コーディング
#    助詞 	 より
#    助詞 	 も
#    名詞 	 販売
#    助詞 	 に
#    名詞 	 集中
#    動詞 	 する
#    名詞 	 必要
#    助詞 	 が
#    動詞 	 ある
#    名詞 	 事業
#    名詞 	 主
#    助詞 	 は
#    記号 	 、
#    動詞 	 買っ
#    助詞 	 て
#    動詞 	 き
#    助詞 	 て
#    副詞 	 そのまま
#    動詞 	 使う
#    名詞 	 こと
#    助詞 	 が
#    動詞 	 できる
#    名詞 	 Magento
#    助詞 	 の
#    名詞 	 よう
#    助動詞 	 な
#    名詞 	 プラットフォーム
#    助詞 	 を
#    名詞 	 使用
#    動詞 	 し
#    助動詞 	 ます
#    名詞 	 心配
#    動詞 	 し
#    助動詞 	 ない
#    助詞 	 で
#    動詞 	 ください
#    名詞 	 バックグラウンド
#    助詞 	 で
#    名詞 	 PHP
#    助詞 	 が
#    動詞 	 動い
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 電子
#    名詞 	 商
#    名詞 	 取引
#    助詞 	 の
#    名詞 	 サイト
#    助詞 	 から
#    記号 	 、
#    名詞 	 ヒゲ
#    助詞 	 の
#    名詞 	 油
#    助詞 	 を
#    副詞 	 まだ
#    動詞 	 売る
#    名詞 	 こと
#    助詞 	 が
#    動詞 	 でき
#    助動詞 	 ます
#    名詞 	 秘密
#    助詞 	 に
#    動詞 	 し
#    助詞 	 て
#    動詞 	 おき
#    助動詞 	 ます
#    名詞 	 そこ
#    助詞 	 で
#    動詞 	 立ち止まる
#    名詞 	 必要
#    助詞 	 は
#    動詞 	 あり
#    助動詞 	 ませ
#    助動詞 	 ん
#    名詞 	 Symfony
#    助詞 	 の
#    名詞 	 よう
#    助動詞 	 な
#    名詞 	 高度
#    助動詞 	 な
#    名詞 	 フレーム
#    名詞 	 ワーク
#    助詞 	 は
#    名詞 	 広範囲
#    助詞 	 の
#    名詞 	 アプリケーション
#    助詞 	 の
#    名詞 	 複雑
#    助動詞 	 な
#    名詞 	 ビジネス
#    名詞 	 ロジック
#    助詞 	 に
#    名詞 	 対処
#    動詞 	 でき
#    助動詞 	 ます
#    名詞 	 React
#    助詞 	 や
#    名詞 	 Vue
#    記号 	 、
#    名詞 	 Abgular
#    助詞 	 の
#    名詞 	 よう
#    助動詞 	 な
#    名詞 	 最新
#    助詞 	 の
#    名詞 	 フロント
#    名詞 	 エンド
#    助詞 	 の
#    名詞 	 フレーム
#    名詞 	 ワーク
#    助詞 	 と
#    形容詞 	 うまく
#    名詞 	 適合
#    動詞 	 する
#    名詞 	 API
#    助詞 	 を
#    名詞 	 構築
#    動詞 	 する
#    助詞 	 のに
#    名詞 	 PHP
#    助詞 	 は
#    動詞 	 優れ
#    助動詞 	 た
#    名詞 	 言語
#    助動詞 	 です
#    名詞 	 PHP
#    助詞 	 の
#    名詞 	 ビジネス
#    名詞 	 感覚
#    名詞 	 PHP
#    助詞 	 が
#    名詞 	 Web
#    名詞 	 サイト
#    助詞 	 の
#    名詞 	 80
#    名詞 	 パーセント
#    助詞 	 で
#    名詞 	 使用
#    動詞 	 さ
#    動詞 	 れ
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 話
#    助詞 	 に
#    動詞 	 戻り
#    助動詞 	 ます
#    名詞 	 経済
#    名詞 	 力
#    助詞 	 に
#    動詞 	 つなげ
#    助詞 	 て
#    動詞 	 ください
#    接続詞 	 つまり
#    記号 	 、
#    名詞 	 PHP
#    助詞 	 の
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 は
#    名詞 	 山
#    助詞 	 ほど
#    名詞 	 存在
#    動詞 	 し
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 の
#    助動詞 	 です
#    助詞 	 から
#    名詞 	 あなた
#    助詞 	 にとって
#    助詞 	 の
#    名詞 	 利点
#    助詞 	 は
#    名詞 	 以下
#    助詞 	 の
#    名詞 	 よう
#    助動詞 	 な
#    名詞 	 もの
#    助動詞 	 です
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 を
#    動詞 	 雇う
#    名詞 	 の
#    助詞 	 は
#    記号 	 、
#    副詞 	 極めて
#    名詞 	 簡単
#    助動詞 	 です
#    名詞 	 不明瞭
#    助動詞 	 な
#    名詞 	 フレーム
#    名詞 	 ワーク
#    助詞 	 で
#    動詞 	 間に合わ
#    動詞 	 せる
#    名詞 	 こと
#    助詞 	 を
#    動詞 	 決め
#    助動詞 	 た
#    名詞 	 プロジェクト
#    助詞 	 に対して
#    記号 	 、
#    形容詞 	 新しい
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 が
#    動詞 	 見つかる
#    名詞 	 こと
#    助詞 	 を
#    名詞 	 お祈り
#    動詞 	 致し
#    助動詞 	 ます
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 を
#    動詞 	 雇う
#    名詞 	 の
#    助詞 	 は
#    記号 	 、
#    副詞 	 極めて
#    名詞 	 簡単
#    助動詞 	 です
#    名詞 	 不明瞭
#    助動詞 	 な
#    名詞 	 フレーム
#    名詞 	 ワーク
#    助詞 	 で
#    動詞 	 間に合わ
#    動詞 	 せる
#    名詞 	 こと
#    助詞 	 を
#    動詞 	 決め
#    助動詞 	 た
#    名詞 	 プロジェクト
#    助詞 	 に対して
#    記号 	 、
#    形容詞 	 新しい
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 が
#    動詞 	 見つかる
#    名詞 	 こと
#    助詞 	 を
#    名詞 	 お祈り
#    動詞 	 致し
#    助動詞 	 ます
#    名詞 	 開発
#    助詞 	 の
#    名詞 	 コスト
#    助詞 	 は
#    動詞 	 抑え
#    動詞 	 られ
#    助動詞 	 ます
#    接続詞 	 というのも
#    記号 	 、
#    名詞 	 採用
#    名詞 	 市場
#    助詞 	 に
#    動詞 	 出
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 の
#    名詞 	 能力
#    助詞 	 は
#    形容詞 	 高く
#    記号 	 、
#    接続詞 	 また
#    名詞 	 一
#    助詞 	 から
#    動詞 	 作り直す
#    名詞 	 必要
#    助詞 	 は
#    動詞 	 あり
#    助動詞 	 ませ
#    助動詞 	 ん
#    名詞 	 利用
#    動詞 	 できる
#    名詞 	 オープン
#    名詞 	 ソース
#    助詞 	 の
#    名詞 	 プロジェクト
#    助詞 	 は
#    名詞 	 たくさん
#    名詞 	 存在
#    動詞 	 し
#    助詞 	 て
#    動詞 	 い
#    助動詞 	 ます
#    名詞 	 開発
#    助詞 	 の
#    名詞 	 コスト
#    助詞 	 は
#    動詞 	 抑え
#    動詞 	 られ
#    助動詞 	 ます
#    接続詞 	 というのも
#    記号 	 、
#    名詞 	 採用
#    名詞 	 市場
#    助詞 	 に
#    動詞 	 出
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 の
#    名詞 	 能力
#    助詞 	 は
#    形容詞 	 高く
#    記号 	 、
#    接続詞 	 また
#    名詞 	 一
#    助詞 	 から
#    動詞 	 作り直す
#    名詞 	 必要
#    助詞 	 は
#    動詞 	 あり
#    助動詞 	 ませ
#    助動詞 	 ん
#    名詞 	 利用
#    動詞 	 できる
#    名詞 	 オープン
#    名詞 	 ソース
#    助詞 	 の
#    名詞 	 プロジェクト
#    助詞 	 は
#    名詞 	 たくさん
#    名詞 	 存在
#    動詞 	 し
#    助詞 	 て
#    動詞 	 い
#    助動詞 	 ます
#    連体詞 	 どんな
#    名詞 	 理由
#    助動詞 	 で
#    助動詞 	 あれ
#    記号 	 、
#    名詞 	 ビジネス
#    助詞 	 における
#    名詞 	 基本
#    名詞 	 的
#    助動詞 	 な
#    名詞 	 洞察
#    名詞 	 力
#    助詞 	 は
#    記号 	 、
#    名詞 	 スタート
#    名詞 	 アップ
#    助詞 	 の
#    名詞 	 現場
#    助詞 	 で
#    助詞 	 は
#    動詞 	 欠け
#    助詞 	 て
#    動詞 	 い
#    助動詞 	 ます
#    接続詞 	 次に
#    記号 	 、
#    名詞 	 誰か
#    助詞 	 が
#    名詞 	 ブロック
#    名詞 	 チェーン
#    助詞 	 や
#    名詞 	 機械
#    名詞 	 学習
#    助詞 	 について
#    助詞 	 の
#    名詞 	 失言
#    助詞 	 で
#    記号 	 、
#    名詞 	 簡単
#    助動詞 	 な
#    名詞 	 Web
#    助詞 	 の
#    名詞 	 アプリ
#    助詞 	 について
#    名詞 	 説明
#    動詞 	 し
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 の
#    助詞 	 を
#    動詞 	 聞い
#    助動詞 	 たら
#    記号 	 、
#    接続詞 	 ただ
#    動詞 	 うなづき
#    記号 	 、
#    形容詞 	 涼しい
#    名詞 	 顔
#    助詞 	 で
#    名詞 	 Laravel
#    助詞 	 や
#    名詞 	 Symfony
#    助詞 	 が
#    副詞 	 ほぼ
#    名詞 	 間違い
#    助動詞 	 なく
#    記号 	 、
#    副詞 	 ちゃんと
#    形容詞 	 うまく
#    動詞 	 動い
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 理由
#    助詞 	 を
#    名詞 	 説明
#    動詞 	 し
#    助動詞 	 ましょ
#    助動詞 	 う
#    副詞 	 要するに
#    記号 	 、
#    名詞 	 自分
#    助詞 	 の
#    名詞 	 マーケティング
#    名詞 	 部門
#    助詞 	 の
#    名詞 	 誇大
#    名詞 	 広告
#    助詞 	 を
#    名詞 	 信用
#    動詞 	 し
#    助詞 	 て
#    助詞 	 は
#    動詞 	 いけ
#    助動詞 	 ませ
#    助動詞 	 ん
#    名詞 	 ブートストラップ
#    助動詞 	 な
#    名詞 	 スタート
#    名詞 	 アップ
#    助詞 	 にとって
#    助詞 	 は
#    副詞 	 いくら
#    名詞 	 強調
#    動詞 	 し
#    助詞 	 て
#    助詞 	 も
#    動詞 	 し
#    助詞 	 たり
#    助動詞 	 ませ
#    助動詞 	 ん
#    名詞 	 PHP
#    助詞 	 の
#    名詞 	 エコ
#    名詞 	 システム
#    助詞 	 で
#    名詞 	 ソリューション
#    助詞 	 を
#    動詞 	 見つけ
#    助詞 	 て
#    動詞 	 ください
#    副詞 	 大抵
#    記号 	 、
#    名詞 	 PHP
#    助詞 	 で
#    動詞 	 進め
#    助詞 	 て
#    動詞 	 いく
#    名詞 	 こと
#    助詞 	 により
#    記号 	 、
#    名詞 	 費用
#    助詞 	 や
#    名詞 	 開発
#    名詞 	 時間
#    助詞 	 の
#    連体詞 	 ほんの
#    副詞 	 わずか
#    助動詞 	 な
#    名詞 	 一部
#    助詞 	 で
#    名詞 	 ビジネス
#    名詞 	 ロジック
#    助詞 	 を
#    名詞 	 実行
#    動詞 	 する
#    名詞 	 こと
#    助詞 	 が
#    動詞 	 でき
#    助動詞 	 ます
#    名詞 	 上級
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 が
#    動詞 	 もたらす
#    名詞 	 視点
#    名詞 	 真
#    助詞 	 の
#    名詞 	 上級
#    名詞 	 エンジニア
#    助詞 	 は
#    名詞 	 インターネット
#    名詞 	 上
#    助詞 	 で
#    助詞 	 の
#    名詞 	 経験
#    助詞 	 が
#    名詞 	 2
#    名詞 	 年
#    助詞 	 の
#    記号 	 ”
#    名詞 	 上級
#    名詞 	 開発
#    名詞 	 者
#    記号 	 ”
#    助詞 	 と
#    名詞 	 話
#    助詞 	 を
#    動詞 	 し
#    助動詞 	 た
#    名詞 	 時
#    助詞 	 に
#    助詞 	 は
#    副詞 	 決して
#    動詞 	 得る
#    名詞 	 こと
#    助詞 	 の
#    形容詞 	 ない
#    記号 	 、
#    名詞 	 堅実
#    助動詞 	 で
#    名詞 	 広範
#    助動詞 	 な
#    名詞 	 視点
#    助詞 	 を
#    動詞 	 もたらし
#    助詞 	 て
#    動詞 	 くれ
#    助動詞 	 ます
#    名詞 	 PHP
#    助詞 	 の
#    名詞 	 よう
#    助動詞 	 な
#    名詞 	 実証
#    名詞 	 済み
#    助詞 	 の
#    名詞 	 テクノロジ
#    助詞 	 を
#    名詞 	 使用
#    動詞 	 する
#    名詞 	 場合
#    記号 	 、
#    名詞 	 10
#    名詞 	 年
#    助詞 	 の
#    名詞 	 経験
#    助詞 	 を
#    動詞 	 積ん
#    助動詞 	 だ
#    名詞 	 エキスパート
#    助詞 	 を
#    動詞 	 見つける
#    名詞 	 こと
#    助詞 	 は
#    副詞 	 とても
#    名詞 	 簡単
#    助動詞 	 です
#    名詞 	 企業
#    名詞 	 家
#    助詞 	 にとって
#    記号 	 、
#    名詞 	 経験
#    名詞 	 豊か
#    助動詞 	 な
#    名詞 	 エンジニア
#    助詞 	 と
#    動詞 	 組む
#    名詞 	 こと
#    助詞 	 は
#    名詞 	 コスト
#    助詞 	 の
#    名詞 	 削減
#    助詞 	 に
#    動詞 	 なり
#    助動詞 	 ます
#    名詞 	 若手
#    助詞 	 の
#    名詞 	 チーム
#    助詞 	 を
#    動詞 	 雇っ
#    助詞 	 て
#    名詞 	 お金
#    助詞 	 を
#    記号 	 ”
#    名詞 	 倹約
#    記号 	 ”
#    動詞 	 しよ
#    助動詞 	 う
#    助詞 	 と
#    動詞 	 する
#    助詞 	 より
#    助詞 	 も
#    副詞 	 むしろ
#    記号 	 、
#    名詞 	 MVP
#    助詞 	 を
#    副詞 	 より
#    名詞 	 高速
#    助詞 	 に
#    動詞 	 し
#    記号 	 、
#    名詞 	 初め
#    助詞 	 から
#    形容詞 	 高い
#    名詞 	 品質
#    助詞 	 で
#    名詞 	 構築
#    動詞 	 し
#    助詞 	 て
#    動詞 	 ください
#    名詞 	 PHP
#    助詞 	 と
#    名詞 	 Symfony
#    助詞 	 や
#    名詞 	 Laravel
#    助詞 	 といった
#    名詞 	 フレーム
#    名詞 	 ワーク
#    助詞 	 を
#    動詞 	 用いる
#    名詞 	 場合
#    記号 	 、
#    名詞 	 上級
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 を
#    動詞 	 見つける
#    名詞 	 の
#    助詞 	 が
#    名詞 	 はるか
#    助詞 	 に
#    名詞 	 現実
#    名詞 	 的
#    助動詞 	 です
#    副詞 	 なかなか
#    形容詞 	 しぶとい
#    名詞 	 PHP
#    名詞 	 2019
#    名詞 	 年
#    助詞 	 に
#    助詞 	 は
#    名詞 	 PHP
#    助詞 	 の
#    名詞 	 終焉
#    助詞 	 に関する
#    名詞 	 ブログ
#    助詞 	 の
#    名詞 	 投稿
#    助詞 	 は
#    副詞 	 ついに
#    動詞 	 終わり
#    助詞 	 に
#    動詞 	 なる
#    助動詞 	 だろ
#    助動詞 	 う
#    記号 	 、
#    助詞 	 と
#    副詞 	 いつも
#    名詞 	 期待
#    動詞 	 し
#    助詞 	 て
#    動詞 	 い
#    助動詞 	 ます
#    連体詞 	 その
#    名詞 	 反面
#    記号 	 、
#    名詞 	 他
#    助詞 	 の
#    名詞 	 人
#    助詞 	 が
#    名詞 	 私
#    助詞 	 の
#    名詞 	 秘密
#    助詞 	 を
#    動詞 	 知ら
#    助動詞 	 なけれ
#    助詞 	 ば
#    記号 	 、
#    連体詞 	 その
#    名詞 	 方
#    助詞 	 が
#    形容詞 	 良い
#    助詞 	 かも
#    動詞 	 しれ
#    助動詞 	 ない
#    助詞 	 と
#    助詞 	 も
#    動詞 	 思っ
#    助詞 	 て
#    動詞 	 い
#    助動詞 	 ます
#    名詞 	 PHP
#    助詞 	 や
#    名詞 	 Ruby
#    助詞 	 の
#    名詞 	 よう
#    助動詞 	 な
#    形容詞 	 素晴らしい
#    名詞 	 言語
#    助詞 	 の
#    名詞 	 ため
#    記号 	 、
#    名詞 	 上級
#    名詞 	 開発
#    名詞 	 者
#    助詞 	 を
#    動詞 	 雇っ
#    助詞 	 て
#    名詞 	 166
#    名詞 	 万
#    名詞 	 円
#    名詞 	 以下
#    助詞 	 の
#    名詞 	 MVP
#    助詞 	 を
#    名詞 	 次
#    助詞 	 から
#    名詞 	 次
#    助詞 	 へ
#    助詞 	 と
#    動詞 	 作り出し
#    助詞 	 て
#    動詞 	 い
#    助動詞 	 ます
#    名詞 	 PHP
#    助詞 	 は
#    名詞 	 プログラミング
#    名詞 	 言語
#    助詞 	 の
#    名詞 	 Fidel
#    名詞 	 Castro
#    助動詞 	 です
#    接続詞 	 つまり
#    記号 	 、
#    名詞 	 結局
#    助詞 	 の
#    名詞 	 ところ
#    名詞 	 Castro
#    助詞 	 は
#    名詞 	 彼
#    助詞 	 の
#    名詞 	 暗殺
#    助詞 	 を
#    動詞 	 命じ
#    助動詞 	 た
#    名詞 	 5
#    名詞 	 人
#    助詞 	 の
#    名詞 	 アメリカ
#    名詞 	 大統領
#    助詞 	 より
#    助詞 	 も
#    名詞 	 長生き
#    動詞 	 し
#    助動詞 	 まし
#    助動詞 	 た
#    接続詞 	 そして
#    副詞 	 もちろん
#    記号 	 、
#    名詞 	 Mark
#    名詞 	 Twain
#    助詞 	 の
#    名詞 	 死
#    助詞 	 の
#    名詞 	 報道
#    助詞 	 が
#    副詞 	 実際
#    助詞 	 より
#    名詞 	 誇張
#    動詞 	 さ
#    動詞 	 れ
#    助動詞 	 た
#    名詞 	 よう
#    助詞 	 に
#    記号 	 、
#    名詞 	 Web
#    助詞 	 の
#    名詞 	 80
#    名詞 	 パーセント
#    助詞 	 を
#    動詞 	 動かし
#    助詞 	 て
#    動詞 	 いる
#    名詞 	 言語
#    助詞 	 を
#    動詞 	 終わっ
#    助動詞 	 た
#    助詞 	 と
#    動詞 	 考える
#    名詞 	 の
#    助詞 	 は
#    記号 	 、
#    副詞 	 まるで
#    名詞 	 訳
#    助詞 	 が
#    動詞 	 分から
#    助動詞 	 ない
#    名詞 	 こと
#    助動詞 	 です
#    名詞 	 PHP
#    名詞 	 万
#    名詞 	 歳
#    副詞 	 元々
#    助詞 	 の
#    名詞 	 投稿
#    助詞 	 は
#    名詞 	 eTeam
#    助詞 	 の
#    名詞 	 ブログ
#    助動詞 	 です
# chunks:
#    Gutenbergと
# 	--> WordPressに関する
#    WordPressに関する
# 	--> 騒動は、
#    騒動は、
# 	--> 最新記事です
#    PHPの
# 	--> 終焉に
#    終焉に
# 	--> つながる
#    つながる
# 	--> 最新記事です
#    最新記事です
# 	--> None
#    深呼吸を
# 	--> してください、
#    してください、
# 	--> みなさん
#    みなさん
# 	--> None
#    トロールは
# 	--> 無視し、
#    無視し、
# 	--> 見ていきましょう
#    Mark Twainと
# 	--> Fidel Castroと
#    Fidel Castroと
# 	--> PHPとの
#    PHPとの
# 	--> 共通点を
#    共通点を
# 	--> 見ていきましょう
#    見ていきましょう
# 	--> None
#    そして、
# 	--> 理由です
#    もっと
# 	--> 重要なのは、
#    重要なのは、
# 	--> 理由です
#    スタートアップや
# 	--> スモールビジネスにとって、
#    スモールビジネスにとって、
# 	--> 理由です
#    PHPが
# 	--> 選択である
#    今でも
# 	--> 選択である
#    合理的な
# 	--> 選択である
#    選択である
# 	--> 理由です
#    理由です
# 	--> None
#    PHPは
# 	--> 廃れ始めたのか
#    いつから
# 	--> 廃れ始めたのか
#    廃れ始めたのか
# 	--> None
#    “PHPは
# 	--> 登場し始めたのは
#    もう
# 	--> ダメだ”といった
#    ダメだ”といった
# 	--> ブログの
#    ブログの
# 	--> 投稿が、
#    投稿が、
# 	--> 登場し始めたのは
#    登場し始めたのは
# 	--> お知らせください）
#    2011年のようです
# 	--> ものを
#    （これより
# 	--> 古い
#    古い
# 	--> ものを
#    ものを
# 	--> 見つけたら、
#    見つけたら、
# 	--> お知らせください）
#    お知らせください）
# 	--> None
#    Mediumや、
# 	--> mushroomsのように
#    mushroomsのように
# 	--> 出現した
#    突然
# 	--> 出現した
#    出現した
# 	--> coding bootcampsを
#    coding bootcampsを
# 	--> 探し回れば、
#    探し回れば、
# 	--> 無視しているかです
#    その
# 	--> 唯一の
#    唯一の
# 	--> 共通点は、
#    共通点は、
# 	--> 無視しているかです
#    みんなが
# 	--> 嫌っているか、あるいは
#    PHPを
# 	--> 嫌っているか、あるいは
#    嫌っているか、あるいは
# 	--> 無視しているかです
#    単に
# 	--> 無視しているかです
#    無視しているかです
# 	--> None
#    どうやら、
# 	--> 不可能のようです
#    法外な
# 	--> 値段の
#    値段の
# 	--> コーヒーを
#    コーヒーを
# 	--> 飲みながら、
#    飲みながら、
# 	--> コーディングするのは
#    油まみれの
# 	--> ヒゲと
#    ヒゲと
# 	--> Tシャツと
#    皮肉たっぷりの
# 	--> Tシャツと
#    Tシャツと
# 	--> 一緒に、
#    一緒に、
# 	--> コーディングするのは
#    PHPで
# 	--> コーディングするのは
#    コーディングするのは
# 	--> 不可能のようです
#    不可能のようです
# 	--> None
#    ばかな
# 	--> None
#    もう
# 	--> たくさんです
#    たくさんです
# 	--> None
#    反PHPの
# 	--> エコーチェンバー現象の
#    エコーチェンバー現象の
# 	--> せいで、
#    せいで、
# 	--> 話しかけています
#    疑わしい
# 	--> ビジネス上の
#    ビジネス上の
# 	--> 決断を
#    決断を
# 	--> 下そうとしている
#    下そうとしている
# 	--> 創設者に
#    創設者に
# 	--> 話しかけています
#    私は
# 	--> 話しかけています
#    いつも
# 	--> 話しかけています
#    話しかけています
# 	--> None
#    これが
# 	--> 現実です
#    現実です
# 	--> None
#    2018年現在、
# 	--> 使用している
#    Webサイトの
# 	--> 約80パーセントが
#    約80パーセントが
# 	--> 使用している
#    PHPが
# 	--> 使用している
#    使用している
# 	--> None
#    PHPは、
# 	--> 廃れていないと
#    なんだかんだ
# 	--> 言っても、
#    言っても、
# 	--> 廃れていないと
#    それほど
# 	--> 廃れていないと
#    廃れていないと
# 	--> 思います
#    思います
# 	--> None
#    神話
# 	--> None
#    PHPは
# 	--> スケーラブルではない
#    スケーラブルではない
# 	--> None
#    まったく
# 	--> その通りです
#    その通りです
# 	--> None
#    Wikipediaは
# 	--> 動いており、
#    完全に
# 	--> 動いており、
#    PHPによって
# 	--> 動いており、
#    動いており、
# 	--> サイトです
#    インターネットで
# 	--> 多い
#    5番目に
# 	--> 多い
#    アクセス件数の
# 	--> 多い
#    多い
# 	--> サイトです
#    サイトです
# 	--> None
#    PHPを
# 	--> 使っている
#    使っている
# 	--> Facebookと
#    Facebookと
# 	--> 呼ばれる
#    呼ばれる
# 	--> 取るに
#    この
# 	--> 取るに
#    取るに
# 	--> 足らない
#    足らない
# 	--> サイトも
#    サイトも
# 	--> あります
#    あります
# 	--> None
#    聞いた
# 	--> ことが
#    ことが
# 	--> ありますか?
#    ありますか?
# 	--> None
#    PHPは
# 	--> 遅い
#    遅い
# 	--> None
#    もちろん、
# 	--> あります
#    旧来の
# 	--> PHPは
#    PHPは
# 	--> 遅くなる
#    遅くなる
# 	--> ことが
#    ことが
# 	--> あります
#    あります
# 	--> None
#    私の
# 	--> 最初の
#    最初の
# 	--> Apple IIeが
#    Apple IIeが
# 	--> 遅かったから、
#    遅かったから、
# 	--> 聞こえてくるのと
#    OS 10は
# 	--> OSだと
#    ひどい
# 	--> OSだと
#    OSだと
# 	--> 聞こえてくるのと
#    聞こえてくるのと
# 	--> 同じような
#    ほぼ
# 	--> 同じような
#    同じような
# 	--> 議論です
#    議論です
# 	--> None
#    PHP7は
# 	--> 速いです
#    十分
# 	--> 速いです
#    速いです
# 	--> None
#    実に
# 	--> 速いです
#    Pythonより
# 	--> 速いです
#    3倍も
# 	--> 速いです
#    速いです
# 	--> None
#    PHPが
# 	--> 輝く
#    輝く
# 	--> プロジェクト
#    プロジェクト
# 	--> None
#    私が
# 	--> 必要だという
#    事業主に
# 	--> 必要だという
#    Webサイトが
# 	--> 必要だという
#    必要だという
# 	--> 話を
#    話を
# 	--> する
#    する
# 	--> とき、
#    とき、
# 	--> 提案します
#    PHPベースの
# 	--> 検討する
#    CMS、
# 	--> 検討する
#    例えば
# 	--> 検討する
#    Drupalなどを
# 	--> 検討する
#    検討する
# 	--> ことを
#    ことを
# 	--> 提案します
#    まず
# 	--> 提案します
#    提案します
# 	--> None
#    PHPで
# 	--> 構築する
#    カスタムCMSを
# 	--> 構築する
#    構築する
# 	--> 際でも、
#    際でも、
# 	--> 収まります
#    大部分の
# 	--> スモールビジネスの
#    スモールビジネスの
# 	--> 予算の
#    予算の
# 	--> 範囲内に
#    範囲内に
# 	--> 収まります
#    十分
# 	--> 収まります
#    収まります
# 	--> None
#    ”でも、
# 	--> 多いです
#    「とても
# 	--> 高価で
#    高価で
# 	--> ニッチな
#    ニッチな
# 	--> Technology X」は
#    Technology X」は
# 	--> どうですか”と
#    どうですか”と
# 	--> つぶやくような
#    つぶやくような
# 	--> 返事を
#    返事を
# 	--> もらう
#    もらう
# 	--> ことが
#    ことが
# 	--> 多いです
#    多いです
# 	--> None
#    誤解しないでください
# 	--> None
#    私は
# 	--> 管理してきました
#    機械学習、
# 	--> 高負荷の
#    高負荷の
# 	--> システム、
#    システム、
# 	--> Javaを
#    最先端の
# 	--> Javaを
#    Javaを
# 	--> 使って
#    使って
# 	--> 管理してきました
#    プロジェクトを
# 	--> 管理してきました
#    管理してきました
# 	--> None
#    私は、
# 	--> 技術革新反対主義者ではありません
#    技術革新反対主義者ではありません
# 	--> None
#    私は
# 	--> 実業家です
#    実業家です
# 	--> None
#    そして、
# 	--> 理由です
#    それが
# 	--> 見つける
#    共に
# 	--> 働く
#    働く
# 	--> 企業ごとに
#    企業ごとに
# 	--> 見つける
#    完全に
# 	--> 見つける
#    適切な
# 	--> 技術を
#    技術を
# 	--> 見つける
#    見つける
# 	--> ことに
#    ことに
# 	--> 固執している
#    固執している
# 	--> 理由です
#    理由です
# 	--> None
#    PHPは
# 	--> 優れています
#    コンテンツ主導型の
# 	--> Webサイトを
#    Webサイトを
# 	--> 構成するのに
#    構成するのに
# 	--> 優れています
#    優れています
# 	--> None
#    私が
# 	--> 働く
#    共に
# 	--> 働く
#    働く
# 	--> ビジネスの
#    ビジネスの
# 	--> ほとんどは、
#    ほとんどは、
# 	--> 必要です
#    アップデートや
# 	--> コピーの
#    コピーの
# 	--> 変更、
#    変更、
# 	--> 追加、
#    ブログ投稿の
# 	--> 追加、
#    追加、
# 	--> 運用が
#    テンプレートでの
# 	--> 運用が
#    運用が
# 	--> 必要です
#    容易な
# 	--> サイトが
#    サイトが
# 	--> 必要です
#    必要です
# 	--> None
#    また、
# 	--> 簡単なのです
#    こうした
# 	--> ものが、
#    あらゆる
# 	--> ものが、
#    ものが、
# 	--> 簡単なのです
#    専門技能を
# 	--> 持たない
#    持たない
# 	--> 職員が
#    職員が
# 	--> 壊す
#    状況を
# 	--> 壊す
#    壊す
# 	--> こと
#    こと
# 	--> なく
#    なく
# 	--> 実行できる
#    実行できる
# 	--> ほど
#    ほど
# 	--> 簡単なのです
#    簡単なのです
# 	--> None
#    同じ
# 	--> ことが
#    ことが
# 	--> 当てはまります
#    電子商取引にも
# 	--> 当てはまります
#    当てはまります
# 	--> None
#    コーディングよりも
# 	--> 集中する
#    販売に
# 	--> 集中する
#    集中する
# 	--> 必要が
#    必要が
# 	--> ある
#    ある
# 	--> 事業主は、
#    事業主は、
# 	--> 使用します
#    買ってきて
# 	--> 使う
#    そのまま
# 	--> 使う
#    使う
# 	--> ことが
#    ことが
# 	--> できる
#    できる
# 	--> プラットフォームを
#    Magentoのような
# 	--> プラットフォームを
#    プラットフォームを
# 	--> 使用します
#    使用します
# 	--> None
#    心配しないでください
# 	--> None
#    バックグラウンドで
# 	--> 動いている
#    PHPが
# 	--> 動いている
#    動いている
# 	--> 電子商取引の
#    電子商取引の
# 	--> サイトから、
#    サイトから、
# 	--> 売る
#    ヒゲの
# 	--> 油を
#    油を
# 	--> 売る
#    まだ
# 	--> 売る
#    売る
# 	--> ことが
#    ことが
# 	--> できます
#    できます
# 	--> None
#    秘密に
# 	--> しておきます
#    しておきます
# 	--> None
#    そこで
# 	--> 立ち止まる
#    立ち止まる
# 	--> 必要は
#    必要は
# 	--> ありません
#    ありません
# 	--> None
#    Symfonyのような
# 	--> フレームワークは
#    高度な
# 	--> フレームワークは
#    フレームワークは
# 	--> 対処できます
#    広範囲の
# 	--> アプリケーションの
#    アプリケーションの
# 	--> ビジネスロジックに
#    複雑な
# 	--> ビジネスロジックに
#    ビジネスロジックに
# 	--> 対処できます
#    対処できます
# 	--> None
#    Reactや
# 	--> Vue、
#    Vue、
# 	--> Abgularのような
#    Abgularのような
# 	--> 最新の
#    最新の
# 	--> フロントエンドの
#    フロントエンドの
# 	--> フレームワークと
#    フレームワークと
# 	--> 適合する
#    うまく
# 	--> 適合する
#    適合する
# 	--> APIを
#    APIを
# 	--> 構築するのに
#    構築するのに
# 	--> 言語です
#    PHPは
# 	--> 言語です
#    優れた
# 	--> 言語です
#    言語です
# 	--> None
#    PHPの
# 	--> ビジネス感覚
#    ビジネス感覚
# 	--> None
#    PHPが
# 	--> 使用されている
#    Webサイトの
# 	--> 80パーセントで
#    80パーセントで
# 	--> 使用されている
#    使用されている
# 	--> 話に
#    話に
# 	--> 戻ります
#    戻ります
# 	--> None
#    経済力に
# 	--> つなげてください
#    つなげてください
# 	--> None
#    つまり、
# 	--> 存在しているのですから
#    PHPの
# 	--> 開発者は
#    開発者は
# 	--> 存在しているのですから
#    山ほど
# 	--> 存在しているのですから
#    存在しているのですから
# 	--> None
#    あなたにとっての
# 	--> 利点は
#    利点は
# 	--> ものです
#    以下のような
# 	--> ものです
#    ものです
# 	--> None
#    開発者を
# 	--> 雇うのは、
#    雇うのは、
# 	--> 簡単です
#    極めて
# 	--> 簡単です
#    簡単です
# 	--> None
#    不明瞭な
# 	--> フレームワークで
#    フレームワークで
# 	--> 間に合わせる
#    間に合わせる
# 	--> ことを
#    ことを
# 	--> 決めた
#    決めた
# 	--> プロジェクトに対して、
#    プロジェクトに対して、
# 	--> 見つかる
#    新しい
# 	--> 開発者が
#    開発者が
# 	--> 見つかる
#    見つかる
# 	--> ことを
#    ことを
# 	--> お祈り致します
#    お祈り致します
# 	--> None
#    開発者を
# 	--> 雇うのは、
#    雇うのは、
# 	--> 簡単です
#    極めて
# 	--> 簡単です
#    簡単です
# 	--> None
#    不明瞭な
# 	--> フレームワークで
#    フレームワークで
# 	--> 間に合わせる
#    間に合わせる
# 	--> ことを
#    ことを
# 	--> 決めた
#    決めた
# 	--> プロジェクトに対して、
#    プロジェクトに対して、
# 	--> 見つかる
#    新しい
# 	--> 開発者が
#    開発者が
# 	--> 見つかる
#    見つかる
# 	--> ことを
#    ことを
# 	--> お祈り致します
#    お祈り致します
# 	--> None
#    開発の
# 	--> コストは
#    コストは
# 	--> 抑えられます
#    抑えられます
# 	--> None
#    というのも、
# 	--> ありません
#    採用市場に
# 	--> 出ている
#    出ている
# 	--> 開発者の
#    開発者の
# 	--> 能力は
#    能力は
# 	--> 高く、また
#    高く、また
# 	--> ありません
#    一から
# 	--> 作り直す
#    作り直す
# 	--> 必要は
#    必要は
# 	--> ありません
#    ありません
# 	--> None
#    利用できる
# 	--> オープンソースの
#    オープンソースの
# 	--> プロジェクトは
#    プロジェクトは
# 	--> 存在しています
#    たくさん
# 	--> 存在しています
#    存在しています
# 	--> None
#    開発の
# 	--> コストは
#    コストは
# 	--> 抑えられます
#    抑えられます
# 	--> None
#    というのも、
# 	--> ありません
#    採用市場に
# 	--> 出ている
#    出ている
# 	--> 開発者の
#    開発者の
# 	--> 能力は
#    能力は
# 	--> 高く、また
#    高く、また
# 	--> ありません
#    一から
# 	--> 作り直す
#    作り直す
# 	--> 必要は
#    必要は
# 	--> ありません
#    ありません
# 	--> None
#    利用できる
# 	--> オープンソースの
#    オープンソースの
# 	--> プロジェクトは
#    プロジェクトは
# 	--> 存在しています
#    たくさん
# 	--> 存在しています
#    存在しています
# 	--> None
#    どんな
# 	--> 理由であれ、
#    理由であれ、
# 	--> 欠けています
#    ビジネスにおける
# 	--> 洞察力は、
#    基本的な
# 	--> 洞察力は、
#    洞察力は、
# 	--> 欠けています
#    スタートアップの
# 	--> 現場では
#    現場では
# 	--> 欠けています
#    欠けています
# 	--> None
#    次に、
# 	--> 説明しましょう
#    誰かが
# 	--> 説明しているのを
#    ブロックチェーンや
# 	--> 機械学習についての
#    機械学習についての
# 	--> 失言で、
#    失言で、
# 	--> 説明しているのを
#    簡単な
# 	--> Webの
#    Webの
# 	--> アプリについて
#    アプリについて
# 	--> 説明しているのを
#    説明しているのを
# 	--> 聞いたら、
#    聞いたら、
# 	--> 説明しましょう
#    ただ
# 	--> うなづき、
#    うなづき、
# 	--> なく、
#    涼しい
# 	--> 顔で
#    顔で
# 	--> なく、
#    Laravel や
# 	--> Symfonyが
#    Symfonyが
# 	--> なく、
#    ほぼ
# 	--> なく、
#    間違い
# 	--> なく、
#    なく、
# 	--> 説明しましょう
#    ちゃんと
# 	--> 動いている
#    うまく
# 	--> 動いている
#    動いている
# 	--> 理由を
#    理由を
# 	--> 説明しましょう
#    説明しましょう
# 	--> None
#    要するに、
# 	--> いけません
#    自分の
# 	--> マーケティング部門の
#    マーケティング部門の
# 	--> 誇大広告を
#    誇大広告を
# 	--> 信用しては
#    信用しては
# 	--> いけません
#    いけません
# 	--> None
#    ブートストラップな
# 	--> スタートアップにとっては
#    スタートアップにとっては
# 	--> 強調してもしたりません
#    いくら
# 	--> 強調してもしたりません
#    強調してもしたりません
# 	--> None
#    PHPの
# 	--> エコシステムで
#    エコシステムで
# 	--> 見つけてください
#    ソリューションを
# 	--> 見つけてください
#    見つけてください
# 	--> None
#    大抵、
# 	--> できます
#    PHPで
# 	--> 進めていく
#    進めていく
# 	--> ことにより、
#    ことにより、
# 	--> できます
#    費用や
# 	--> 開発時間の
#    開発時間の
# 	--> 一部で
#    ほんの
# 	--> 一部で
#    わずかな
# 	--> 一部で
#    一部で
# 	--> 実行する
#    ビジネスロジックを
# 	--> 実行する
#    実行する
# 	--> ことが
#    ことが
# 	--> できます
#    できます
# 	--> None
#    上級開発者が
# 	--> もたらす
#    もたらす
# 	--> 視点
#    視点
# 	--> None
#    真の
# 	--> 上級エンジニアは
#    上級エンジニアは
# 	--> もたらしてくれます
#    インターネット上での
# 	--> 経験が
#    経験が
# 	--> した
#    2年の”上級開発者”と
# 	--> した
#    話を
# 	--> した
#    した
# 	--> 時には
#    時には
# 	--> 得る
#    決して
# 	--> 得る
#    得る
# 	--> ことの
#    ことの
# 	--> ない、
#    ない、
# 	--> 視点を
#    堅実で
# 	--> 広範な
#    広範な
# 	--> 視点を
#    視点を
# 	--> もたらしてくれます
#    もたらしてくれます
# 	--> None
#    PHPのような
# 	--> 実証済みの
#    実証済みの
# 	--> テクノロジを
#    テクノロジを
# 	--> 使用する
#    使用する
# 	--> 場合、
#    場合、
# 	--> 簡単です
#    10年の
# 	--> 経験を
#    経験を
# 	--> 積んだ
#    積んだ
# 	--> エキスパートを
#    エキスパートを
# 	--> 見つける
#    見つける
# 	--> ことは
#    ことは
# 	--> 簡単です
#    とても
# 	--> 簡単です
#    簡単です
# 	--> None
#    企業家にとって、
# 	--> なります
#    経験
# 	--> 豊かな
#    豊かな
# 	--> エンジニアと
#    エンジニアと
# 	--> 組む
#    組む
# 	--> ことは
#    ことは
# 	--> なります
#    コストの
# 	--> 削減に
#    削減に
# 	--> なります
#    なります
# 	--> None
#    若手の
# 	--> チームを
#    チームを
# 	--> 雇って
#    雇って
# 	--> お金を”倹約”しようとするよりも
#    お金を”倹約”しようとするよりも
# 	--> 構築してください
#    むしろ、
# 	--> 構築してください
#    MVPを
# 	--> し、
#    より
# 	--> し、
#    高速に
# 	--> し、
#    し、
# 	--> 構築してください
#    初めから
# 	--> 構築してください
#    高い
# 	--> 品質で
#    品質で
# 	--> 構築してください
#    構築してください
# 	--> None
#    PHPと
# 	--> Laravelといった
#    Symfonyや
# 	--> Laravelといった
#    Laravelといった
# 	--> フレームワークを
#    フレームワークを
# 	--> 用いる
#    用いる
# 	--> 場合、
#    場合、
# 	--> 現実的です
#    上級開発者を
# 	--> 見つけるのが
#    見つけるのが
# 	--> 現実的です
#    はるかに
# 	--> 現実的です
#    現実的です
# 	--> None
#    なかなか
# 	--> しぶとい
#    しぶとい
# 	--> PHP
#    PHP
# 	--> None
#    2019年には
# 	--> 期待しています
#    PHPの
# 	--> 終焉に関する
#    終焉に関する
# 	--> ブログの
#    ブログの
# 	--> 投稿は
#    投稿は
# 	--> なるだろう、と
#    ついに
# 	--> なるだろう、と
#    終わりに
# 	--> なるだろう、と
#    なるだろう、と
# 	--> 期待しています
#    いつも
# 	--> 期待しています
#    期待しています
# 	--> None
#    その
# 	--> 反面、
#    反面、
# 	--> 知らなければ、
#    他の
# 	--> 人が
#    人が
# 	--> 知らなければ、
#    私の
# 	--> 秘密を
#    秘密を
# 	--> 知らなければ、
#    知らなければ、
# 	--> 良いかもしれないとも
#    その
# 	--> 方が
#    方が
# 	--> 良いかもしれないとも
#    良いかもしれないとも
# 	--> 思っています
#    思っています
# 	--> None
#    PHPや
# 	--> Rubyのような
#    Rubyのような
# 	--> 言語の
#    素晴らしい
# 	--> 言語の
#    言語の
# 	--> ため、
#    ため、
# 	--> 作り出しています
#    上級開発者を
# 	--> 雇って
#    雇って
# 	--> 作り出しています
#    166万円以下の
# 	--> MVPを
#    MVPを
# 	--> 作り出しています
#    次から
# 	--> 次へと
#    次へと
# 	--> 作り出しています
#    作り出しています
# 	--> None
#    PHPは
# 	--> Fidel Castroです
#    プログラミング言語の
# 	--> Fidel Castroです
#    Fidel Castroです
# 	--> None
#    つまり、
# 	--> 長生きしました
#    結局の
# 	--> ところ
#    ところ
# 	--> 長生きしました
#    Castroは
# 	--> 長生きしました
#    彼の
# 	--> 暗殺を
#    暗殺を
# 	--> 命じた
#    命じた
# 	--> 5人の
#    5人の
# 	--> アメリカ大統領よりも
#    アメリカ大統領よりも
# 	--> 長生きしました
#    長生きしました
# 	--> None
#    そして
# 	--> ことです
#    もちろん、
# 	--> 終わったと
#    Mark Twainの
# 	--> 死の
#    死の
# 	--> 報道が
#    報道が
# 	--> 誇張されたように、
#    実際より
# 	--> 誇張されたように、
#    誇張されたように、
# 	--> 終わったと
#    Webの
# 	--> 80パーセントを
#    80パーセントを
# 	--> 動かしている
#    動かしている
# 	--> 言語を
#    言語を
# 	--> 終わったと
#    終わったと
# 	--> 考えるのは、
#    考えるのは、
# 	--> ことです
#    まるで
# 	--> 分からない
#    訳が
# 	--> 分からない
#    分からない
# 	--> ことです
#    ことです
# 	--> None
#    PHP万歳
# 	--> None
#    元々の
# 	--> 投稿は
#    投稿は
# 	--> ブログです
#    eTeamの
# 	--> ブログです
#    ブログです
# 	--> None
# sentences:
#    GutenbergとWordPressに関する騒動は、PHPの終焉につながる最新記事です
#    深呼吸をしてください、みなさん
#    トロールは無視し、Mark TwainとFidel CastroとPHPとの共通点を見ていきましょう
#    そして、もっと重要なのは、スタートアップやスモールビジネスにとって、PHPが今でも合理的な選択である理由です
#    PHPはいつから廃れ始めたのか
#    “PHPはもうダメだ”といったブログの投稿が、登場し始めたのは2011年のようです（これより古いものを見つけたら、お知らせください）
#    Mediumや、mushroomsのように突然出現したcoding bootcampsを探し回れば、その唯一の共通点は、みんながPHPを嫌っているか、あるいは単に無視しているかです
#    どうやら、法外な値段のコーヒーを飲みながら、油まみれのヒゲと皮肉たっぷりのTシャツと一緒に、PHPでコーディングするのは不可能のようです
#    ばかな
#    もうたくさんです
#    反PHPのエコーチェンバー現象のせいで、疑わしいビジネス上の決断を下そうとしている創設者に私はいつも話しかけています
#    これが現実です
#    2018年現在、Webサイトの約80パーセントがPHPが使用している
#    PHPは、なんだかんだ言っても、それほど廃れていないと思います
#    神話
#    PHPはスケーラブルではない
#    まったくその通りです
#    Wikipediaは完全にPHPによって動いており、インターネットで5番目にアクセス件数の多いサイトです
#    PHPを使っているFacebookと呼ばれるこの取るに足らないサイトもあります
#    聞いたことがありますか?
#    PHPは遅い
#    もちろん、旧来のPHPは遅くなることがあります
#    私の最初のApple IIeが遅かったから、OS 10はひどいOSだと聞こえてくるのとほぼ同じような議論です
#    PHP7は十分速いです
#    実にPythonより3倍も速いです
#    PHPが輝くプロジェクト
#    私が事業主にWebサイトが必要だという話をするとき、PHPベースのCMS、例えばDrupalなどを検討することをまず提案します
#    PHPでカスタムCMSを構築する際でも、大部分のスモールビジネスの予算の範囲内に十分収まります
#    ”でも、「とても高価でニッチなTechnology X」はどうですか”とつぶやくような返事をもらうことが多いです
#    誤解しないでください
#    私は機械学習、高負荷のシステム、最先端のJavaを使ってプロジェクトを管理してきました
#    私は、技術革新反対主義者ではありません
#    私は実業家です
#    そして、それが共に働く企業ごとに完全に適切な技術を見つけることに固執している理由です
#    PHPはコンテンツ主導型のWebサイトを構成するのに優れています
#    私が共に働くビジネスのほとんどは、アップデートやコピーの変更、ブログ投稿の追加、テンプレートでの運用が容易なサイトが必要です
#    また、こうしたあらゆるものが、専門技能を持たない職員が状況を壊すことなく実行できるほど簡単なのです
#    同じことが電子商取引にも当てはまります
#    コーディングよりも販売に集中する必要がある事業主は、買ってきてそのまま使うことができるMagentoのようなプラットフォームを使用します
#    心配しないでください
#    バックグラウンドでPHPが動いている電子商取引のサイトから、ヒゲの油をまだ売ることができます
#    秘密にしておきます
#    そこで立ち止まる必要はありません
#    Symfonyのような高度なフレームワークは広範囲のアプリケーションの複雑なビジネスロジックに対処できます
#    ReactやVue、Abgularのような最新のフロントエンドのフレームワークとうまく適合するAPIを構築するのにPHPは優れた言語です
#    PHPのビジネス感覚
#    PHPがWebサイトの80パーセントで使用されている話に戻ります
#    経済力につなげてください
#    つまり、PHPの開発者は山ほど存在しているのですから
#    あなたにとっての利点は以下のようなものです
#    開発者を雇うのは、極めて簡単です
#    不明瞭なフレームワークで間に合わせることを決めたプロジェクトに対して、新しい開発者が見つかることをお祈り致します
#    開発者を雇うのは、極めて簡単です
#    不明瞭なフレームワークで間に合わせることを決めたプロジェクトに対して、新しい開発者が見つかることをお祈り致します
#    開発のコストは抑えられます
#    というのも、採用市場に出ている開発者の能力は高く、また一から作り直す必要はありません
#    利用できるオープンソースのプロジェクトはたくさん存在しています
#    開発のコストは抑えられます
#    というのも、採用市場に出ている開発者の能力は高く、また一から作り直す必要はありません
#    利用できるオープンソースのプロジェクトはたくさん存在しています
#    どんな理由であれ、ビジネスにおける基本的な洞察力は、スタートアップの現場では欠けています
#    次に、誰かがブロックチェーンや機械学習についての失言で、簡単なWebのアプリについて説明しているのを聞いたら、ただうなづき、涼しい顔でLaravel やSymfonyがほぼ間違いなく、ちゃんとうまく動いている理由を説明しましょう
#    要するに、自分のマーケティング部門の誇大広告を信用してはいけません
#    ブートストラップなスタートアップにとってはいくら強調してもしたりません
#    PHPのエコシステムでソリューションを見つけてください
#    大抵、PHPで進めていくことにより、費用や開発時間のほんのわずかな一部でビジネスロジックを実行することができます
#    上級開発者がもたらす視点
#    真の上級エンジニアはインターネット上での経験が2年の”上級開発者”と話をした時には決して得ることのない、堅実で広範な視点をもたらしてくれます
#    PHPのような実証済みのテクノロジを使用する場合、10年の経験を積んだエキスパートを見つけることはとても簡単です
#    企業家にとって、経験豊かなエンジニアと組むことはコストの削減になります
#    若手のチームを雇ってお金を”倹約”しようとするよりもむしろ、MVPをより高速にし、初めから高い品質で構築してください
#    PHPとSymfonyやLaravelといったフレームワークを用いる場合、上級開発者を見つけるのがはるかに現実的です
#    なかなかしぶといPHP
#    2019年にはPHPの終焉に関するブログの投稿はついに終わりになるだろう、といつも期待しています
#    その反面、他の人が私の秘密を知らなければ、その方が良いかもしれないとも思っています
#    PHPやRubyのような素晴らしい言語のため、上級開発者を雇って166万円以下のMVPを次から次へと作り出しています
#    PHPはプログラミング言語のFidel Castroです
#    つまり、結局のところCastroは彼の暗殺を命じた5人のアメリカ大統領よりも長生きしました
#    そしてもちろん、Mark Twainの死の報道が実際より誇張されたように、Webの80パーセントを動かしている言語を終わったと考えるのは、まるで訳が分からないことです
#    PHP万歳
#    元々の投稿はeTeamのブログです

# %%
columns = ['id', 'entry_title', 'post_date', 'tag', 'content', 'meta_info', 'sentence', 'token', 'similarity']

# %% [markdown]
# ### TF-IDFを計算する

# %%
data = []
ids = []

find_all_data = mysql_class.find_all(columns)
for row in find_all_data:
    # 文書ごとの単語の原型から空白区切りでdataに格納
    data.append(' '.join([token['lemma'] for token in json.loads(row[columns.index('token')])]))
    ids.append(row[columns.index('id')])

# 文書集合を元にして各文書中の単語のTF-IDF値を計算
vectorizer = TfidfVectorizer(analyzer='word', max_df=0.5)
vecs = vectorizer.fit_transform(data)

index = 0
for id, vec in zip(ids, vecs.toarray()):
    meta_info = json.loads(find_all_data[index][columns.index('meta_info')])
    title = meta_info['title']
    print(id , title)
    index += 1
    
    for w_id, tfidf in sorted(enumerate(vec), key=lambda x: x[1], reverse=True)[:10]:
        lemma = vectorizer.get_feature_names()[w_id]
        print('\t{0:s}: {1:f}'.format(lemma, tfidf))
# Out:
# 54 PHPはもうダメだ、PHP万歳！
# 	ビジネス: 0.252688
# 	上級: 0.234473
# 	サイト: 0.188685
# 	雇う: 0.181705
# 	お祈り: 0.149113
# 	ヒゲ: 0.149113
# 	スモール: 0.129636
# 	廃れる: 0.129636
# 	致す: 0.129636
# 	終焉: 0.125761
# 89 70%の人がフェイクニュースに懸念 — Google の闘い
# 	報道: 0.289511
# 	機関: 0.203878
# 	ニュース: 0.190931
# 	ロシア: 0.185237
# 	マレーシア: 0.180408
# 	ブック: 0.176394
# 	ウクライナ: 0.169980
# 	フェイス: 0.167452
# 	事件: 0.144755
# 	オランダ: 0.141726
# 178 データサイエンティストにおいて、最も需要のあるスキルとは
# 	サイエンティスト: 0.602251
# 	求人: 0.355333
# 	スキル: 0.288436
# 	需要: 0.190947
# 	サイエンス: 0.180826
# 	機械: 0.158557
# 	学習: 0.144955
# 	おすすめ: 0.131951
# 	情報: 0.122141
# 	雇用: 0.118444
# 179 JavaScriptとオブジェクト指向プログラミング
# 	オブジェクト: 0.598996
# 	クラス: 0.438188
# 	関数: 0.181245
# 	カプセル: 0.175637
# 	指向: 0.156177
# 	継承: 0.156100
# 	アクセス: 0.135809
# 	インスタンス: 0.132433
# 	プログラミング: 0.107488
# 	ユース: 0.106957
# 424 気をつけよう:プログラミングのキャリアの話 – 後編
# 	デスク: 0.213184
# 	ソート: 0.194548
# 	プラットフォーム: 0.187185
# 	トップ: 0.177943
# 	アルゴリズム: 0.174199
# 	アプリケーション: 0.170327
# 	言語: 0.157562
# 	プログラミング: 0.140883
# 	習得: 0.137088
# 	すべて: 0.132669
# 273 気をつけよう:プログラミングのキャリアの話 – 前編
# 	エンド: 0.407963
# 	バック: 0.299024
# 	ソケット: 0.295758
# 	マスター: 0.229198
# 	データベース: 0.175654
# 	選ぶ: 0.138736
# 	プログラミング: 0.138498
# 	フロント: 0.135307
# 	サーバ: 0.123386
# 	好き: 0.123249
# 388 役立つコードレビュー 8つのヒント
# 	レビュー: 0.664386
# 	チーム: 0.250795
# 	規則: 0.167858
# 	さん: 0.120253
# 	代案: 0.119132
# 	心がける: 0.117987
# 	遅れ: 0.115902
# 	伝える: 0.108927
# 	フィードバック: 0.104357
# 	小さい: 0.098698
# 48 プログラマの採用面接で聞かれる、データ構造とアルゴリズムに関する50以上の質問
# 	解答: 0.549387
# 	面接: 0.348542
# 	質問: 0.270431
# 	アルゴリズム: 0.232127
# 	配列: 0.229124
# 	よい: 0.217438
# 	連結: 0.212827
# 	構造: 0.212501
# 	分木: 0.200370
# 	リスト: 0.163001
# 323 The 2019 DevOps RoadMap
# 	コース: 0.620102
# 	学ぶ: 0.335709
# 	エンジニア: 0.328193
# 	無料: 0.181934
# 	習得: 0.167511
# 	ツール: 0.136292
# 	学習: 0.101985
# 	ネットワーク: 0.100520
# 	選択肢: 0.094157
# 	向け: 0.091215
# 818 Web 3.0: Webの移行が始まっている
# 	通貨: 0.461728
# 	広告: 0.382321
# 	企業: 0.234422
# 	仮想: 0.203763
# 	チェーン: 0.195115
# 	コンテンツ: 0.169447
# 	支払い: 0.167880
# 	ブロック: 0.151289
# 	プラットフォーム: 0.136507
# 	サイト: 0.134868
# 763 スクラムで失敗する5大理由とその対策としてできること
# 	スクラム: 0.852065
# 	導入: 0.196977
# 	チーム: 0.161532
# 	組織: 0.129339
# 	計画: 0.121731
# 	製品: 0.105543
# 	方式: 0.103549
# 	スプリント: 0.096545
# 	自社: 0.082979
# 	同僚: 0.070262
# 361 開発者が知っておくべきSOLIDの原則
# 	クラス: 0.537847
# 	原則: 0.485693
# 	インターフェース: 0.249615
# 	メソッド: 0.206427
# 	依存: 0.168073
# 	スーパー: 0.156229
# 	違反: 0.136700
# 	モジュール: 0.131450
# 	実装: 0.127882
# 	責任: 0.122985
# 460 ソフトウェア設計が重要である理由
# 	設計: 0.617774
# 	ソフトウェア: 0.554100
# 	コンポーネント: 0.155732
# 	顧客: 0.137175
# 	ホワイト: 0.125966
# 	出典: 0.113942
# 	ボード: 0.088703
# 	メンテナンス: 0.088292
# 	インターフェース: 0.085826
# 	文書: 0.085596
# 42 大規模な決済システムを構築する際に学んだ分散型アーキテクチャの考え方 – 後編
# 	システム: 0.457550
# 	分散: 0.428315
# 	メッセージ: 0.348213
# 	決済: 0.326499
# 	構築: 0.176349
# 	配信: 0.146576
# 	持続: 0.123737
# 	リクエスト: 0.118820
# 	ノード: 0.111734
# 	ロス: 0.107206
# 492 大規模な決済システムを構築する際に学んだ分散型アーキテクチャの考え方 – 前編
# 	可用性: 0.422163
# 	決済: 0.417943
# 	システム: 0.408215
# 	持続: 0.232309
# 	ノード: 0.190704
# 	分散: 0.190704
# 	一貫: 0.189503
# 	整合: 0.182033
# 	垂直: 0.160564
# 	水平: 0.130253
# 26 イーサリアムやEOSよりも優れた仮想マシンの設計過程
# 	仮想: 0.347620
# 	マシン: 0.305859
# 	ネットワーク: 0.202561
# 	アカウント: 0.200721
# 	設計: 0.168754
# 	チューリング: 0.163813
# 	セキュリティ: 0.149931
# 	障壁: 0.143336
# 	実装: 0.136502
# 	パフォーマンス: 0.135476
# 57 13年分の未熟なゲームのコード
# 	バインディング: 0.380766
# 	武器: 0.344006
# 	ゲーム: 0.273900
# 	グローバル: 0.258061
# 	トン: 0.200813
# 	関数: 0.160699
# 	状態: 0.148839
# 	変数: 0.142037
# 	シングル: 0.137550
# 	フィールド: 0.134229
# 463 開発者が、開発者ではない同僚から言われて嬉しい11の言葉 – 「クライアントが、IE6で使えなきゃダメだと言っている」
# 	会議: 0.231532
# 	創造: 0.186330
# 	給与: 0.171582
# 	構築: 0.171271
# 	いとこ: 0.164604
# 	チーム: 0.159490
# 	嬉しい: 0.154019
# 	節約: 0.151088
# 	言葉: 0.128833
# 	あなた: 0.122623
# 506 機械が私たちの偏見を継承する仕組み
# 	偏見: 0.587387
# 	アルゴリズム: 0.295835
# 	人種: 0.233858
# 	広告: 0.209488
# 	単語: 0.185130
# 	コンピュータ: 0.167411
# 	女性: 0.135006
# 	客観: 0.133659
# 	差別: 0.129958
# 	性差: 0.127559
# 577 色:ヘキサコードから眼球まで – Part 3.
# 	空間: 0.330326
# 	ピクセル: 0.324436
# 	スペクトル: 0.301688
# 	ディスプレイ: 0.288953
# 	エネルギー: 0.216466
# 	線形: 0.181302
# 	注釈: 0.181056
# 	軌跡: 0.175601
# 	分光: 0.163479
# 	サブ: 0.161715
# 171 コードレビューのレビューはマネージャーの仕事
# 	レビュー: 0.536686
# 	マネージャー: 0.393559
# 	チーム: 0.284608
# 	トレーニング: 0.175031
# 	文化: 0.166028
# 	プロセス: 0.160899
# 	メンバー: 0.147029
# 	実践: 0.144588
# 	品質: 0.125739
# 	マネジメント: 0.101616
# 486 色:ヘキサコードから眼球まで – Part 2.
# 	光源: 0.390082
# 	波長: 0.390082
# 	細胞: 0.347312
# 	空間: 0.296540
# 	スペクトル: 0.219516
# 	座標: 0.209642
# 	明度: 0.198359
# 	刺激: 0.180007
# 	被験者: 0.169930
# 	プロット: 0.161585
# 774 色:ヘキサコードから眼球まで – Part 1.
# 	放射: 0.555275
# 	波長: 0.462731
# 	感度: 0.288037
# 	分光: 0.235994
# 	スペクトル: 0.206867
# 	エネルギー: 0.203115
# 	レモン: 0.188795
# 	電球: 0.176996
# 	面積: 0.121222
# 	電磁: 0.117997
# 61 なぜPythonはこんなにも遅いのか?
# 	インタプリタ: 0.344001
# 	言語: 0.276159
# 	型付き: 0.267519
# 	動的: 0.207709
# 	変数: 0.196818
# 	アプリケーション: 0.184805
# 	メモリ: 0.141348
# 	遅い: 0.134533
# 	最適: 0.134446
# 	コンパイラ: 0.132842
# 22 分岐予測の簡単な歴史 – Part 3
# 	分岐: 0.643844
# 	予測: 0.580655
# 	履歴: 0.165170
# 	性能: 0.144607
# 	テーブル: 0.128972
# 	不成立: 0.091868
# 	講演: 0.084104
# 	コスト: 0.083234
# 	要因: 0.076479
# 	ハードウェア: 0.071881
# 612 分岐予測の簡単な歴史 – Part 2
# 	分岐: 0.615831
# 	予測: 0.373585
# 	ビット: 0.329537
# 	履歴: 0.328559
# 	方式: 0.256437
# 	テーブル: 0.139053
# 	グローバル: 0.138284
# 	干渉: 0.137707
# 	エントリ: 0.121850
# 	ローカル: 0.105043
# 448 分岐予測の簡単な歴史 – Part 1
# 	分岐: 0.702786
# 	予測: 0.361686
# 	成立: 0.358898
# 	命令: 0.352782
# 	パイプライン: 0.113481
# 	方式: 0.105169
# 	後半: 0.085175
# 	前方: 0.075864
# 	前半: 0.073753
# 	後方: 0.065083
# 544 React.jsのアプリにNeo4jの日付と空間のタイプを扱う
# 	コンポーネント: 0.386418
# 	インデックス: 0.353797
# 	レビュー: 0.287957
# 	空間: 0.198730
# 	日付: 0.173016
# 	ポート: 0.170962
# 	期間: 0.158648
# 	検索: 0.155209
# 	イン: 0.149785
# 	地図: 0.147467
# 317 ブラウザのキャッシュをクリアする
# 	キャッシュ: 0.537316
# 	フェッチ: 0.456665
# 	オリジン: 0.304536
# 	リクエスト: 0.261949
# 	ヘッダ: 0.198560
# 	クリア: 0.173406
# 	リソース: 0.167508
# 	レスポンス: 0.158610
# 	無効: 0.142787
# 	ネットワーク: 0.131788
# 605 拡張現実（AR）ロボット工学
# 	ロボット: 0.681830
# 	工学: 0.289961
# 	地図: 0.166306
# 	フォン: 0.153308
# 	バーチャル: 0.152592
# 	探査: 0.142343
# 	センサー: 0.141823
# 	ネコ: 0.122008
# 	火星: 0.122008
# 	ジェット: 0.118683
# 600 ツールは解決策ではない
# 	惨事: 0.334353
# 	プログラマ: 0.258081
# 	主人公: 0.245531
# 	主任: 0.234844
# 	著者: 0.233853
# 	テスト: 0.218286
# 	ソフトウェア: 0.195926
# 	ずさん: 0.195445
# 	規律: 0.188306
# 	捜査: 0.130296
# 144 2018ワールドカップのGraphQL APIを作りました
# 	ワールドカップ: 0.510596
# 	選手: 0.357890
# 	スキーマ: 0.298721
# 	トーナメント: 0.226932
# 	ゴール: 0.200143
# 	ポルトガル: 0.197290
# 	モロッコ: 0.170199
# 	ノード: 0.149607
# 	試合: 0.147967
# 	スターター: 0.139804
# 112 コーディング面接とSnakeゲームに唯一共通すること
# 	ウィンドウ: 0.693636
# 	スライディング: 0.471399
# 	シーケンス: 0.323860
# 	アルゴリズム: 0.178598
# 	最大: 0.117193
# 	ずれる: 0.113365
# 	要素: 0.082701
# 	ヘビ: 0.081732
# 	サブ: 0.076177
# 	パケット: 0.073226
# 817 分散型システム徹底入門 Part 3.
# 	分散: 0.435034
# 	ブロック: 0.386376
# 	チェーン: 0.346044
# 	台帳: 0.233153
# 	ネットワーク: 0.197834
# 	ハッシュ: 0.193599
# 	コイン: 0.181427
# 	取引: 0.153124
# 	ノード: 0.149543
# 	ファイル: 0.145640
# 798 TwilioとAWS IoTボタンを使った子供のトイレ訓練
# 	ボタン: 0.573816
# 	うん: 0.289124
# 	ちる: 0.278296
# 	子供: 0.228026
# 	電話: 0.213996
# 	発信: 0.186247
# 	ベッド: 0.152481
# 	番号: 0.151057
# 	押す: 0.149260
# 	鳴る: 0.144562
# 745 分散型システム徹底入門 – Part 2.
# 	分散: 0.474013
# 	ノード: 0.430921
# 	システム: 0.208545
# 	ファイル: 0.190088
# 	メッセージ: 0.166269
# 	マシン: 0.163779
# 	複製: 0.151714
# 	コンシューマ: 0.137819
# 	ブローカ: 0.134228
# 	アプリケーション: 0.126725
# 708 分散型システム徹底入門 – Part 1.
# 	分散: 0.586839
# 	システム: 0.266252
# 	データベース: 0.239000
# 	可用性: 0.210147
# 	一貫: 0.194381
# 	レコード: 0.162470
# 	水平: 0.150306
# 	マシン: 0.150122
# 	分断: 0.150045
# 	スケール: 0.145081
# 77 GitトラブルをGetしてしまったら:バージョン管理のお話
# 	コミット: 0.431701
# 	オブジェクト: 0.381233
# 	破損: 0.244168
# 	コマンド: 0.224925
# 	ブランチ: 0.224353
# 	ファイル: 0.215771
# 	修復: 0.182213
# 	ダメ: 0.125236
# 	ライン: 0.124997
# 	ツリー: 0.119822
# 768 iPhone XのFace IDを、Pythonとディープラーニングで再現する方法
# 	解除: 0.292689
# 	ロック: 0.247614
# 	距離: 0.244809
# 	顔面: 0.238362
# 	ネットワーク: 0.230599
# 	登録: 0.195218
# 	学習: 0.194966
# 	別人: 0.192501
# 	訓練: 0.183306
# 	シャム: 0.170259
# 116 HHVMの今後
# 	チーム: 0.256738
# 	互換: 0.238737
# 	リリース: 0.229295
# 	ユーザ: 0.212741
# 	サポート: 0.203125
# 	パフォーマンス: 0.162871
# 	目標: 0.157969
# 	ラン: 0.146249
# 	言語: 0.145473
# 	挙動: 0.133538
# 341 ソフトウェア開発における学習性無力感 – 作業環境の改善
# 	上司: 0.718614
# 	環境: 0.265753
# 	あなた: 0.188798
# 	プログラマ: 0.177977
# 	ミーティング: 0.147295
# 	彼ら: 0.111141
# 	マネージャー: 0.100083
# 	議論: 0.093359
# 	職場: 0.091961
# 	役職: 0.091508
# 477 製品ロードマップの使用をやめて、GISTプランニングを試すべき理由
# 	アイディア: 0.755025
# 	プランニング: 0.268381
# 	ゴール: 0.255979
# 	四半期: 0.209595
# 	プロジェクト: 0.163017
# 	ステップ: 0.138744
# 	バンク: 0.111784
# 	即応: 0.104487
# 	プラン: 0.098580
# 	マップ: 0.090419
# 504 より良い製品案を選択するために役立つツール
# 	確信: 0.479348
# 	ダッシュボード: 0.453936
# 	インパクト: 0.248902
# 	スコア: 0.224263
# 	顧客: 0.221003
# 	推定: 0.150717
# 	製品: 0.137667
# 	証拠: 0.128500
# 	容易: 0.127148
# 	労力: 0.123337
# 206 恐竜に教える現代のCSS – Part 3
# 	分離: 0.262854
# 	コンポーネント: 0.241117
# 	スタイル: 0.210291
# 	規則: 0.188070
# 	アプローチ: 0.182329
# 	クラス: 0.166509
# 	スキン: 0.161421
# 	定義: 0.158697
# 	発想: 0.151501
# 	エレメント: 0.135590
# 680 恐竜に教える現代のCSS – Part 2
# 	プリプロセッサ: 0.589590
# 	ポストプロセッサ: 0.427090
# 	構文: 0.199223
# 	コマンド: 0.171769
# 	プレフィックス: 0.161546
# 	変換: 0.156691
# 	インストール: 0.140840
# 	プラグ: 0.120764
# 	ツール: 0.115614
# 	ファイル: 0.112991
# 523 恐竜に教える現代のCSS – Part 1
# 	レイアウト: 0.614234
# 	グリッド: 0.218013
# 	ページ: 0.214907
# 	属性: 0.179925
# 	組み: 0.174921
# 	組む: 0.171016
# 	指定: 0.142199
# 	コンテンツ: 0.137763
# 	外観: 0.114703
# 	マージン: 0.108860
# 683 Dockerコンテナが遅くなるもう一つの原因
# 	カーネル: 0.475445
# 	コンテナ: 0.272544
# 	ベア: 0.189527
# 	メタル: 0.181260
# 	プロセス: 0.173475
# 	稼働: 0.167945
# 	デバッグ: 0.148838
# 	パフォーマンス: 0.147079
# 	リソース: 0.137919
# 	呼び出し: 0.130210
# 731 カオステストでHTTP/2の問題を見つけ出す
# 	パケット: 0.400904
# 	損失: 0.305765
# 	カオス: 0.301915
# 	サイドカー: 0.252965
# 	遅延: 0.233477
# 	不利益: 0.201276
# 	ストリーム: 0.193716
# 	サービス: 0.186396
# 	リクエスト: 0.179261
# 	テスト: 0.166589
# 124 15年目のVim
# 	プラグ: 0.464297
# 	イン: 0.341005
# 	バッファ: 0.236910
# 	ファイル: 0.235152
# 	ターミナル: 0.205765
# 	コマンド: 0.194731
# 	ペイン: 0.169594
# 	検索: 0.166107
# 	開く: 0.160687
# 	ファジー: 0.147360
# 595 ディープラーニングの限界
# 	幾何: 0.348731
# 	モデル: 0.290725
# 	人間: 0.278363
# 	学習: 0.276319
# 	空間: 0.247968
# 	訓練: 0.243556
# 	マッピング: 0.195002
# 	入力: 0.181295
# 	変換: 0.166823
# 	勾配: 0.137628
# 752 PythonとKerasを使ってAlphaZero AIを自作する
# 	ゲーム: 0.379473
# 	プレイヤー: 0.377310
# 	対戦: 0.317063
# 	バリュー: 0.203826
# 	ファイル: 0.195435
# 	対局: 0.178054
# 	アルゴリズム: 0.174751
# 	学習: 0.172380
# 	訓練: 0.151941
# 	番号: 0.138066
# 407 紙と鉛筆でビットコインをマイニング:1日に0.67ハッシュ
# 	マイニング: 0.439316
# 	ハッシュ: 0.396477
# 	ビット: 0.386112
# 	ラウンド: 0.319681
# 	コイン: 0.309624
# 	ハッシング: 0.260168
# 	ブロック: 0.197818
# 	手作業: 0.136357
# 	アルゴリズム: 0.123042
# 	加算: 0.110272
# 394 Redux-Observable Epic vs Redux-Saga: 何が問題なのか
# 	ラウンド: 0.467580
# 	戦い: 0.220135
# 	コーナー: 0.177008
# 	攻撃: 0.168629
# 	ストリーム: 0.167128
# 	アクション: 0.145888
# 	ディスパッチ: 0.131405
# 	勝者: 0.131405
# 	カン: 0.124711
# 	反撃: 0.124711
# 555 リモートワークのストレス
# 	リモート: 0.480204
# 	仕事: 0.334114
# 	ワーク: 0.268033
# 	義務: 0.225339
# 	チャット: 0.205944
# 	働く: 0.181216
# 	子ども: 0.155591
# 	オフィス: 0.150872
# 	ストレス: 0.140965
# 	孤独: 0.108444
# 513 優秀な面接者に共通するものとは? 数千の実例を調べてみました。- 後編
# 	面接: 0.885615
# 	候補: 0.233497
# 	質問: 0.123167
# 	会社: 0.091273
# 	真摯: 0.079511
# 	ヒント: 0.054546
# 	働く: 0.053906
# 	自身: 0.052513
# 	与える: 0.051786
# 	関与: 0.051346
# 481 RustにおけるfutureとgRPC
# 	応答: 0.330389
# 	通信: 0.291853
# 	キュー: 0.286548
# 	コール: 0.279167
# 	サーバ: 0.254075
# 	完了: 0.233044
# 	単一: 0.226970
# 	チャネル: 0.199641
# 	双方向: 0.195133
# 	ハンドラ: 0.185529
# 748 優秀な面接者に共通するものとは? 数千の実例を調べてみました。- 前編
# 	面接: 0.675407
# 	ブランド: 0.480289
# 	候補: 0.203513
# 	応募: 0.191571
# 	会社: 0.139217
# 	スコア: 0.135081
# 	技術: 0.090848
# 	評価: 0.083322
# 	企業: 0.082523
# 	プラットフォーム: 0.075937
# 740 「フロントエンド開発者」の終焉
# 	フロント: 0.515378
# 	エンド: 0.476768
# 	肩書き: 0.229799
# 	職責: 0.179104
# 	候補: 0.150276
# 	求人: 0.139655
# 	広告: 0.129909
# 	ビジュアル: 0.116747
# 	仕事: 0.116693
# 	名乗る: 0.113291
# 799 Goでクリーンアーキテクチャを試す
# 	レイヤ: 0.667051
# 	クリーン: 0.233534
# 	テスト: 0.233501
# 	独立: 0.224669
# 	ユース: 0.183824
# 	データベース: 0.182231
# 	アーキテクチャ: 0.174184
# 	依存: 0.150938
# 	ビジネス: 0.147620
# 	ルール: 0.116725
# 511 超高速エンジンの内部:Quantum CSS（別名Stylo）- 後編
# 	スタイル: 0.399947
# 	マッチ: 0.326729
# 	ルール: 0.308118
# 	ノード: 0.305436
# 	セレクタ: 0.282836
# 	ブランチ: 0.173056
# 	コア: 0.171264
# 	計算: 0.168745
# 	並列: 0.166944
# 	キャッシュ: 0.165985
# 303 40行以内で正規表現エンジンを構築
# 	一致: 0.586561
# 	文字: 0.526446
# 	パターン: 0.321487
# 	テキスト: 0.264119
# 	返す: 0.134262
# 	関数: 0.118904
# 	正規: 0.114909
# 	残り: 0.100667
# 	実装: 0.085989
# 	ケース: 0.084703
# 554 AlphaGo Zeroの動作方法と理由
# 	探索: 0.346913
# 	モンテカルロ: 0.345921
# 	ノード: 0.320473
# 	盤面: 0.319010
# 	ポリシー: 0.318005
# 	展開: 0.230876
# 	ゲーム: 0.214446
# 	エキスパート: 0.198997
# 	囲碁: 0.158481
# 	確率: 0.142183
# 723 超高速エンジンの内部:Quantum CSS（別名Stylo）- 前編
# 	エンジン: 0.513309
# 	ノード: 0.410647
# 	スタイル: 0.310799
# 	カスケード: 0.171257
# 	ルール: 0.156496
# 	先祖: 0.140151
# 	計算: 0.133506
# 	レイヤ: 0.127761
# 	フォーム: 0.125742
# 	記入: 0.122991
# 587 ブロックチェ-ンを構築しながら学ぶ
# 	チェーン: 0.550592
# 	ブロック: 0.487314
# 	トランザクション: 0.321807
# 	ノード: 0.295445
# 	マイニング: 0.258996
# 	ハッシュ: 0.127145
# 	コンセンサス: 0.107254
# 	プルーフ: 0.104360
# 	アルゴリズム: 0.096178
# 	リクエスト: 0.086560
# 423 ディープラーニングにおけるセマンティックセグメンテーションのガイド2017年版
# 	畳み込む: 0.654639
# 	セグメンテーション: 0.411369
# 	デコーダ: 0.206184
# 	セマンティック: 0.202721
# 	エンコーダ: 0.173993
# 	出典: 0.127609
# 	画像: 0.125681
# 	アーキテクチャ: 0.124910
# 	ピラミッド: 0.119758
# 	論文: 0.118492
# 764 100万回のWebSocket接続とGo
# 	接続: 0.441668
# 	バッファ: 0.331388
# 	パケット: 0.294743
# 	サーバ: 0.258974
# 	グレード: 0.190910
# 	読み込み: 0.171580
# 	書き出し: 0.152101
# 	要求: 0.151339
# 	送信: 0.127770
# 	実装: 0.116769
# 596 非難なき事後分析と公正な企業文化
# 	事故: 0.392533
# 	非難: 0.261526
# 	行為: 0.260341
# 	失敗: 0.255640
# 	事後: 0.252032
# 	技術: 0.243810
# 	ミス: 0.176627
# 	ストーリー: 0.157091
# 	放免: 0.126934
# 	分析: 0.126149
# 685 WebAssemblyはなぜ速いのか
# 	最適: 0.424089
# 	パフォーマンス: 0.297228
# 	コンパイル: 0.296522
# 	パース: 0.252323
# 	コンパイラ: 0.251418
# 	エンジン: 0.153700
# 	高速: 0.135481
# 	タスク: 0.110699
# 	かかる: 0.110328
# 	機械: 0.104830
# 351 Unixコマンド”yes”についてのちょっとした話
# 	バッファ: 0.381393
# 	バージョン: 0.248052
# 	文字: 0.192517
# 	プログラム: 0.176269
# 	些細: 0.154851
# 	ビルト: 0.147223
# 	パラメータ: 0.146444
# 	遅い: 0.134683
# 	シンプル: 0.131766
# 	そんな: 0.130407
# 633 さよなら、Firebug
# 	拡張: 0.327111
# 	ブレーク: 0.296162
# 	リリース: 0.282990
# 	パネル: 0.227552
# 	統合: 0.128546
# 	コミュニティ: 0.127878
# 	ツール: 0.123736
# 	フォーマット: 0.121188
# 	ネット: 0.117933
# 	デバッグ: 0.115906
# 422 モノリシックなバージョン管理の利点
# 	レポ: 0.719168
# 	モノ: 0.481920
# 	プロジェクト: 0.192347
# 	依存: 0.136934
# 	バージョン: 0.121459
# 	関係: 0.100239
# 	ファイル: 0.099592
# 	コミット: 0.064975
# 	ヘッド: 0.064412
# 	従業: 0.064088
# 580 Stack Overflow: 100万人の開発者を手助けするVim終了方法
# 	訪問: 0.428692
# 	割合: 0.344252
# 	質問: 0.293515
# 	身動き: 0.288154
# 	終了: 0.284403
# 	ユーザ: 0.186362
# 	タグ: 0.174915
# 	見出し: 0.154035
# 	抜け出せる: 0.144077
# 	取れる: 0.135224
# 233 サーバレスはより安く、より複雑だ
# 	レス: 0.488180
# 	マイクロ: 0.287284
# 	複雑: 0.259559
# 	サーバ: 0.242760
# 	サービス: 0.240859
# 	ワイヤ: 0.140064
# 	スーパー: 0.121782
# 	引き換え: 0.117039
# 	メリット: 0.114065
# 	リング: 0.105361
# 696 処理速度の遅いcurrentTimeMillis（） – 後編
# 	タイマー: 0.506971
# 	精密: 0.278962
# 	速い: 0.260877
# 	プロセッサ: 0.216200
# 	時刻: 0.207323
# 	分解能: 0.188673
# 	コール: 0.163777
# 	コア: 0.158088
# 	遅い: 0.155423
# 	システム: 0.148175
# 454 プログラミング言語について
# 	英語: 0.461188
# 	名前: 0.345534
# 	プログラミング: 0.222222
# 	関数: 0.222180
# 	ロシア: 0.198315
# 	付け: 0.163718
# 	外国: 0.148736
# 	文字: 0.135682
# 	表記: 0.134274
# 	言語: 0.115981
# 21 V8エンジンでのJavaScriptの機能と最適化コードの書き方に関する5つのベストプラクティス
# 	オブジェクト: 0.401696
# 	エンジン: 0.318281
# 	最適: 0.306571
# 	メソッド: 0.217562
# 	オフセット: 0.179163
# 	コンパイラ: 0.170389
# 	数値: 0.167841
# 	行列: 0.164268
# 	ビット: 0.143313
# 	すべて: 0.127822
# 225 SQLトランザクション分離 実践ガイド
# 	トランザクション: 0.746915
# 	直列: 0.203572
# 	分離: 0.195393
# 	レベル: 0.151935
# 	データベース: 0.149216
# 	副作用: 0.134161
# 	更新: 0.133597
# 	コミット: 0.125441
# 	異常: 0.118394
# 	違反: 0.117854
# 700 SymSpell対BK木:100倍速い文字列のあいまい検索とスペルチェック
# 	距離: 0.614428
# 	編集: 0.414634
# 	単語: 0.320072
# 	検索: 0.248893
# 	辞書: 0.212000
# 	収録: 0.173646
# 	アルゴリズム: 0.154577
# 	計算: 0.138735
# 	スペル: 0.130127
# 	最大: 0.127855
# 438 MOSSプログラムがwebpackに約1400万円の助成金を支給
# 	モジュール: 0.548975
# 	助成: 0.329171
# 	ローダ: 0.225535
# 	作業: 0.194897
# 	援助: 0.169151
# 	バンドル: 0.144111
# 	作者: 0.135424
# 	ストーン: 0.118978
# 	申請: 0.118978
# 	皆様: 0.118978
# 163 JITコンパイルでの冒険 パート2:x64 JIT
# 	命令: 0.487824
# 	機械: 0.251066
# 	出力: 0.249354
# 	コンパイラ: 0.228815
# 	インタプリタ: 0.221134
# 	ジャンプ: 0.202608
# 	アセンブリ: 0.168895
# 	演算: 0.163666
# 	パート: 0.155379
# 	ラベル: 0.137433
# 267 Goのワークスティーリング型スケジューラ
# 	キュー: 0.494145
# 	ルーチン: 0.440556
# 	空転: 0.405512
# 	プロセッサ: 0.380190
# 	スケジューリング: 0.196063
# 	スティール: 0.184324
# 	ローカル: 0.168831
# 	グローバル: 0.161642
# 	ブロック: 0.129511
# 	配分: 0.081084
# 154 Node6からNode8へのアップデート – 実際のパフォーマンスの比較
# 	パーセント: 0.318640
# 	パッケージ: 0.206666
# 	インストール: 0.190577
# 	分の: 0.164685
# 	短縮: 0.163742
# 	サイト: 0.155229
# 	注釈: 0.146298
# 	マウント: 0.138095
# 	モード: 0.137546
# 	キャッシュ: 0.132826
# 634 JITコンパイルでの冒険 パート1:インタプリタ
# 	インタプリタ: 0.459195
# 	ループ: 0.450835
# 	セル: 0.224578
# 	演算: 0.216401
# 	プログラム: 0.202609
# 	最適: 0.194281
# 	命令: 0.183538
# 	シリーズ: 0.171663
# 	トレーシング: 0.149764
# 	ブラケット: 0.145287
# 478 技術ドキュメンテーションのためのreStructuredTextとMarkdownを比較する
# 	マーク: 0.326306
# 	ドキュメンテーション: 0.281586
# 	拡張: 0.280023
# 	アップ: 0.207949
# 	言語: 0.180887
# 	標準: 0.175347
# 	慣れ親しむ: 0.161625
# 	輝き: 0.156892
# 	昨今: 0.120896
# 	実装: 0.119330
# 765 Bashアプリケーションをテストする
# 	テスト: 0.606174
# 	ドキュメンテーション: 0.229201
# 	インストール: 0.198393
# 	フレーム: 0.148638
# 	ワーク: 0.147759
# 	関数: 0.134310
# 	選択肢: 0.128583
# 	ファイル: 0.123794
# 	欠点: 0.121099
# 	コマンド: 0.120980
# 329 Angular 2/4が狭量で遅すぎる理由
# 	フロント: 0.237085
# 	フレーム: 0.234851
# 	ワーク: 0.233463
# 	エコ: 0.208018
# 	本番: 0.200094
# 	エンド: 0.194955
# 	企業: 0.173530
# 	発表: 0.171258
# 	成熟: 0.148398
# 	システム: 0.147324
# 161 処理速度の遅いcurrentTimeMillis（） – 前編
# 	タイマー: 0.377374
# 	プロセッサ: 0.335859
# 	ナノ: 0.295956
# 	精度: 0.264255
# 	クロック: 0.243729
# 	計測: 0.208622
# 	ファミリー: 0.185396
# 	ミリ: 0.167509
# 	タイム: 0.150645
# 	命令: 0.145729
# 426 正式リリースされたES8の主な新機能 ????
# 	オブジェクト: 0.417634
# 	関数: 0.341938
# 	コンマ: 0.227032
# 	仕様: 0.218827
# 	宣言: 0.215534
# 	末尾: 0.213851
# 	文字: 0.208817
# 	返す: 0.196116
# 	リテラル: 0.177432
# 	パラメータ: 0.176492
# 738 Go言語Internal パート2:名前付き戻り値の魅力的な利点
# 	戻り: 0.591204
# 	名前: 0.280944
# 	付き: 0.197637
# 	バイト: 0.160635
# 	連載: 0.145695
# 	関数: 0.143229
# 	言語: 0.139566
# 	利点: 0.136303
# 	ソース: 0.133476
# 	生成: 0.132118
# 739 Kotlinの隠れたコストについてのベンチマーク
# 	コスト: 0.527936
# 	ラムダ: 0.376250
# 	範囲: 0.298244
# 	パフォーマンス: 0.183971
# 	著者: 0.174904
# 	関数: 0.172464
# 	コンパニオン: 0.157422
# 	ボクシング: 0.157422
# 	隠れる: 0.153241
# 	ベンチマーク: 0.135789
# 151 ファイルシステムよりも35%高速に
# 	書き込み: 0.383908
# 	データベース: 0.327673
# 	ファイル: 0.326057
# 	ディスク: 0.300073
# 	読み込み: 0.295507
# 	直接: 0.231095
# 	パフォーマンス: 0.183929
# 	ディレクトリ: 0.143916
# 	テスト: 0.141796
# 	オプション: 0.136549
# 110 Swype式キーボードを改良する
# 	距離: 0.611984
# 	文字: 0.355375
# 	単語: 0.291006
# 	キーボード: 0.238495
# 	平均: 0.184159
# 	当たり: 0.178830
# 	英語: 0.176659
# 	キー: 0.143988
# 	親指: 0.143585
# 	成績: 0.138028
# 482 CPUマスク
# 	マスク: 0.642166
# 	ビット: 0.356589
# 	マクロ: 0.313587
# 	パラメータ: 0.233424
# 	関数: 0.193817
# 	カーネル: 0.168771
# 	マップ: 0.141754
# 	オペランド: 0.131436
# 	与える: 0.117358
# 	番号: 0.100160
# 13 レガシープロトコル向けレガシー検索エンジンの構築
# 	検索: 0.329962
# 	ギガバイト: 0.263978
# 	ファイル: 0.251119
# 	インターネット: 0.232965
# 	インデックス: 0.225643
# 	空間: 0.211242
# 	プロトコル: 0.208991
# 	クロール: 0.188560
# 	エンジン: 0.183920
# 	ポート: 0.155765
# 791 JavaScript モジュールの現状
# 	モジュール: 0.621615
# 	モード: 0.223185
# 	ポート: 0.213386
# 	イン: 0.186954
# 	スムーズ: 0.139201
# 	移行: 0.134654
# 	作者: 0.131437
# 	挙動: 0.129640
# 	互換: 0.120177
# 	エコ: 0.118082
# 366 IRCは死んだ。IRCよ栄えよ。
# 	ネットワーク: 0.374210
# 	ユーザ: 0.372677
# 	チャネル: 0.281483
# 	衰退: 0.259961
# 	成長: 0.220694
# 	チャット: 0.162862
# 	庭園: 0.135634
# 	打撃: 0.134654
# 	よる: 0.121098
# 	指摘: 0.099039
# 781 2017年JavaScriptのテスト概論
# 	テスト: 0.722500
# 	アサーション: 0.267742
# 	単体テスト: 0.165863
# 	ライブラリ: 0.162312
# 	スパイ: 0.140797
# 	スナップショット: 0.130514
# 	フレーム: 0.124911
# 	ワーク: 0.124173
# 	ツール: 0.119754
# 	サポート: 0.111980
# 409 Googleのバグ発見報奨金 – 5千ドルのエラーページ
# 	報奨: 0.412385
# 	報告: 0.350901
# 	要求: 0.251780
# 	ページ: 0.220576
# 	アクセス: 0.216645
# 	措置: 0.182757
# 	応答: 0.180794
# 	ヘッダ: 0.168049
# 	デバッグ: 0.152992
# 	複製: 0.137622
# 505 GraphQLはWeb APIの次のフロンティアか?
# 	規約: 0.496757
# 	採用: 0.159242
# 	リソース: 0.150383
# 	ユーザ: 0.148129
# 	最大: 0.128835
# 	ひょっと: 0.124626
# 	技術: 0.124260
# 	提供: 0.120839
# 	候補: 0.120623
# 	編成: 0.118577
# 363 Webデベロッパのためのセキュリティ・チェックリスト
# 	パスワード: 0.274688
# 	サービス: 0.269702
# 	攻撃: 0.265134
# 	セキュリティ: 0.244691
# 	認証: 0.202001
# 	暗号: 0.181148
# 	保護: 0.174809
# 	ユーザ: 0.152486
# 	ログイン: 0.151772
# 	応答: 0.141015
# 92 コーディングに対する考え方を変える6つのプログラミングパラダイム
# 	言語: 0.440789
# 	プログラミング: 0.341752
# 	スタック: 0.219064
# 	記号: 0.206314
# 	プッシュ: 0.170549
# 	宣言: 0.170512
# 	依存: 0.159981
# 	変数: 0.153422
# 	ラッチ: 0.144227
# 	関数: 0.136759
# 726 Webサイト開発にCSS in JavaScriptを使うのはやめよう
# 	スタイリング: 0.468878
# 	神話: 0.437619
# 	コンポーネント: 0.383544
# 	スタイル: 0.307038
# 	ドキュメント: 0.111983
# 	要素: 0.110603
# 	命名: 0.077276
# 	付き: 0.071913
# 	ファイル: 0.068621
# 	本稿: 0.067758
# 218 MXNet API入門 パート1
# 	行列: 0.419396
# 	画像: 0.323462
# 	パート: 0.238115
# 	深層: 0.194331
# 	トレーニング: 0.186961
# 	ピクセル: 0.184877
# 	グレー: 0.134090
# 	学習: 0.128316
# 	ビット: 0.117086
# 	搭載: 0.111545
# 620 LLVM上で、LuaのCライブラリを使用して、コンパイラを使わずにソフトウェアを書く（後編）
# 	リンカ: 0.392720
# 	ドキュメント: 0.257337
# 	ブロック: 0.235718
# 	関数: 0.222286
# 	シンボル: 0.220756
# 	基本: 0.194936
# 	テーブル: 0.133125
# 	コンパイラ: 0.130241
# 	エントリ: 0.124432
# 	モジュール: 0.121604
# 502 webpackとRollup:似て非なるもの
# 	ライブラリ: 0.253876
# 	アプリケーション: 0.230521
# 	分割: 0.224684
# 	モジュール: 0.223476
# 	ファイル: 0.179294
# 	読み込める: 0.155991
# 	寄付: 0.148406
# 	皆様: 0.145301
# 	作業: 0.142809
# 	ツール: 0.141523
# 242 LLVM上で、LuaのCライブラリを使用して、コンパイラを使わずにソフトウェアを書く（前半）
# 	ヘッダ: 0.326564
# 	コンパイラ: 0.286284
# 	言語: 0.276316
# 	ライブラリ: 0.269920
# 	関数: 0.254483
# 	ファイル: 0.237429
# 	プリプロセッサ: 0.179842
# 	エンド: 0.163582
# 	呼び出す: 0.150127
# 	プログラム: 0.121966
# 715 マルコフモデル ~概要から原理まで~ （後編）
# 	マルコフ: 0.517737
# 	ウィンドウ: 0.365521
# 	キー: 0.337205
# 	モデル: 0.330410
# 	出現: 0.265408
# 	回数: 0.190135
# 	分布: 0.162979
# 	コーパス: 0.157686
# 	単語: 0.147660
# 	続く: 0.109116
# 778 オーバーエンジニアリングの正体とその向き合い方
# 	エンジニアリング: 0.468280
# 	オーバー: 0.354934
# 	要件: 0.270422
# 	クリック: 0.213357
# 	思惑: 0.211899
# 	ステップ: 0.201854
# 	エンジニア: 0.189298
# 	主観: 0.188794
# 	内容: 0.166218
# 	イメージ: 0.138816
# 624 確率的データ構造の比較:カッコウフィルタ対ブルームフィルタ
# 	カッコウ: 0.763071
# 	フィルタ: 0.413971
# 	挿入: 0.256512
# 	要素: 0.171479
# 	陽性: 0.162465
# 	フィンガー: 0.140341
# 	プリント: 0.115952
# 	バケット: 0.108220
# 	インデックス: 0.100765
# 	確率: 0.072879
# 125 マルコフモデル ~概要から原理まで~ （前編）
# 	マルコフ: 0.585741
# 	モデル: 0.313999
# 	キー: 0.286829
# 	単語: 0.272856
# 	分布: 0.272482
# 	クン: 0.218982
# 	トー: 0.216798
# 	重み: 0.156789
# 	トーク: 0.141111
# 	ヒストグラム: 0.136673
# 636 ディープラーニングのための線形代数入門:一般的演算の初学者向けガイド
# 	行列: 0.734356
# 	ベクトル: 0.429150
# 	乗算: 0.223255
# 	次元: 0.190414
# 	代数: 0.164442
# 	演算: 0.150392
# 	スカラー: 0.147509
# 	内積: 0.139673
# 	線形: 0.125097
# 	加算: 0.104203
# 87 私が書いた最速のハッシュテーブル – PART 4
# 	挿入: 0.435208
# 	テーブル: 0.390008
# 	バイト: 0.320124
# 	削除: 0.260635
# 	ハッシュ: 0.193576
# 	要素: 0.191452
# 	整数: 0.191357
# 	キー: 0.172641
# 	ナノ: 0.171949
# 	グラフ: 0.166449
# 694 興味深いデータ構造:BK木
# 	距離: 0.595494
# 	ノード: 0.368089
# 	ルート: 0.241076
# 	単語: 0.224959
# 	検索: 0.202155
# 	公理: 0.179702
# 	半径: 0.159999
# 	構造: 0.158142
# 	辞書: 0.150506
# 	要素: 0.142426
# 498 機械学習のための仮説検定
# 	検定: 0.586926
# 	損失: 0.352391
# 	モデル: 0.309860
# 	訓練: 0.211996
# 	仮説: 0.207245
# 	推定: 0.175470
# 	交差: 0.173406
# 	ホールド: 0.168777
# 	適合: 0.149883
# 	回帰: 0.108009
# 395 私が書いた最速のハッシュテーブル – PART 3
# 	テーブル: 0.410425
# 	ルック: 0.363590
# 	グラフ: 0.302038
# 	要素: 0.247079
# 	整数: 0.227499
# 	バイト: 0.211437
# 	コンテナ: 0.211323
# 	ナノ: 0.197253
# 	挿入: 0.189440
# 	キー: 0.186590
# 38 Go言語のリアルタイムGC 理論と実践
# 	コレクタ: 0.342963
# 	ベンチマーク: 0.315688
# 	一時: 0.277528
# 	オブジェクト: 0.261180
# 	フェーズ: 0.251631
# 	停止: 0.247558
# 	プログラム: 0.239138
# 	グレー: 0.236549
# 	スライド: 0.195593
# 	ヒープ: 0.163287
# 499 私はC言語を知らない
# 	解答: 0.658136
# 	定義: 0.245422
# 	コンマ: 0.223192
# 	符号: 0.213213
# 	動作: 0.179656
# 	ポインタ: 0.174425
# 	コンパイラ: 0.153190
# 	関数: 0.149402
# 	引数: 0.112919
# 	プログラム: 0.104422
# 484 200行のコードへのブロックチェーンの実装
# 	ブロック: 0.733377
# 	チェーン: 0.420367
# 	ノード: 0.363323
# 	ハッシュ: 0.144726
# 	最新: 0.103694
# 	送信: 0.102156
# 	プルーフ: 0.098002
# 	オブ: 0.092595
# 	制御: 0.075066
# 	サーバ: 0.073949
# 687 Dockerの本番運用
# 	カーネル: 0.239762
# 	運用: 0.224957
# 	発生: 0.215894
# 	システム: 0.203068
# 	ボリューム: 0.184299
# 	不具合: 0.177776
# 	安定: 0.140935
# 	ベータ: 0.140469
# 	クラッシュ: 0.135092
# 	バグ: 0.131539
# 468 どのようにして5,000ドルのGoogleマップXSSを発見したか
# 	フィールド: 0.384269
# 	マップ: 0.320173
# 	文字: 0.262215
# 	メッセージ: 0.229668
# 	リクエスト: 0.214662
# 	形式: 0.191539
# 	注釈: 0.190188
# 	エン: 0.156304
# 	デバッガ: 0.151146
# 	バイナリ: 0.142532
# 401 私が書いた最速のハッシュテーブル – PART 2
# 	ハッシュ: 0.424492
# 	テーブル: 0.414102
# 	挿入: 0.405921
# 	スロット: 0.355208
# 	べき乗: 0.206776
# 	素数: 0.185530
# 	モジュロ: 0.173187
# 	削除: 0.172568
# 	要素: 0.154015
# 	ルック: 0.152354
# 758 JOSEは、絶対に避けるべき悪い標準規格である
# 	暗号: 0.554911
# 	規格: 0.387493
# 	付き: 0.269626
# 	標準: 0.221021
# 	認証: 0.208368
# 	攻撃: 0.156636
# 	セキュリティ: 0.144559
# 	署名: 0.141149
# 	ヘッダ: 0.137664
# 	偽造: 0.131319
# 447 残りの私たちにとって、Rが最高のプログラミング言語である理由
# 	パッケージ: 0.516153
# 	返す: 0.220143
# 	人々: 0.179346
# 	インデックス: 0.166592
# 	文字通り: 0.148528
# 	インストール: 0.139991
# 	残り: 0.128379
# 	ブラケット: 0.121599
# 	弱み: 0.113265
# 	作業: 0.111323
# 754 組み込みシステム上でのC++
# 	組み込み: 0.337938
# 	関数: 0.268042
# 	ガード: 0.240241
# 	コンパイラ: 0.235576
# 	ファームウェア: 0.221569
# 	呼び出す: 0.197657
# 	ファシリティ: 0.171519
# 	オブジェクト: 0.163689
# 	チェーン: 0.162924
# 	インライン: 0.155987
# 631 UIデザインにおけるボタン:スタイルの進化とベストプラクティス
# 	ボタン: 0.752840
# 	ユーザー: 0.281201
# 	フラット: 0.266173
# 	ゴースト: 0.263328
# 	デザイン: 0.173193
# 	要素: 0.113989
# 	クレジット: 0.104060
# 	コントラスト: 0.098319
# 	丸まる: 0.095756
# 	行動: 0.095240
# 64 #/usr/binとその同種の周辺を探る
# 	コマンド: 0.489123
# 	ファイル: 0.420061
# 	プロセス: 0.291139
# 	ポリシー: 0.184233
# 	出力: 0.166277
# 	オプション: 0.165436
# 	区切り: 0.163226
# 	指定: 0.142976
# 	コア: 0.135191
# 	単位: 0.116077
# 623 私が書いた最速のハッシュテーブル – PART 1
# 	テーブル: 0.605290
# 	スロット: 0.466495
# 	要素: 0.228032
# 	ハッシュ: 0.222876
# 	挿入: 0.195325
# 	ルック: 0.161489
# 	埋まる: 0.154514
# 	探索: 0.150846
# 	グラフ: 0.138776
# 	素数: 0.106971
# 762 RethinkDBとPostgreSQLの比較:私の個人的な経験より – 後編
# 	データベース: 0.282087
# 	テーブル: 0.221965
# 	パーセント: 0.217938
# 	サーバ: 0.181636
# 	ディスク: 0.157063
# 	マスタ: 0.147638
# 	速度: 0.141173
# 	かかる: 0.136133
# 	負荷: 0.132335
# 	本番: 0.129669
# 471 型安全性と統計計算
# 	統計: 0.495402
# 	ベクトル: 0.304581
# 	計算: 0.284789
# 	安全: 0.252072
# 	仮定: 0.246103
# 	標本: 0.211800
# 	作為: 0.176687
# 	分析: 0.133702
# 	システム: 0.132071
# 	欠損: 0.129323
# 613 信頼性の高いパスワードの生成
# 	パスワード: 0.814344
# 	エントロピー: 0.297255
# 	ワード: 0.190100
# 	生成: 0.174436
# 	文字: 0.130202
# 	サイコロ: 0.111202
# 	マネージャ: 0.105644
# 	単語: 0.090394
# 	転送: 0.084965
# 	リスト: 0.084498
# 177 RethinkDBとPostgreSQLの比較:私の個人的な経験より – 前編
# 	書き直す: 0.227797
# 	ライセンス: 0.186458
# 	リアルタイム: 0.181749
# 	データベース: 0.177484
# 	ベンチマーク: 0.140512
# 	話す: 0.132473
# 	アプリケーション: 0.131591
# 	反応: 0.128246
# 	初旬: 0.127902
# 	投稿: 0.124665
# 342 効率的にゲームを更新する
# 	接尾: 0.553067
# 	区間: 0.298324
# 	圧縮: 0.281385
# 	ソート: 0.275566
# 	スキャン: 0.223005
# 	シーケンス: 0.199228
# 	ブロック: 0.183506
# 	ハッシュ: 0.173079
# 	ミリ: 0.167769
# 	古い: 0.160496
# 433 できる動的計画法:ロッド切り出し問題
# 	切断: 0.671930
# 	長い: 0.343113
# 	切り出す: 0.324054
# 	箇所: 0.198242
# 	利益: 0.180351
# 	最大: 0.151519
# 	ロッド: 0.147940
# 	切り出し: 0.139389
# 	価格: 0.114459
# 	動的: 0.110867
# 128 なぜリフレクションは遅いのか
# 	メソッド: 0.304112
# 	オプション: 0.283925
# 	呼び出し: 0.270864
# 	遅い: 0.192558
# 	取得: 0.190388
# 	コスト: 0.188140
# 	アクセス: 0.187898
# 	下記: 0.173302
# 	オーバヘッド: 0.168967
# 	キャッシュ: 0.162404
# 445 Rust開発者のためのC++入門書:所有権と借用について
# 	メソッド: 0.350831
# 	移動: 0.311019
# 	所有: 0.310276
# 	ライフ: 0.297706
# 	コピー: 0.288724
# 	参照: 0.256908
# 	借用: 0.248528
# 	コンパイラ: 0.217520
# 	関数: 0.212141
# 	場所: 0.165401
# 490 Gitのスケーリング（と、その背景）
# 	管理: 0.223629
# 	ファイル: 0.204053
# 	すべて: 0.196336
# 	チーム: 0.181964
# 	社内: 0.180842
# 	タッチ: 0.164031
# 	ベース: 0.149836
# 	スケール: 0.143838
# 	エンジニアリング: 0.135210
# 	ウド: 0.133039
# 41 ニューラルネットワークの動物園 : ニューラルネットワーク・アーキテクチャのチートシート（後編）
# 	ネットワーク: 0.458842
# 	ゲート: 0.365947
# 	ニューロン: 0.343523
# 	原文: 0.279373
# 	入力: 0.224312
# 	訓練: 0.183218
# 	回帰: 0.145206
# 	スヌーピー: 0.141814
# 	セル: 0.129415
# 	画像: 0.125959
# 645 週末にいちばん多く使われるプログラミング言語は?
# 	週末: 0.676763
# 	平日: 0.534060
# 	タグ: 0.319554
# 	質問: 0.234598
# 	割合: 0.095705
# 	相対: 0.083357
# 	人気: 0.075995
# 	中心: 0.067994
# 	占める: 0.065183
# 	パーセント: 0.064138
# 126 JVMはそんなに重くない
# 	重い: 0.409351
# 	インストール: 0.196626
# 	膨張: 0.130356
# 	手順: 0.126746
# 	いじる: 0.121366
# 	ファイル: 0.120188
# 	肥大: 0.116063
# 	そんなに: 0.110264
# 	製品: 0.109891
# 	あなた: 0.107757
# 704 ニューラルネットワークの動物園 : ニューラルネットワーク・アーキテクチャのチートシート（前編）
# 	ニューロン: 0.440234
# 	ネットワーク: 0.371005
# 	入力: 0.343954
# 	訓練: 0.272231
# 	原文: 0.213480
# 	ノード: 0.155583
# 	セル: 0.131855
# 	出力: 0.130290
# 	アーキテクチャ: 0.126399
# 	学習: 0.125471
# 51 学校では習わないコーディングスキル:オブジェクト所有権
# 	所有: 0.732447
# 	オブジェクト: 0.350423
# 	解放: 0.260090
# 	割り当て: 0.210749
# 	可変: 0.168460
# 	メモリ: 0.139518
# 	関数: 0.122961
# 	スキル: 0.105483
# 	言語: 0.103841
# 	規約: 0.102599
# 259 私たちはいかにして環状線で”悪さをする列車”を捕まえたか
# 	インシデント: 0.675253
# 	列車: 0.541128
# 	環状: 0.213066
# 	信号: 0.140234
# 	干渉: 0.130117
# 	発生: 0.124407
# 	マレー: 0.096848
# 	走る: 0.089394
# 	ブレーキ: 0.084198
# 	原因: 0.076903
# 642 一から学ぶベジェ曲線
# 	線分: 0.762636
# 	端点: 0.508424
# 	ならう: 0.227552
# 	アニメーション: 0.142337
# 	ござる: 0.133615
# 	ありがとう: 0.130408
# 	厳密: 0.123396
# 	リクエスト: 0.108087
# 	皆さん: 0.090443
# 	表現: 0.086810
# 15 型クラスはインターフェースとどう違うのか
# 	クラス: 0.543409
# 	インスタンス: 0.438902
# 	インターフェース: 0.258408
# 	パラメータ: 0.240735
# 	関数: 0.240268
# 	定義: 0.228598
# 	取り込む: 0.158026
# 	実装: 0.149908
# 	変数: 0.131168
# 	メソッド: 0.130890
# 716 どれだけ速く文字列からスペースを削除できるのか
# 	ビット: 0.387668
# 	速い: 0.376196
# 	プロセッサ: 0.340112
# 	命令: 0.337312
# 	ワード: 0.251044
# 	文字: 0.222405
# 	バイト: 0.175049
# 	分岐: 0.167992
# 	削除: 0.142520
# 	単位: 0.133457
# 553 Node.jsのパフォーマンス最適化を阻むものの見つけ方
# 	最適: 0.768766
# 	関数: 0.265177
# 	戻す: 0.252385
# 	アリ: 0.144077
# 	マーク: 0.133179
# 	ヒューリスティック: 0.115604
# 	地獄: 0.104110
# 	遂行: 0.101368
# 	コンパイル: 0.093972
# 	解明: 0.093040
# 412 数値最適化のインタラクティブ・チュートリアル
# 	勾配: 0.547236
# 	最小: 0.298894
# 	共役: 0.243386
# 	探索: 0.237322
# 	降下: 0.236738
# 	次元: 0.205427
# 	係数: 0.181744
# 	関数: 0.178290
# 	ステップ: 0.167777
# 	都市: 0.146656
# 410 糸が紡ぎ出す明暗
# 	画像: 0.514969
# 	レーザー: 0.291349
# 	織機: 0.231917
# 	ピン: 0.226712
# 	丸い: 0.190500
# 	アルゴリズム: 0.168925
# 	暗い: 0.165303
# 	通す: 0.164764
# 	カッター: 0.154611
# 	ステップ: 0.133893
# 182 すばらしいビット
# 	ビット: 0.501731
# 	導出: 0.285738
# 	取得: 0.224551
# 	高速: 0.211479
# 	小文字: 0.205940
# 	浮動: 0.194075
# 	小数点: 0.192380
# 	大文字: 0.186193
# 	逆数: 0.181960
# 	累乗: 0.163980
# 132 Lispのアイデア
# 	言語: 0.413687
# 	アイデア: 0.275793
# 	インタプリタ: 0.264864
# 	プログラミング: 0.256081
# 	再帰: 0.204921
# 	科学: 0.183763
# 	定義: 0.181571
# 	万能: 0.177057
# 	チューリングマシン: 0.167897
# 	コンピュータ: 0.146605
# 65 仮想DOMの内部の動き
# 	ノード: 0.519002
# 	コンポーネント: 0.515546
# 	備考: 0.201334
# 	削除: 0.172407
# 	ライフサイクル: 0.169741
# 	リファレンス: 0.155565
# 	ツリー: 0.154626
# 	リーフ: 0.138734
# 	フローチャート: 0.131079
# 	仮想: 0.125844
# 451 映画制作におけるPython
# 	映画: 0.451979
# 	部門: 0.371269
# 	エフェクト: 0.277402
# 	キャラクター: 0.272116
# 	映像: 0.247784
# 	アニメーション: 0.199605
# 	長編: 0.190129
# 	場面: 0.144276
# 	パイプライン: 0.122949
# 	アーティスト: 0.112688
# 248 エンコード方式 base-122
# 	文字: 0.430467
# 	バイト: 0.346801
# 	エン: 0.322766
# 	ビット: 0.308314
# 	変換: 0.297247
# 	方式: 0.218500
# 	デコード: 0.199753
# 	サイズ: 0.159802
# 	ポイント: 0.155100
# 	バイナリ: 0.141277
# 467 –cap-dropオプションを使ったDockerコンテナの安全性を高める工夫
# 	コンテナ: 0.683938
# 	プロセス: 0.328015
# 	削除: 0.250952
# 	ルート: 0.198404
# 	ファイル: 0.159434
# 	権限: 0.147555
# 	任意: 0.134225
# 	ソケット: 0.133394
# 	セキュリティ: 0.106867
# 	特権: 0.105272
# 575 Sublime Textを逆アセンブルする
# 	文書: 0.296556
# 	インデント: 0.227939
# 	描画: 0.189801
# 	正規: 0.172438
# 	ガイド: 0.169461
# 	オプション: 0.167268
# 	バイナリ: 0.157950
# 	設定: 0.151680
# 	実線: 0.147497
# 	点線: 0.143088
# 712 バージョンの充足可能性問題
# 	パッケージ: 0.688859
# 	バージョン: 0.298396
# 	充足: 0.266353
# 	インストール: 0.211743
# 	依存: 0.208577
# 	証明: 0.179212
# 	管理: 0.167869
# 	関係: 0.157609
# 	方程式: 0.135313
# 	完全: 0.130516
# 524 部分文字列とRegExpの領域の冒険
# 	文字: 0.525535
# 	表現: 0.263267
# 	ベンチマーク: 0.245170
# 	実装: 0.240203
# 	正規: 0.218855
# 	スライシング: 0.162304
# 	ラン: 0.155295
# 	パフォーマンス: 0.137258
# 	フラグ: 0.133729
# 	最適: 0.125339
# 713 チュートリアル – システムコールの書き方
# 	カーネル: 0.599935
# 	コール: 0.526965
# 	システム: 0.297979
# 	コンパイル: 0.145452
# 	自作: 0.117784
# 	起動: 0.109533
# 	設定: 0.107599
# 	関数: 0.097726
# 	ダウンロード: 0.093651
# 	名前: 0.076676
# 730 Haskell、OCaml、RacketでGCのレイテンシを測る
# 	ワースト: 0.499326
# 	停止: 0.382372
# 	ミリ: 0.310645
# 	ベンチマーク: 0.274277
# 	ケース: 0.185291
# 	定常: 0.147211
# 	ラン: 0.136504
# 	明示: 0.117971
# 	計測: 0.117356
# 	世代: 0.106832
# 374 #Anthony Calandra / モダンC++の機能
# 	移動: 0.339933
# 	リテラル: 0.282827
# 	推論: 0.277304
# 	右辺: 0.266412
# 	ラムダ: 0.231641
# 	オブジェクト: 0.219790
# 	テンプレート: 0.209933
# 	関数: 0.200718
# 	参照: 0.145943
# 	左辺: 0.142335
# 336 確率的プログラミング
# 	確率: 0.456622
# 	論文: 0.231814
# 	プログラミング: 0.231424
# 	統計: 0.227938
# 	推論: 0.197386
# 	プログラム: 0.197053
# 	言語: 0.189465
# 	サイコロ: 0.187432
# 	モデル: 0.175009
# 	棄却: 0.174188
# 650 OSのデバッグ:メモリアロケーション講座
# 	報告: 0.218746
# 	わかる: 0.205730
# 	やあ: 0.199860
# 	コンテンツ: 0.176289
# 	レポート: 0.175496
# 	遅い: 0.166082
# 	バグ: 0.161172
# 	政治: 0.160255
# 	みなさん: 0.140684
# 	調査: 0.136945
# 494 Riotのオンラインサービス運用:第2部
# 	コンテナ: 0.613153
# 	パック: 0.412587
# 	クラスタ: 0.312311
# 	ホスト: 0.255891
# 	スケジューリング: 0.172546
# 	デーモン: 0.123374
# 	状態: 0.121897
# 	起動: 0.114731
# 	ミラー: 0.101947
# 	本稿: 0.099372
# 637 グラフ代数
# 	グラフ: 0.685006
# 	頂点: 0.429659
# 	代数: 0.331448
# 	法則: 0.200030
# 	公理: 0.155331
# 	分配: 0.130475
# 	インスタンス: 0.126662
# 	表記: 0.115033
# 	クリーク: 0.103417
# 	満たす: 0.093947
# 251 Python 3を使うべきでない場合（なんてない）
# 	移行: 0.327927
# 	新人: 0.267731
# 	痛み: 0.249882
# 	企業: 0.152240
# 	文字: 0.150884
# 	グレード: 0.141638
# 	にとって: 0.133337
# 	やむを得ない: 0.126481
# 	知れる: 0.111989
# 	つめ: 0.103442
# 216 私たちはなぜReactではなくVue.jsを選んだのか
# 	コンポーネント: 0.385999
# 	バック: 0.182913
# 	エンド: 0.181492
# 	双方向: 0.166467
# 	ステート: 0.160027
# 	フレーム: 0.153044
# 	ワーク: 0.152139
# 	テンプレート: 0.119775
# 	可読性: 0.112285
# 	バインディング: 0.103382
# 5 コードの半減期とテセウスの船
# 	半減: 0.363015
# 	プロジェクト: 0.345361
# 	減衰: 0.269015
# 	コミット: 0.217772
# 	線形: 0.196770
# 	変化: 0.143995
# 	指数: 0.143074
# 	安定: 0.122191
# 	分析: 0.120308
# 	存続: 0.112167
# 296 最も割高なアンチパターン : 構造化されたデータを文字列関数で操作する「printfアンチパターン」について
# 	文字: 0.463405
# 	アンチ: 0.312956
# 	操作: 0.276722
# 	生成: 0.243146
# 	フォーマット: 0.204896
# 	脆弱: 0.176279
# 	パターン: 0.152447
# 	サイト: 0.144155
# 	割高: 0.143116
# 	関数: 0.139784
# 196 私のGoogleインターンシップ体験記
# 	オフィス: 0.368247
# 	インターンシップ: 0.305363
# 	ヶ月: 0.286740
# 	ロンドン: 0.264648
# 	インターン: 0.246838
# 	チーム: 0.155694
# 	面接: 0.141297
# 	従業: 0.126613
# 	エンジニアリング: 0.118734
# 	プロジェクト: 0.115359
# 188 プログラミングスタックをEveはどのように統合するのか
# 	データモデル: 0.420369
# 	統一: 0.328742
# 	データベース: 0.290423
# 	レコード: 0.259474
# 	操作: 0.239124
# 	スタック: 0.210497
# 	各層: 0.174502
# 	セット: 0.146864
# 	プログラミング: 0.130851
# 	アプリケーション: 0.107663
# 193 IPをQRコードで実現する
# 	パケット: 0.504282
# 	カメラ: 0.396010
# 	エン: 0.172395
# 	送れる: 0.167637
# 	ヘッダ: 0.159526
# 	デコード: 0.148183
# 	ミリ: 0.118775
# 	受信: 0.113414
# 	デバイス: 0.112924
# 	ジャック: 0.112572
# 84 AWSでWordPressを使用したスムーズで簡単な構築
# 	インスタンス: 0.460874
# 	ファイル: 0.446659
# 	プラグ: 0.214824
# 	ディスク: 0.167714
# 	イン: 0.157778
# 	テーマ: 0.152357
# 	フォールトトレラント: 0.151948
# 	画像: 0.149207
# 	ロード: 0.143603
# 	アップ: 0.142500
# 772 プログラマとしてのキャリアを脅かす反復運動過多損傷の痛みをどう解消したか
# 	痛み: 0.761565
# 	筋肉: 0.202796
# 	緊張: 0.141497
# 	手首: 0.132923
# 	キーボード: 0.127049
# 	仕事: 0.122556
# 	年間: 0.092713
# 	パートタイム: 0.091988
# 	博士: 0.091959
# 	働く: 0.081982
# 741 Q&A:人工知能の未来（後編）
# 	兵器: 0.398495
# 	人間: 0.370137
# 	ロボット: 0.355988
# 	自律: 0.254307
# 	機械: 0.218467
# 	研究: 0.174576
# 	インテリジェント: 0.148707
# 	システム: 0.107994
# 	人類: 0.105961
# 	スーパー: 0.102573
# 453 Q&A:人工知能の未来（前編）
# 	人間: 0.385309
# 	マシン: 0.303493
# 	知能: 0.283922
# 	学習: 0.241977
# 	研究: 0.232808
# 	誤解: 0.199241
# 	タスク: 0.194196
# 	機械: 0.179302
# 	知的: 0.163139
# 	ムーア: 0.142779
# 162 今すぐ始めるLaTeX
# 	パッケージ: 0.299841
# 	テーブル: 0.266334
# 	エディタ: 0.239003
# 	揃える: 0.207720
# 	挿入: 0.203057
# 	文書: 0.193935
# 	ファイル: 0.191202
# 	セクション: 0.179637
# 	セル: 0.168748
# 	ヒント: 0.147998
# 148 英政府デジタルサービスのPaaSチームが採っている、公平な会議進行のためのアプローチ
# 	信号: 0.732432
# 	発言: 0.267493
# 	遮る: 0.182818
# 	チーム: 0.179709
# 	メンバ: 0.137722
# 	会話: 0.119195
# 	人物: 0.115730
# 	物静か: 0.111283
# 	ミーティング: 0.107794
# 	ディスカッション: 0.104992
# 413 CQRSとイベントソーシングの使用法、または「CRUDに何か問題でも?」
# 	コマンド: 0.338999
# 	イベント: 0.306808
# 	エンティティ: 0.304960
# 	ユーザー: 0.217568
# 	更新: 0.188628
# 	データモデル: 0.176660
# 	モデル: 0.160671
# 	メールアドレス: 0.153601
# 	昔ながら: 0.143282
# 	ストア: 0.131306
# 434 くだらないAPIなんていらないよ – 2016年のウェブスクレイピング事情
# 	自動: 0.254908
# 	スクリプト: 0.160698
# 	じゃ: 0.159181
# 	サイト: 0.145264
# 	レート: 0.144411
# 	横取り: 0.144217
# 	イメージ: 0.133698
# 	エラー: 0.131179
# 	フォロー: 0.126269
# 	ネタ: 0.117947
# 734 H.264の秘密
# 	可逆: 0.278355
# 	圧縮: 0.271041
# 	動画: 0.254903
# 	成分: 0.250851
# 	周波数: 0.244941
# 	フレーム: 0.244039
# 	画像: 0.243488
# 	エントロピー: 0.222634
# 	情報: 0.189907
# 	符号: 0.167117
# 790 フロントエンドにおいてModel-View-Controllerは死んだのか?
# 	アーキテクチャ: 0.384191
# 	フロント: 0.331731
# 	エンド: 0.272782
# 	コンポーネント: 0.217259
# 	原則: 0.185011
# 	サーバ: 0.176461
# 	アプリケーション: 0.170290
# 	フレーム: 0.153349
# 	ワーク: 0.152442
# 	状態: 0.140373
# 461 C言語、知ってるつもり?
# 	わかる: 0.377408
# 	正解: 0.336367
# 	規格: 0.332884
# 	定める: 0.171173
# 	不定: 0.169218
# 	サイズ: 0.166515
# 	標準: 0.159893
# 	だって: 0.153084
# 	なおす: 0.137669
# 	ビット: 0.136252
# 784 MITライセンスを1行1行読んでいく
# 	ライセンス: 0.710199
# 	著作: 0.391115
# 	許諾: 0.347093
# 	米国: 0.158611
# 	ソフトウェア: 0.131877
# 	権利: 0.126704
# 	特許: 0.126037
# 	複製: 0.083551
# 	条項: 0.073971
# 	訴える: 0.073521
# 602 『モンスターワールドII ドラゴンの罠』1989年オリジナル版のリバースエンジニアリング:正確性の探究
# 	ゲーム: 0.516873
# 	カートリッジ: 0.422252
# 	オリジナル: 0.320121
# 	ドラゴン: 0.194885
# 	モンスター: 0.173517
# 	ワールド: 0.113258
# 	挿す: 0.108127
# 	アセンブラ: 0.102759
# 	メイド: 0.097443
# 	呪い: 0.097443
# 514 Essential Electron : Electronの簡潔・平易な概要
# 	プロセス: 0.382402
# 	メイン: 0.367429
# 	アプリケーション: 0.286956
# 	資料: 0.231304
# 	ネイティブ: 0.225858
# 	参考: 0.182905
# 	言語: 0.168923
# 	ファイル: 0.156521
# 	オープン: 0.152147
# 	モジュール: 0.151738
# 396 パスワードリセット・リンクが漏れていませんか?
# 	リセット: 0.501052
# 	パスワード: 0.465417
# 	漏洩: 0.430054
# 	リンク: 0.260560
# 	トーク: 0.192012
# 	ユーザ: 0.126833
# 	サイト: 0.124934
# 	クン: 0.112521
# 	トー: 0.111399
# 	フォーム: 0.106298
# 168 もしもディスプレイが壊れたら（ヒマラヤで）
# 	トップ: 0.381472
# 	ラップ: 0.369602
# 	キーボード: 0.283145
# 	スマ: 0.205007
# 	接続: 0.180904
# 	キー: 0.158991
# 	とき: 0.156266
# 	ディスプレイ: 0.146048
# 	画面: 0.142396
# 	押す: 0.124337
# 785 畳み込みニューラルネットワークの仕組み
# 	画像: 0.619617
# 	特徴: 0.364571
# 	ピクセル: 0.333617
# 	畳み込む: 0.244502
# 	一致: 0.164206
# 	重み: 0.135134
# 	結合: 0.114195
# 	ウィンドウ: 0.105604
# 	投票: 0.103771
# 	判定: 0.094017
# 597 たった1バイトの書き込みが引き起こすルート権限での実行の脆弱性
# 	確保: 0.362146
# 	メモリ: 0.305672
# 	悪用: 0.229778
# 	攻撃: 0.224592
# 	バッファ: 0.221542
# 	領域: 0.218254
# 	解放: 0.174302
# 	書き込む: 0.164957
# 	関数: 0.164808
# 	フラグ: 0.162200
# 663 Riotのオンラインサービス運用:第1部
# 	プレイヤ: 0.394500
# 	コンテナ: 0.334861
# 	アプリケーション: 0.247327
# 	ネットワーク: 0.207977
# 	チーム: 0.206011
# 	オーバレイ: 0.200327
# 	インフラ: 0.153341
# 	スケジューリング: 0.141348
# 	サーバ: 0.139477
# 	環境: 0.116321
# 583 何でもSSHでやってしまいませんか?
# 	サーバー: 0.586973
# 	接続: 0.295054
# 	認証: 0.199987
# 	チャネル: 0.193497
# 	フィンガー: 0.192556
# 	ホスト: 0.172360
# 	プリント: 0.159093
# 	プロトコル: 0.128052
# 	対応: 0.126301
# 	だって: 0.125422
# 1 500バイトの画像:Haikuのベクターアイコン形式 – 後編
# 	バイト: 0.494264
# 	パス: 0.437779
# 	シェイプ: 0.435109
# 	座標: 0.254679
# 	セグメント: 0.244039
# 	フラグ: 0.195605
# 	ビット: 0.150240
# 	コマンド: 0.149446
# 	曲線: 0.138119
# 	形式: 0.111017
# 775 500バイトの画像:Haikuのベクターアイコン形式 – 前編
# 	グラデーション: 0.381638
# 	バイト: 0.298925
# 	アイコ: 0.261361
# 	ファイル: 0.257362
# 	スタイル: 0.256203
# 	ビット: 0.239057
# 	サイズ: 0.210689
# 	画像: 0.203206
# 	パス: 0.184466
# 	マップ: 0.182754
# 464 逆畳み込みネットワークによる顔の生成
# 	ネットワーク: 0.473399
# 	補間: 0.295606
# 	畳み込む: 0.291473
# 	感情: 0.285578
# 	向き: 0.274747
# 	人物: 0.225617
# 	イス: 0.216947
# 	訓練: 0.186858
# 	描く: 0.152338
# 	イメージ: 0.151599
# 43 Reduxのパターンとアンチパターン
# 	アクション: 0.556956
# 	関数: 0.200598
# 	不変: 0.185721
# 	ローン: 0.175485
# 	ディスパッチ: 0.154926
# 	幾つ: 0.145646
# 	更新: 0.144152
# 	ロジック: 0.122715
# 	引き起こす: 0.121546
# 	複製: 0.120736
# 521 コンピュータービジョン症候群
# 	休憩: 0.509129
# 	症候群: 0.275509
# 	まばたく: 0.172828
# 	コンピューター: 0.169961
# 	テレビ: 0.166083
# 	ビジョン: 0.145794
# 	コンピュータ: 0.144342
# 	画面: 0.126920
# 	間隔: 0.124562
# 	天井: 0.122287
# 282 try { return } finally {}
# 	ブロック: 0.646788
# 	変数: 0.339770
# 	ローカル: 0.324637
# 	スタック: 0.246304
# 	格納: 0.192189
# 	例外: 0.173010
# 	クリーンアップ: 0.127066
# 	終了: 0.120037
# 	中断: 0.117034
# 	答え: 0.112160
# 270 Q. なぜ”B”と表示するのは”#”と表示するよりも著しく遅いのか?
# 	マトリックス: 0.481391
# 	折り返す: 0.399204
# 	折り返し: 0.373600
# 	出力: 0.190213
# 	かかる: 0.179680
# 	文字: 0.142256
# 	端末: 0.131117
# 	著しい: 0.131117
# 	表示: 0.130027
# 	計測: 0.126121
# 58 DRYと不当な抽象化によるコストについて
# 	抽象: 0.714858
# 	原則: 0.197812
# 	重複: 0.134163
# 	コスト: 0.131526
# 	不当: 0.123626
# 	ケース: 0.107740
# 	変人: 0.102716
# 	読む: 0.099383
# 	カプセル: 0.095340
# 	他人: 0.088833
# 626 San Franciscoのアパート探しに役立つSlack bot制作記
# 	物件: 0.841168
# 	座標: 0.188362
# 	アパート: 0.170862
# 	情報: 0.156880
# 	地域: 0.142599
# 	投稿: 0.125007
# 	取得: 0.103080
# 	エリア: 0.085182
# 	価格: 0.084627
# 	ボックス: 0.084260
# 539 Railsアプリケーションを、Heroku上で1分間125,000リクエストに対応できるようにスケーリングする
# 	テスト: 0.332405
# 	レスポンスタイム: 0.313764
# 	テナント: 0.280419
# 	入学: 0.183353
# 	写真: 0.154758
# 	接続: 0.142703
# 	パフォーマンス: 0.142288
# 	データベース: 0.138974
# 	多忙: 0.134107
# 	負荷: 0.130393
# 658 『茹でたニンジン』 : ソフトウェア開発の失敗と技術について
# 	ニンジン: 0.585627
# 	技術: 0.398812
# 	茹でる: 0.319433
# 	調理: 0.239892
# 	リス: 0.131194
# 	料理: 0.118922
# 	失敗: 0.113528
# 	チーム: 0.103170
# 	シェフ: 0.095957
# 	ツール: 0.081473
# 393 バックグラウンドジョブの改善によってRailsのパフォーマンスを高める
# 	ユーザ: 0.349403
# 	消費: 0.306601
# 	メモリ: 0.303176
# 	測定: 0.175978
# 	アプリケーション: 0.172186
# 	プロセス: 0.171385
# 	インスタンス: 0.169206
# 	購読: 0.142321
# 	エラー: 0.142080
# 	メール: 0.141561
# 245 CSSになり損ねた言語たち
# 	スタイル: 0.431799
# 	シート: 0.424641
# 	文書: 0.282589
# 	言語: 0.275447
# 	提案: 0.261384
# 	スタイリング: 0.214164
# 	サポート: 0.108998
# 	シンタックス: 0.108916
# 	ページ: 0.105249
# 	当時: 0.099476
# 231 情報理論を視覚的に理解する （4/4）
# 	理論: 0.355395
# 	情報: 0.329771
# 	エントロピー: 0.315592
# 	ビット: 0.281110
# 	分布: 0.228405
# 	確率: 0.209837
# 	量子: 0.163723
# 	自信: 0.161231
# 	力学: 0.154690
# 	小数: 0.151105
# 139 情報理論を視覚的に理解する （3/4）
# 	エントロピー: 0.531262
# 	情報: 0.420798
# 	分布: 0.336888
# 	交差: 0.319064
# 	変数: 0.144342
# 	表記: 0.143928
# 	天候: 0.134992
# 	偏差: 0.130902
# 	相互: 0.105433
# 	図表: 0.103824
# 75 情報理論を視覚的に理解する （2/4）
# 	ワード: 0.885337
# 	予算: 0.195073
# 	コスト: 0.164525
# 	長い: 0.142422
# 	短い: 0.115856
# 	メッセージ: 0.109235
# 	平均: 0.100645
# 	ビット: 0.081017
# 	増分: 0.080889
# 	発生: 0.079679
# 747 情報理論を視覚的に理解する （1/4） :
# 	着る: 0.425861
# 	コート: 0.389461
# 	確率: 0.375837
# 	治療: 0.331644
# 	降る: 0.270930
# 	ワード: 0.216517
# 	結石: 0.180697
# 	患者: 0.157094
# 	視覚: 0.135869
# 	単語: 0.133842
# 491 『DOOM』（2016）-グラフィックス研究 – 後編
# 	ぼかし: 0.506626
# 	ピクセル: 0.267072
# 	ガラス: 0.259282
# 	歪み: 0.219392
# 	マップ: 0.199614
# 	シーン: 0.193001
# 	適用: 0.179677
# 	屈折: 0.169967
# 	解像度: 0.166757
# 	深度: 0.159558
# 328 『DOOM』（2016）-グラフィックス研究 – 前編
# 	深度: 0.644586
# 	ライト: 0.320580
# 	クラスタ: 0.304603
# 	マップ: 0.219057
# 	メッシュ: 0.198065
# 	タイル: 0.188481
# 	テクスチャ: 0.172459
# 	プレーヤー: 0.123139
# 	計算: 0.120568
# 	ピクセル: 0.111372
# 516 そのJavaScriptの関数は本当に純粋関数?
# 	純粋: 0.749228
# 	関数: 0.394752
# 	数学: 0.200121
# 	振る舞う: 0.154242
# 	想定: 0.137795
# 	振る舞い: 0.131423
# 	改ざん: 0.109514
# 	配列: 0.092302
# 	正解: 0.068764
# 	壊せる: 0.068243
# 584 RxJavaのレシピ:Androidのイベントをストリームに変換する
# 	購読: 0.428620
# 	イベント: 0.310920
# 	音楽: 0.239636
# 	オペレータ: 0.214310
# 	登録: 0.208715
# 	発行: 0.204815
# 	著作: 0.169524
# 	再生: 0.167699
# 	プロデューサ: 0.157908
# 	部屋: 0.152102
# 604 WebSocket大合戦:Clojure、C++、Elixir、Go、NodeJS、Ruby
# 	ブロードキャスト: 0.523116
# 	サーバ: 0.376783
# 	接続: 0.356700
# 	メッセージ: 0.256882
# 	送信: 0.191204
# 	ロック: 0.183586
# 	ベンチマーク: 0.141551
# 	並列: 0.139618
# 	チャネル: 0.123842
# 	抽象: 0.111969
# 82 機械学習に挑んだ一年間 – 機械学習について一から学び、仕事に活用するまでの道のり
# 	機械: 0.485538
# 	学習: 0.483245
# 	コース: 0.293304
# 	週間: 0.147288
# 	コーディング: 0.136069
# 	受講: 0.123772
# 	勉強: 0.121541
# 	習得: 0.112056
# 	挑む: 0.106162
# 	仕事: 0.097042
# 226 FlyWeb―Mozillaによる、完全Web型のクロスデバイス・インタラクションの実験プロジェクト
# 	アプリケーション: 0.315750
# 	ローカル: 0.296651
# 	サーバ: 0.280451
# 	ネットワーク: 0.214454
# 	デバイス: 0.214425
# 	ユーザ: 0.213576
# 	ハッカー: 0.193542
# 	メニュー: 0.177787
# 	エリア: 0.166463
# 	モバイル: 0.146151
# 62 Pythonに咬まれるな : 注意すべきセキュリティリスクのリスト
# 	ファイル: 0.289734
# 	オブジェクト: 0.208517
# 	モジュール: 0.203396
# 	属性: 0.202230
# 	関数: 0.189693
# 	テンプレート: 0.174353
# 	一時: 0.168814
# 	危険: 0.164977
# 	シェル: 0.164326
# 	ポート: 0.145013
# 690 Bluebirdの高速化を可能にする、3つのJavaScriptパフォーマンスの基礎
# 	オブジェクト: 0.478078
# 	関数: 0.454561
# 	フィールド: 0.293805
# 	整数: 0.182844
# 	インライン: 0.154311
# 	割り当て: 0.149825
# 	呼び出す: 0.146649
# 	ビット: 0.146355
# 	フック: 0.133489
# 	割り当てる: 0.125840
# 353 プログラミングのサイドプロジェクトを始めたいきさつ
# 	プロジェクト: 0.454042
# 	ポートフォリオ: 0.267085
# 	学生: 0.150721
# 	経験: 0.142187
# 	ソフトウェア: 0.140148
# 	デザイン: 0.139423
# 	プログラミング: 0.127455
# 	教科書: 0.123923
# 	実践: 0.118944
# 	インターン: 0.115659
# 113 Git Undo エイリアスを定義する
# 	コミット: 0.512709
# 	ブランチ: 0.451566
# 	履歴: 0.325253
# 	参照: 0.239756
# 	エントリ: 0.219803
# 	指定: 0.137848
# 	直前: 0.122233
# 	シェル: 0.121482
# 	コマンド: 0.121264
# 	入力: 0.118106
# 682 GitHubのコード検索 : プログラマにとっての宝の山
# 	検索: 0.342087
# 	プロジェクト: 0.240666
# 	ファイル: 0.218068
# 	ドキュメント: 0.217876
# 	探す: 0.210364
# 	見つける: 0.207020
# 	解決: 0.190725
# 	学ぶ: 0.188436
# 	誰か: 0.167809
# 	興味: 0.156839
# 462 会話型UIの未来はハイブリッドインターフェースだ
# 	会話: 0.559395
# 	メッセージ: 0.324917
# 	リッチ: 0.288931
# 	テキスト: 0.250276
# 	インターフェース: 0.182400
# 	コンピュータ: 0.153550
# 	メッセンジャー: 0.151408
# 	アプリケーション: 0.148358
# 	コマンド: 0.131937
# 	デザイン: 0.101983
# 266 C/C++中規模プロジェクトのための超シンプルなMakefile
# 	ファイル: 0.469506
# 	ディレクトリ: 0.447143
# 	ソース: 0.299065
# 	生成: 0.296024
# 	依存: 0.169455
# 	オブジェクト: 0.163316
# 	ヘッダ: 0.160150
# 	関係: 0.141767
# 	コンパイル: 0.132679
# 	フラグ: 0.131600
# 814 高速なハッシュテーブルを設計する
# 	ハッシュ: 0.677208
# 	テーブル: 0.360572
# 	キー: 0.229841
# 	設計: 0.174298
# 	目標: 0.156016
# 	探索: 0.120211
# 	決定: 0.117544
# 	要素: 0.116822
# 	ビット: 0.113934
# 	バケット: 0.113661
# 672 ゲームをプレイするアルゴリズムを選択するためのアルゴリズム
# 	ゲーム: 0.674378
# 	アルゴリズム: 0.533619
# 	エージェント: 0.184285
# 	ビデオ: 0.159585
# 	選択: 0.094941
# 	知能: 0.076718
# 	パフォーマンス: 0.075729
# 	撃つ: 0.074623
# 	ジャンル: 0.068855
# 	人間: 0.060910
# 10 Go言語の低レイテンシGC実現のための取り組み
# 	停止: 0.433086
# 	メモリ: 0.339274
# 	チャット: 0.295861
# 	フェーズ: 0.272839
# 	スタック: 0.240323
# 	マーク: 0.191799
# 	カーネル: 0.173696
# 	終了: 0.170360
# 	プログラム: 0.137273
# 	ミリ: 0.136829
# 518 「Erlangを使用して、効率的な決済システムを構築するには?」
# 	小節: 0.405211
# 	弾く: 0.281826
# 	ショパン: 0.243126
# 	演奏: 0.227593
# 	解決: 0.196313
# 	規制: 0.190895
# 	批判: 0.184591
# 	金融: 0.178253
# 	専門: 0.168226
# 	右手: 0.162084
# 291 RustとDNSの1年
# 	サーバ: 0.227273
# 	頂上: 0.212610
# 	メモリ: 0.182398
# 	言語: 0.177527
# 	テスト: 0.170709
# 	セーフ: 0.167400
# 	リーク: 0.164281
# 	登る: 0.163036
# 	例外: 0.144698
# 	エラー: 0.139725
# 444 C90, C99, C11, C++98, C++11で異なる動作をするコード
# 	文字: 0.413889
# 	ワイド: 0.334454
# 	マクロ: 0.325353
# 	リテラル: 0.243472
# 	コンパイル: 0.232786
# 	言語: 0.228605
# 	定数: 0.223120
# 	評価: 0.204339
# 	プログラム: 0.204054
# 	規格: 0.197726
# 345 恐竜とLisp : Chromeの「インターネット接続がありません」画面をLispでプレイする
# 	恐竜: 0.749951
# 	サボテン: 0.459390
# 	前かがみ: 0.194357
# 	ジャンプ: 0.181455
# 	スクリーン: 0.140176
# 	画素: 0.110711
# 	形状: 0.100779
# 	ゲーム: 0.092444
# 	キー: 0.080521
# 	タイミング: 0.066416
# 691 React Fiberアーキテクチャについて
# 	ツリー: 0.276652
# 	作業: 0.273356
# 	スタック: 0.259739
# 	スケジューリング: 0.250548
# 	コンポーネント: 0.235212
# 	更新: 0.225494
# 	フレーム: 0.205084
# 	順位: 0.193918
# 	優先: 0.188033
# 	関数: 0.171160
# 485 私たちがAmazon Web ServicesからGoogle Cloud Platformに乗り換えた理由
# 	追記: 0.313556
# 	料金: 0.221256
# 	ワーキング: 0.159030
# 	単位: 0.144858
# 	フレキシブル: 0.132315
# 	ネット: 0.132158
# 	プロダクト: 0.124472
# 	接続: 0.123576
# 	アカウント: 0.122249
# 	セットアップ: 0.115880
# 3 NoSQLデータベース:調査と決定のガイダンス（その3）
# 	データベースシステム: 0.271078
# 	インデックス: 0.267677
# 	データベース: 0.234379
# 	システム: 0.225054
# 	要件: 0.221735
# 	可用性: 0.165731
# 	分析: 0.161881
# 	バッチ: 0.144880
# 	スループット: 0.140944
# 	述語: 0.130483
# 197 NoSQLデータベース:調査と決定のガイダンス（その2）
# 	要件: 0.445244
# 	書き込み: 0.304751
# 	読み取り: 0.237127
# 	技術: 0.215399
# 	図示: 0.195772
# 	ストレージ: 0.179970
# 	可用性: 0.171148
# 	マネジメント: 0.160928
# 	設計: 0.156217
# 	トランザクション: 0.151836
# 673 NoSQLデータベース:調査と決定のガイダンス（その1）
# 	一貫: 0.353393
# 	可用性: 0.337399
# 	分断: 0.289490
# 	ストア: 0.260153
# 	定理: 0.249756
# 	システム: 0.234050
# 	ファミリ: 0.175868
# 	トレードオフ: 0.175799
# 	キー: 0.157928
# 	データベースシステム: 0.139126
# 380 『なぜUber EngineeringはPostgresからMySQLに切り替えたのか』について : RavenDB創始者の見地から
# 	キャッシュ: 0.351200
# 	複製: 0.287450
# 	ディスク: 0.257589
# 	書き込み: 0.242320
# 	ページ: 0.241328
# 	接続: 0.190019
# 	コール: 0.184291
# 	レコード: 0.165333
# 	フォーマット: 0.159103
# 	コスト: 0.155345
# 503 なぜUber EngineeringはPostgresからMySQLに切り替えたのか
# 	マスタ: 0.330622
# 	ディスク: 0.318900
# 	インデックス: 0.316799
# 	更新: 0.287424
# 	データベース: 0.235838
# 	出生: 0.234494
# 	トランザクション: 0.186835
# 	テーブル: 0.182922
# 	レコード: 0.147494
# 	接続: 0.145300
# 50 Haskellと共に4年間を歩んだ起業家の視点
# 	言語: 0.263562
# 	ライブラリ: 0.213370
# 	人材: 0.161116
# 	社名: 0.155078
# 	雇用: 0.154007
# 	思い: 0.135037
# 	バグ: 0.134568
# 	素晴らしい: 0.127626
# 	テスト: 0.126381
# 	推論: 0.117154
# 91 Pythonの内部構造::PyObject ― CPythonの実装から内部に迫る
# 	オブジェクト: 0.622001
# 	マクロ: 0.264847
# 	プロトコル: 0.263811
# 	メンバ: 0.217912
# 	関数: 0.208335
# 	シーケンス: 0.184998
# 	実装: 0.167404
# 	フィールド: 0.165732
# 	辞書: 0.138437
# 	定義: 0.128703
# 39 gh-ost:GitHubのMySQL向けオンライン・スキーマ・マイグレーションツール
# 	テーブル: 0.508890
# 	トリガ: 0.436806
# 	マスター: 0.326850
# 	スロット: 0.208563
# 	リング: 0.166620
# 	ロック: 0.145488
# 	負荷: 0.128196
# 	停止: 0.128181
# 	スキーマ: 0.117692
# 	一時: 0.109887
# 724 GoogleのQUICプロトコル:TCPからUDPへWebを移行する
# 	パケット: 0.495819
# 	プロトコル: 0.386939
# 	接続: 0.354712
# 	トランスポート: 0.240645
# 	多重: 0.191930
# 	サーバ: 0.180349
# 	次世代: 0.162540
# 	出典: 0.149538
# 	ポート: 0.133963
# 	介す: 0.131343
# 360 世界最速のフォントレンダラ、font-rsの内部に迫る
# 	パーサー: 0.250039
# 	ピクセル: 0.228265
# 	描画: 0.199000
# 	累積: 0.182760
# 	面積: 0.176596
# 	フォント: 0.164884
# 	解析: 0.155865
# 	アウトライン: 0.146114
# 	合計: 0.145020
# 	速い: 0.143474
# 557 WebkitがES6の機能を完備 : RegExpを例に、パフォーマンスのための取り組みを詳解する
# 	オブジェクト: 0.659894
# 	プロトタイプ: 0.308031
# 	条件: 0.232507
# 	ルック: 0.191594
# 	識別子: 0.176269
# 	最適: 0.163983
# 	チェーン: 0.148311
# 	オフセット: 0.140305
# 	チェック: 0.109067
# 	格納: 0.104563
# 537 Pythonコードを使用して、Pythonコードを書く方法を人工知能に学習させる
# 	学習: 0.506769
# 	ネットワーク: 0.323198
# 	文字: 0.200638
# 	シーケンス: 0.187548
# 	括弧: 0.180109
# 	アウトプット: 0.177882
# 	ニューロン: 0.177353
# 	インスタンス: 0.127534
# 	インストラクション: 0.122703
# 	インデント: 0.104924
# 199 マイクロサービスの終焉
# 	サービス: 0.741382
# 	マイクロ: 0.198396
# 	ツール: 0.167611
# 	ハイウェイ: 0.154793
# 	構築: 0.128207
# 	構想: 0.117100
# 	プロダクションシステム: 0.109526
# 	スーパー: 0.108131
# 	アプリケーション: 0.106172
# 	トレーシング: 0.095220
# 661 Amazonのソフトウェアエンジニア面接
# 	面接: 0.774362
# 	採用: 0.154017
# 	担当: 0.129612
# 	分間: 0.123469
# 	質問: 0.123079
# 	ベルリン: 0.107405
# 	解決: 0.101045
# 	オフィス: 0.090095
# 	内定: 0.089386
# 	解く: 0.087012
# 239 Pythonパッケージ間の共起関係を可視化してみる
# 	クラスタ: 0.612395
# 	エッジ: 0.349974
# 	パッケージ: 0.301274
# 	シミュレーション: 0.218934
# 	グラフ: 0.206005
# 	ノード: 0.191367
# 	重み: 0.134715
# 	テーブル: 0.123415
# 	中心: 0.114188
# 	積分: 0.104921
# 298 初心者のためのSQLガイド???? : SQLを直感的に理解しよう
# 	テーブル: 0.583197
# 	蔵書: 0.367419
# 	結合: 0.224789
# 	集約: 0.223863
# 	次元: 0.194794
# 	取得: 0.185490
# 	借りる: 0.167648
# 	見せる: 0.117132
# 	著者: 0.113046
# 	指定: 0.108528
# 397 「有害なgoto」「時期尚早な最適化」、そしてプログラミングにまつわる神話は諸悪の根源である
# 	論文: 0.465047
# 	神話: 0.280749
# 	コロンブス: 0.238422
# 	プログラミング: 0.202872
# 	地球: 0.188822
# 	プログラム: 0.171366
# 	タイトル: 0.139756
# 	航海: 0.124801
# 	述べる: 0.123091
# 	平ら: 0.099841
# 81 暗号化と圧縮、どちらを先にするべきか?
# 	暗号: 0.395053
# 	圧縮: 0.327496
# 	信号: 0.301862
# 	励振: 0.288085
# 	音素: 0.288085
# 	音声: 0.193960
# 	ブック: 0.174391
# 	あなた: 0.170832
# 	攻撃: 0.146075
# 	符号: 0.137676
# 756 モジュロ演算の替わりとなる高速処理
# 	倍数: 0.524960
# 	区間: 0.428087
# 	モジュロ: 0.280821
# 	マッピング: 0.233773
# 	公平: 0.232157
# 	演算: 0.214732
# 	ビット: 0.186054
# 	除算: 0.154400
# 	サイクル: 0.153397
# 	整数: 0.142370
# 755 可変性の回避 ― Rubyへの関数型プログラミングスタイルの適用
# 	可変: 0.578503
# 	不変: 0.350170
# 	非破壊: 0.324242
# 	パフォーマンス: 0.252270
# 	更新: 0.166891
# 	複製: 0.159750
# 	配列: 0.146287
# 	永続: 0.122233
# 	回避: 0.120593
# 	構造: 0.104970
# 20 iOS 10とMac OSにおけるニューラルネットワーク
# 	畳み込む: 0.494862
# 	画像: 0.327151
# 	ピクセル: 0.243082
# 	機械: 0.220823
# 	行列: 0.214446
# 	学習: 0.206206
# 	結合: 0.184901
# 	活性: 0.175024
# 	入力: 0.170897
# 	ベクトル: 0.166779
# 311 私がどのようにしてキーロガーをクラックし、最終的に第三者の受信トレイに行きついたか
# 	ロガー: 0.593817
# 	画像: 0.317013
# 	キー: 0.295792
# 	感染: 0.264354
# 	メール: 0.231490
# 	攻撃: 0.188880
# 	ルーチン: 0.165780
# 	脆弱: 0.152940
# 	ファイル: 0.146000
# 	メールアドレス: 0.130106
# 229 Angular 2アプリケーションをimmutable.jsとReduxで構築する
# 	コンポーネント: 0.362936
# 	不変: 0.336916
# 	アクション: 0.318395
# 	アプリケーション: 0.311143
# 	連絡: 0.235252
# 	状態: 0.222771
# 	オブジェクト: 0.173168
# 	すべて: 0.159952
# 	ストア: 0.151697
# 	メソッド: 0.125052
# 571 あなたはCSSプロパティ”display”をどのぐらい知っているだろうか?
# 	レイアウト: 0.544120
# 	要素: 0.404079
# 	アイテム: 0.263273
# 	一覧: 0.218763
# 	仕様: 0.200382
# 	ふるまう: 0.164576
# 	相当: 0.148603
# 	コンテナ: 0.127090
# 	ボックス: 0.116551
# 	スペース: 0.115649
# 797 Dropboxが構築したMagic Pocketの中身:エクサバイトのストレージシステムの仕組み
# 	ボリューム: 0.548693
# 	セル: 0.316344
# 	ブロック: 0.313557
# 	マスター: 0.275301
# 	バケット: 0.232591
# 	ゾーン: 0.154202
# 	消失: 0.141140
# 	ストレージ: 0.136970
# 	プロトコル: 0.117008
# 	訂正: 0.113642
# 608 効率的な統計実践のための、10個のシンプルなルール
# 	統計: 0.634459
# 	ルール: 0.280121
# 	分析: 0.242920
# 	科学: 0.211486
# 	ばらつき: 0.202534
# 	測定: 0.158148
# 	学者: 0.122991
# 	研究: 0.113617
# 	実験: 0.096189
# 	シンプル: 0.089543
# 496 動的配列について – JavaのLinkedListとArrayListを分析・比較する
# 	挿入: 0.390489
# 	メソッド: 0.262394
# 	割り当て: 0.235335
# 	配列: 0.204047
# 	要素: 0.179588
# 	動的: 0.169583
# 	テスト: 0.147430
# 	ランダム: 0.131362
# 	計測: 0.128857
# 	命令: 0.128586
# 381 Androidの10ms問題?解決しました！ : Superpowered Media Serverの紹介
# 	オーディオ: 0.833089
# 	デバイス: 0.246679
# 	往復: 0.169037
# 	メディア: 0.161581
# 	バッファ: 0.130374
# 	サーバ: 0.090742
# 	測定: 0.089497
# 	インストール: 0.083569
# 	アウト: 0.079544
# 	ドロップ: 0.077336
# 27 RailsのAPIにHATEOASを散りばめてみる : RESTの拡張、HATEOASの詳解と実装例
# 	リソース: 0.604938
# 	レベル: 0.201140
# 	ポイント: 0.183891
# 	アダプタ: 0.181963
# 	リクエスト: 0.175686
# 	属性: 0.173362
# 	エンド: 0.172948
# 	フォーマット: 0.166853
# 	仕様: 0.145964
# 	アクション: 0.127481
# 614 Linuxシステムコール徹底ガイド
# 	コール: 0.554847
# 	カーネル: 0.407880
# 	システム: 0.333987
# 	割り込み: 0.269380
# 	アセンブリ: 0.195042
# 	特権: 0.183408
# 	アドレス: 0.150362
# 	レジスタ: 0.149635
# 	プログラム: 0.138230
# 	復帰: 0.132354
# 108 勾配降下法の最適化アルゴリズムを概観する
# 	勾配: 0.722570
# 	降下: 0.567020
# 	バッチ: 0.201204
# 	更新: 0.116090
# 	アルゴリズム: 0.112664
# 	パラメータ: 0.104958
# 	最適: 0.082533
# 	学習: 0.068881
# 	計算: 0.065486
# 	確率: 0.053619
# ...
# 	レイヤ: 0.220627
# 	業界: 0.186431
# 	カモ: 0.161348
# 	ジミー: 0.161348
# 	アヒル: 0.145405
# 	アニメーション: 0.127680
# 	おもちゃ: 0.124330
# 	クイーン: 0.121011
# 773 分散型メッセージングミドルウェアの詳細比較
# 	メッセージ: 0.571533
# 	スループット: 0.304640
# 	ブローカ: 0.278486
# 	メッセージキュー: 0.266340
# 	ブロー: 0.260794
# 	カード: 0.157717
# 	送信: 0.151931
# 	キュー: 0.143008
# 	受信: 0.131372
# 	分散: 0.126083
# 369 Sqwiggleが最初の課金ユーザを獲得した3つの方法
# 	製品: 0.517170
# 	弊社: 0.284983
# 	市場: 0.155383
# 	ネル: 0.149774
# 	ファ: 0.145872
# 	創業: 0.121962
# 	ドリップ: 0.111548
# 	取引: 0.109889
# 	顧客: 0.108292
# 	日間: 0.101123
# 551 エドガー・ダイクストラが綴った「”自然言語プログラミング”の愚かしさについて」
# 	機械: 0.429437
# 	母国: 0.343221
# 	記号: 0.273602
# 	体系: 0.213499
# 	インターフェース: 0.143478
# 	無意味: 0.140387
# 	形式: 0.134424
# 	プログラミング: 0.123071
# 	無分別: 0.119383
# 	西欧: 0.119383
# 440 PythonでTCPスタックを記述するとどうなる?
# 	パケット: 0.751933
# 	シーケンス: 0.276038
# 	番号: 0.249894
# 	応答: 0.207695
# 	送る: 0.141868
# 	送信: 0.119046
# 	消える: 0.112382
# 	スタック: 0.107581
# 	ステップ: 0.106178
# 	交信: 0.092077
# 269 リーダブル・コードを書く
# 	ハルク: 0.423824
# 	コメント: 0.274382
# 	メソッド: 0.210617
# 	可読性: 0.153632
# 	プログラム: 0.142422
# 	コンピュータ: 0.122513
# 	細かい: 0.115704
# 	コンパクト: 0.115224
# 	明快: 0.115224
# 	名前: 0.112415
# 617 iOSインディーズゲームはApp storeでは勝てない?数字データから見えるもの
# 	ゲーム: 0.528925
# 	収入: 0.281936
# 	ダウンロード: 0.237046
# 	ワード: 0.162760
# 	解除: 0.157526
# 	リリース: 0.145060
# 	課金: 0.144414
# 	ロック: 0.143518
# 	有料: 0.137885
# 	レビュー: 0.128688
# 649 シリコンバレーとEdTech革命
# 	シリコンバレー: 0.456500
# 	エド: 0.427106
# 	教育: 0.343758
# 	テック: 0.342468
# 	カーン: 0.236968
# 	投資: 0.116387
# 	ブレンド: 0.106776
# 	ボストン: 0.106776
# 	幼稚園: 0.106776
# 	サル: 0.103007
# 722 Mac OS X Yosemite のデザイン
# 	アイコ: 0.364277
# 	ボタン: 0.313028
# 	エレメント: 0.259950
# 	明るい: 0.253439
# 	アップデート: 0.170337
# 	バー: 0.166598
# 	すっきり: 0.164774
# 	ビジュアル: 0.159887
# 	透明: 0.154281
# 	ファインダー: 0.147172
# 449 MediumのCSSはこの上なく最高！
# 	スタイル: 0.349593
# 	スケール: 0.282372
# 	クラス: 0.224907
# 	プロジェクト: 0.185831
# 	コンポーネント: 0.180377
# 	プレフィックス: 0.176870
# 	付ける: 0.144270
# 	テンプレート: 0.143925
# 	画像: 0.128567
# 	ガイド: 0.123928
# 268 フロントエンドのプログラミング言語をゼロから設計した理由
# 	言語: 0.354421
# 	巨人: 0.267138
# 	未来: 0.203606
# 	エンド: 0.194834
# 	フロント: 0.189551
# 	プログラミング: 0.174619
# 	改革: 0.155247
# 	形作る: 0.152279
# 	オープン: 0.119708
# 	コミュニティ: 0.117203
# 334 リモートワークチーム用の究極のツールボックス:必須ツール15選
# 	無料: 0.392419
# 	ツール: 0.295386
# 	あり: 0.293034
# 	コラボレーション: 0.264274
# 	共有: 0.216163
# 	署名: 0.196811
# 	すばらしい: 0.186347
# 	月額: 0.158977
# 	チーム: 0.157494
# 	作家: 0.146725
# 535 デバッグを必修科目にするべき理由
# 	ブレーク: 0.525434
# 	デバッグ: 0.383850
# 	ポイント: 0.260656
# 	ロギング: 0.195824
# 	ステップ: 0.176680
# 	バグ: 0.139002
# 	不慣れ: 0.136417
# 	プログラマー: 0.131009
# 	リモート: 0.116877
# 	見つける: 0.089405
# 527 Dockerコンテナ内でsshdを実行してはいけない理由
# 	コンテナ: 0.772029
# 	ボリューム: 0.335418
# 	起動: 0.162516
# 	サービス: 0.153143
# 	ソケット: 0.110995
# 	サーバ: 0.106117
# 	シェル: 0.100487
# 	シグナル: 0.094965
# 	ホスト: 0.092265
# 	アクセス: 0.089553
# 615 抽象化と組み合わせができるレイアウト言語があれば、CSSは必要ない
# 	抽象: 0.362552
# 	手段: 0.320153
# 	言語: 0.249589
# 	レイアウト: 0.243523
# 	場当たり: 0.218234
# 	デザイナー: 0.148612
# 	了解: 0.145490
# 	だから: 0.133256
# 	組み合わせ: 0.118672
# 	高水準: 0.115454
# 35 Clojureだと生産性が上がるわけ
# 	言語: 0.477389
# 	プロジェクト: 0.186881
# 	解答: 0.166011
# 	特徴: 0.153483
# 	ドライバー: 0.130956
# 	落ち込む: 0.130956
# 	インタラクティブ: 0.128806
# 	冗長: 0.123482
# 	解決: 0.112839
# 	当初: 0.110432
# 573 私を魅了した起業家について
# 	面談: 0.337285
# 	プログラム: 0.302630
# 	アイディア: 0.236641
# 	エンジニアリング: 0.194612
# 	プログラマー: 0.180249
# 	援助: 0.174169
# 	学生: 0.158874
# 	支援: 0.152706
# 	業界: 0.129734
# 	コミットメント: 0.122017
# 655 Goのガーベジコレクタを視覚化するツール
# 	ヒープ: 0.383484
# 	オペレーティングシステム: 0.328494
# 	メモリ: 0.263687
# 	報告: 0.215873
# 	プログラム: 0.193058
# 	プレフィックス: 0.155997
# 	出力: 0.150365
# 	ライブ: 0.142661
# 	デバッグ: 0.141179
# 	記録: 0.140752
# 88 型安全性とは何か
# 	安全: 0.531923
# 	言語: 0.403898
# 	プログラム: 0.353539
# 	システム: 0.242630
# 	正しく: 0.156708
# 	定義: 0.156242
# 	保証: 0.152717
# 	不正: 0.144374
# 	型付け: 0.137780
# 	動作: 0.135168
# 660 クラスの「継承」より「合成」がよい理由とは?ゲーム開発におけるコードのフレキシビリティと可読性の向上
# 	継承: 0.734367
# 	ひし形: 0.259643
# 	合成: 0.254515
# 	クラス: 0.206883
# 	キャラクター: 0.200073
# 	用いる: 0.116577
# 	構造: 0.113140
# 	ゲーム: 0.099736
# 	可読性: 0.094118
# 	絡み合う: 0.087417
# 406 Haskellを愛する若者たちへ
# 	あなた: 0.361992
# 	相手: 0.255908
# 	知識: 0.228680
# 	数学: 0.213744
# 	学ぶ: 0.193342
# 	言動: 0.145777
# 	アドバイス: 0.140920
# 	手紙: 0.122947
# 	アイデア: 0.121386
# 	プログラミング: 0.118077
# 78 機械学習のレベル別学習法
# 	学習: 0.486790
# 	機械: 0.461928
# 	ブック: 0.300187
# 	知識: 0.259331
# 	テキスト: 0.179311
# 	本書: 0.141700
# 	能力: 0.126059
# 	代数: 0.121646
# 	仕上げ: 0.119508
# 	ベイズ: 0.107265
# 652 Rubyにはウンザリ！動的型付け、副作用、およびオブジェクト指向プログラミング全般からの考察
# 	テスト: 0.447079
# 	オブジェクト: 0.264892
# 	指向: 0.210244
# 	理論: 0.140212
# 	副作用: 0.139000
# 	言語: 0.136746
# 	完ぺき: 0.126549
# 	ハマる: 0.114352
# 	駆動: 0.113357
# 	数学: 0.109451
# 727 爆速HTML – Elmでの仮想DOM
# 	抽象: 0.295087
# 	差分: 0.272024
# 	仮想: 0.252638
# 	不変: 0.231617
# 	検出: 0.210703
# 	純粋: 0.168375
# 	ライブラリ: 0.153906
# 	プロフィール: 0.152141
# 	アプローチ: 0.146744
# 	速度: 0.144381
# 118 関数型プログラマのためのRust
# 	オブジェクト: 0.408281
# 	参照: 0.303075
# 	言語: 0.259106
# 	ボックス: 0.236492
# 	寿命: 0.196214
# 	マクロ: 0.189649
# 	記憶: 0.168254
# 	所有: 0.145463
# 	リテラル: 0.141920
# 	シンタックス: 0.127127
# 101 機械学習の用語集:データ、学習とモデリング
# 	学習: 0.557844
# 	モデル: 0.406746
# 	機械: 0.293611
# 	データセット: 0.268427
# 	トレーニング: 0.259404
# 	バイアス: 0.250658
# 	用語: 0.137541
# 	インスタンス: 0.114252
# 	アルゴリズム: 0.113245
# 	成績: 0.108043
# 719 確率的プログラミングが重要な理由
# 	確率: 0.604956
# 	推論: 0.448779
# 	プログラミング: 0.276349
# 	プログラム: 0.165525
# 	物語: 0.158428
# 	言語: 0.144231
# 	モデル: 0.142108
# 	モデリング: 0.120085
# 	方向: 0.102288
# 	学習: 0.100277
# 271 ソフトウェアエンジニアリングにおける認知バイアス5つ
# 	バイアス: 0.537196
# 	認知: 0.206565
# 	報酬: 0.173754
# 	価値: 0.128463
# 	否定: 0.124551
# 	人間: 0.123001
# 	テスト: 0.119086
# 	投票: 0.113998
# 	見積もる: 0.106327
# 	割り引く: 0.100462
# 174 親愛なるGoogleへ
# 	メール: 0.358545
# 	サービス: 0.218158
# 	アカウント: 0.171215
# 	ユーザ: 0.169059
# 	料金: 0.132805
# 	連携: 0.130120
# 	彼ら: 0.125631
# 	生活: 0.124520
# 	検索: 0.114356
# 	広告: 0.112207
# 288 アスペクト指向プログラミング入門
# 	アドバイス: 0.451611
# 	アスペクト: 0.434042
# 	呼び出し: 0.240518
# 	関数: 0.232742
# 	ピックアップ: 0.231796
# 	ログ: 0.224134
# 	メッセージ: 0.192449
# 	送出: 0.177270
# 	例外: 0.174582
# 	メソッド: 0.153960
# 258 オーストラリアのスタートアップが成功しにくい理由
# 	税制: 0.335149
# 	オーストラリア: 0.258255
# 	案件: 0.253702
# 	スタート: 0.205240
# 	優遇: 0.157888
# 	大都市: 0.157888
# 	持ち株: 0.157888
# 	しくむ: 0.151016
# 	メルボルン: 0.151016
# 	国外: 0.151016
# 60 日常にある機械学習の応用例
# 	機械: 0.439372
# 	学習: 0.372988
# 	ユーザー: 0.250519
# 	モデル: 0.224248
# 	識別: 0.185475
# 	決定: 0.175563
# 	事例: 0.150011
# 	顧客: 0.130347
# 	不正: 0.122221
# 	手書き: 0.121262
# 326 まずコードの可読性を最適化しよう
# 	最適: 0.419412
# 	可読性: 0.277015
# 	尚早: 0.224115
# 	連結: 0.223929
# 	づらい: 0.190052
# 	グラフ: 0.162702
# 	時期: 0.157471
# 	読む: 0.147879
# 	メソッド: 0.121525
# 	メモリ: 0.120257
# 766 Python 2.7.x と 3.x の決定的な違いを例とともに
# 	メソッド: 0.325849
# 	関数: 0.227348
# 	除算: 0.208270
# 	括弧: 0.207721
# 	整数: 0.205761
# 	変化: 0.192845
# 	オブジェクト: 0.185118
# 	構文: 0.172738
# 	ルック: 0.156203
# 	内包: 0.150220
# 610 ジョエル・スポルスキによる『Trello, Inc.について』
# 	投資: 0.425894
# 	会社: 0.243320
# 	製品: 0.153713
# 	オフィス: 0.139841
# 	チーム: 0.130696
# 	キャピタル: 0.123613
# 	ベンチャー: 0.122017
# 	ボード: 0.119675
# 	お金: 0.119121
# 	マイケル: 0.108935
# 751 JPL（ジェット推進研究所）におけるLispの顛末
# 	ロボット: 0.302119
# 	ロビー: 0.258202
# 	エージェント: 0.209799
# 	ローバー: 0.189216
# 	リモート: 0.173557
# 	ミッション: 0.165847
# 	探査: 0.135154
# 	自律: 0.132642
# 	言語: 0.132307
# 	エンジニア: 0.128146
# 512 あなたにWebSocketは必要ないかも
# 	ロング: 0.458164
# 	ポーリング: 0.446094
# 	ストリーム: 0.294091
# 	エミュレート: 0.213471
# 	プロトコル: 0.180945
# 	同期: 0.169266
# 	送信: 0.140715
# 	通信: 0.128839
# 	双方向: 0.121693
# 	サーバ: 0.118839
# 419 OCaml入門の手引
# 	エディタ: 0.203367
# 	生産: 0.198094
# 	ツール: 0.182596
# 	知識: 0.172776
# 	言語: 0.169313
# 	リスク: 0.162955
# 	チェック: 0.148274
# 	ラン: 0.141846
# 	妥当: 0.136934
# 	コア: 0.128175
# 127 大学院に入った時に知っておきたかった、ソフトウェアエンジニアとして学んだ9つのこと
# 	利害: 0.203188
# 	科学: 0.200446
# 	あなた: 0.183503
# 	研究: 0.152963
# 	習得: 0.148258
# 	すばらしい: 0.129097
# 	利益: 0.115827
# 	神経: 0.110046
# 	仕事: 0.106994
# 	とにかく: 0.104722
# 725 サーバの適切な名前の付け方
# 	レコード: 0.454898
# 	命名: 0.295730
# 	単語: 0.295200
# 	規則: 0.284441
# 	ホスト: 0.257987
# 	サーバ: 0.211036
# 	センタ: 0.205070
# 	用途: 0.154261
# 	ドメイン: 0.142916
# 	地域: 0.132439
# 534 MediaRecorder APIを使った簡単なオーディオキャプチャ
# 	録音: 0.599237
# 	音声: 0.334415
# 	ストリーム: 0.261500
# 	メディア: 0.205267
# 	再生: 0.177066
# 	コーダ: 0.158360
# 	完了: 0.121904
# 	格納: 0.121273
# 	要素: 0.117667
# 	アプリケーション: 0.109506
# 664 機械学習はどの分野に属するのか?
# 	分野: 0.415036
# 	知能: 0.393598
# 	学習: 0.336051
# 	機械: 0.289283
# 	マイニング: 0.287017
# 	サイエンス: 0.260457
# 	人工: 0.255576
# 	コンピューター: 0.188249
# 	統計: 0.183694
# 	手法: 0.128624
# 415 眼鏡なしのコードレビュー
# 	眼鏡: 0.325698
# 	あなた: 0.278974
# 	メソッド: 0.270558
# 	参考: 0.201383
# 	空間: 0.186962
# 	跳ぶ: 0.172839
# 	クラス: 0.150628
# 	名前: 0.133711
# 	見つめる: 0.126720
# 	わかる: 0.120252
# 455 Chefはオープンソースではない
# 	コミュニティ: 0.339045
# 	社外: 0.248499
# 	社員: 0.243817
# 	オープン: 0.207775
# 	エコ: 0.183694
# 	回答: 0.139257
# 	ソース: 0.134473
# 	企業: 0.129664
# 	パッチ: 0.129425
# 	フリー: 0.129425
# 100 Webページレンダリングについて知っておくべきこと: ピクセルは高コスト
# 	ビデオ: 0.325624
# 	セレクタ: 0.271054
# 	マッチング: 0.268820
# 	パイプライン: 0.262567
# 	スタイル: 0.252969
# 	レイアウト: 0.237001
# 	表示: 0.189743
# 	つきもの: 0.187326
# 	ほう: 0.183110
# 	画面: 0.178908
# 136 ユーザー数をグロースさせるための数少ない手法リスト
# 	ユーザー: 0.566440
# 	獲得: 0.268438
# 	成長: 0.224688
# 	あなた: 0.184897
# 	バーベル: 0.178703
# 	チャネル: 0.168575
# 	製品: 0.158390
# 	コンテンツ: 0.142052
# 	お金: 0.122745
# 	投資: 0.117027
# 293 スケールするエンジニアチームについてGoogleが教えてくれたこと
# 	エンジニア: 0.314988
# 	新入り: 0.264796
# 	文化: 0.217014
# 	社員: 0.214831
# 	規約: 0.193390
# 	チーム: 0.189800
# 	エンジニアリング: 0.183343
# 	品質: 0.176092
# 	社内: 0.175156
# 	ツール: 0.164873
# 319 Go言語がダメな理由
# 	構造: 0.300471
# 	ヒープ: 0.248796
# 	組み込み: 0.230641
# 	汎用: 0.228130
# 	言語: 0.225098
# 	関数: 0.210004
# 	プログラミング: 0.203883
# 	不変: 0.171098
# 	返す: 0.153569
# 	システム: 0.150282
# 770 モダンなWebプロジェクトにおけるベストプラクティス
# 	環境: 0.511349
# 	ファイル: 0.274799
# 	アプリケーション: 0.250903
# 	本番: 0.244449
# 	プロジェクト: 0.219216
# 	配信: 0.149230
# 	メンバー: 0.141074
# 	設定: 0.132230
# 	ブランチ: 0.130441
# 	ステージング: 0.121403
# 579 Heroku元CTOによる『ベルリンのスタートアップシーンへの旅』
# 	スタート: 0.360624
# 	ベルリン: 0.253286
# 	アップ: 0.248348
# 	ヨーロッパ: 0.220796
# 	企業: 0.212495
# 	サンフランシスコ: 0.169495
# 	ジェームズ: 0.151322
# 	起業: 0.128474
# 	スタッフ: 0.123757
# 	関わる: 0.118873
# 750 Servoにおける単位系の静的チェック
# 	単位: 0.692611
# 	画素: 0.259825
# 	座標: 0.248680
# 	変換: 0.186362
# 	バグ: 0.139931
# 	ライブラリー: 0.138816
# 	原点: 0.138816
# 	静的: 0.131293
# 	たとえば: 0.127779
# 	幾何: 0.111307
# 586 VagrantとDocker: Mac OS X上でPostgres、Elasticsearch、Redisをセットアップする方法
# 	キシ: 0.510677
# 	コンテナ: 0.501461
# 	プロ: 0.362659
# 	仮想: 0.251091
# 	マシン: 0.147284
# 	環境: 0.145162
# 	インストール: 0.129843
# 	ポート: 0.127997
# 	コマンド: 0.126686
# 	起動: 0.123154
# 541 スタートアップ向け法務の完全入門ガイド
# 	創業: 0.593371
# 	契約: 0.381274
# 	策定: 0.277707
# 	法的: 0.236084
# 	ひな: 0.158409
# 	財産: 0.150706
# 	解雇: 0.144732
# 	および: 0.139997
# 	スタート: 0.138025
# 	知的: 0.124866
# 674 機械学習とは何か? – 機械学習の定義と使える言い回し
# 	機械: 0.538046
# 	学習: 0.527805
# 	統計: 0.236055
# 	プログラマ: 0.134069
# 	スパムメール: 0.132957
# 	定義: 0.127222
# 	分野: 0.115652
# 	決定: 0.114662
# 	マース: 0.106365
# 	ミッチェル: 0.106365
# 357 Dockerにまつわる誤解とベストプラクティスについて
# 	サーバ: 0.407033
# 	管理: 0.355745
# 	コンテナ: 0.303013
# 	イメージ: 0.239475
# 	システム: 0.198317
# 	ツール: 0.191377
# 	本番: 0.178402
# 	環境: 0.175431
# 	ホスト: 0.142265
# 	ロール: 0.137182
# 247 科学者が書いた質の低いコードが、ベストプラクティスに則ったコードに勝る理由
# 	ネーミング: 0.257897
# 	プログラマ: 0.232244
# 	科学: 0.202390
# 	継承: 0.193452
# 	関数: 0.154147
# 	多重: 0.150071
# 	多用: 0.148760
# 	コントローラ: 0.141819
# 	むちゃ: 0.117252
# 	マネージャ: 0.117116
# 14 Q. AngularJSとjQueryの違いは何でしょうか?
# 	ライブラリ: 0.451142
# 	仲間: 0.386367
# 	新規: 0.346751
# 	タスク: 0.280908
# 	デフォルト: 0.271170
# 	導入: 0.271170
# 	プログラマ: 0.266322
# 	知識: 0.257793
# 	違う: 0.214867
# 	全く: 0.201245
# 131 データサイエンス・ベン図
# 	サイエンス: 0.383954
# 	統計: 0.307720
# 	スキル: 0.301584
# 	知識: 0.195760
# 	専門: 0.181328
# 	実質: 0.178748
# 	分野: 0.172693
# 	ハッカー: 0.169485
# 	数学: 0.168899
# 	ハッキング: 0.167660
# 256 大切な作業に表計算ソフトは使わないように（本当に！）
# 	経済: 0.371410
# 	学者: 0.297128
# 	ソフト: 0.290350
# 	タイムズ: 0.265903
# 	計算: 0.229172
# 	フィナンシャル: 0.227916
# 	解析: 0.166423
# 	レビュー: 0.152419
# 	中略: 0.139251
# 	資本: 0.132097
# 710 D3.jsにあてはまらないこと
# 	チャート: 0.601874
# 	ポリ: 0.200909
# 	フィル: 0.196705
# 	あれこれ: 0.174004
# 	下さる: 0.161695
# 	グラフィック: 0.154941
# 	ライブラリ: 0.152752
# 	いじる: 0.140060
# 	誤解: 0.128399
# 	ユーティリティー: 0.117960
# 789 GitHubでの”Merge pull request”の弊害
# 	コミット: 0.515714
# 	ジェーン: 0.354539
# 	テナー: 0.319507
# 	メン: 0.319507
# 	マージ: 0.181189
# 	履歴: 0.157653
# 	彼女: 0.136045
# 	ボタン: 0.121192
# 	修正: 0.118702
# 	パッチ: 0.100334
# 759 「たのしい失業生活」入門
# 	失業: 0.488237
# 	ライフ: 0.394701
# 	瞑想: 0.264566
# 	楽しい: 0.233813
# 	雑用: 0.220472
# 	片付ける: 0.106279
# 	ゴールド: 0.084350
# 	始末: 0.084350
# 	気分: 0.083694
# 	成し遂げる: 0.082550
# 686 Google I/OがAirbnbの空室状況に及ぼす影響
# 	料金: 0.529853
# 	宿泊: 0.424031
# 	開催: 0.326273
# 	物件: 0.231757
# 	ホテル: 0.211241
# 	需要: 0.205718
# 	会議: 0.180866
# 	イベント: 0.160147
# 	値上げ: 0.121152
# 	参加: 0.110259
# 338 定まらない”共有”のアイコン
# 	共有: 0.618990
# 	アイコ: 0.580034
# 	トレー: 0.174775
# 	表す: 0.167013
# 	デザイン: 0.123079
# 	プレゼント: 0.116516
# 	デザイナー: 0.108481
# 	行為: 0.108481
# 	プラットフォーム: 0.101195
# 	ミルクセーキ: 0.096969
# 200 ZFSがあればGitなんか要らない?
# 	ファイル: 0.477185
# 	プール: 0.393198
# 	スナップショット: 0.379630
# 	システム: 0.350650
# 	マウント: 0.206958
# 	コマンド: 0.159238
# 	プッシュ: 0.156736
# 	ストレージ: 0.141621
# 	ディスク: 0.131105
# 	差分: 0.105724
# 230 CSS will-changeプロパティについて知っておくべきこと
# 	要素: 0.565479
# 	変化: 0.337094
# 	最適: 0.242990
# 	アニメーション: 0.151879
# 	変形: 0.138404
# 	宣言: 0.134962
# 	包含: 0.133105
# 	生じる: 0.132438
# 	ページ: 0.116025
# 	コンテンツ: 0.114424
# 566 スタートアップ vs 大企業
# 	スタート: 0.445107
# 	企業: 0.428001
# 	アップ: 0.321126
# 	勤める: 0.203984
# 	働く: 0.194944
# 	仕事: 0.145712
# 	ストレス: 0.135396
# 	影響: 0.120011
# 	会社: 0.112318
# 	ビジネス: 0.106590
# 292 すべてのプログラマが読むべき記事10選
# 	プログラマ: 0.578384
# 	すべて: 0.259853
# 	知識: 0.206905
# 	文字: 0.201819
# 	エン: 0.196049
# 	浮動: 0.156402
# 	メモリ: 0.156241
# 	小数点: 0.155035
# 	セキュリティ: 0.153939
# 	時刻: 0.143868
# 779 Uncle Bobのリトル・モッカー
# 	スパイ: 0.387155
# 	テスト: 0.384521
# 	スタブ: 0.336558
# 	ダブル: 0.322971
# 	ダミー: 0.295054
# 	ええ: 0.279652
# 	なるほど: 0.170032
# 	振る舞い: 0.120550
# 	はい: 0.114641
# 	ログイン: 0.114127
# 709 最高のプログラミング言語（または私は如何にして心配するのを止めてコードを愛するようになったか）
# 	言語: 0.770210
# 	並行: 0.118751
# 	シェル: 0.107952
# 	プログラマ: 0.107287
# 	水準: 0.100552
# 	すばらしい: 0.094625
# 	容量: 0.085308
# 	美しい: 0.085308
# 	ライブラリ: 0.082609
# 	コミュニティ: 0.074957
# 479 車輪の再発明
# 	車輪: 0.492756
# 	発明: 0.310800
# 	シチズン: 0.271228
# 	多様: 0.219564
# 	遺伝: 0.217628
# 	進化: 0.178703
# 	フレーム: 0.162354
# 	ワーク: 0.161394
# 	サイエンス: 0.139084
# 	無駄遣い: 0.125400
# 169 ある中級プログラマの告白
# 	サイト: 0.348751
# 	サテライト: 0.169606
# 	プログラマ: 0.167971
# 	実力: 0.126285
# 	イエス: 0.111630
# 	中級: 0.104487
# 	商品: 0.104131
# 	プログラム: 0.099740
# 	技術: 0.097732
# 	学ぶ: 0.094714
# 203 JavaScriptの読み込みにおける非同期スクリプト注入の悪影響
# 	スクリプト: 0.578088
# 	属性: 0.385867
# 	インライン: 0.294888
# 	ブロック: 0.286582
# 	非同期: 0.181790
# 	順序: 0.159735
# 	直ちに: 0.157566
# 	ドキュメント: 0.142212
# 	ページ: 0.113800
# 	読み込む: 0.090713
# 520 ディープラーニング（深層学習）を用いたビジネスモデル
# 	サービス: 0.228054
# 	企業: 0.217310
# 	チップ: 0.206611
# 	トレーニング: 0.182691
# 	ビジネス: 0.173955
# 	技術: 0.153793
# 	顧客: 0.150233
# 	モデル: 0.141345
# 	課題: 0.141264
# 	大手: 0.137915
# 811 JavaScriptフレームワークはもうこりごり
# 	フレーム: 0.573679
# 	ワーク: 0.570287
# 	ポリ: 0.156700
# 	氷山: 0.156700
# 	フィル: 0.153421
# 	ライブラリ: 0.148925
# 	モデル: 0.134454
# 	地図: 0.100325
# 	いったい: 0.092800
# 	イディオム: 0.078350
# 290 Webフレームワークとは何か
# 	リクエスト: 0.555710
# 	アプリケーション: 0.324432
# 	フレーム: 0.235775
# 	ワーク: 0.234381
# 	レスポンス: 0.209367
# 	サーバ: 0.171886
# 	ステータス: 0.147007
# 	要求: 0.141806
# 	フォーム: 0.132753
# 	すべて: 0.129677
# 813 機械学習アルゴリズムへの招待
# 	学習: 0.524439
# 	アルゴリズム: 0.387389
# 	回帰: 0.368717
# 	モデル: 0.236477
# 	分類: 0.224531
# 	教師: 0.208409
# 	訓練: 0.143151
# 	機械: 0.139498
# 	ラベル: 0.121207
# 	手法: 0.117847
# 315 asyncioを用いたpythonの高速なスクレイピング
# 	コルーチン: 0.858557
# 	自作: 0.157627
# 	リクエスト: 0.148784
# 	おまけ: 0.122221
# 	ライブラリ: 0.113285
# 	非同期: 0.091962
# 	再開: 0.090783
# 	ループ: 0.077758
# 	フォーム: 0.074973
# 	ひとつ: 0.068686
# 356 Clojureで学ぶデータ構造:ハッシュテーブル
# 	バケット: 0.503142
# 	ハッシュ: 0.413133
# 	ノード: 0.341784
# 	キー: 0.293088
# 	テーブル: 0.260113
# 	配列: 0.227979
# 	連結: 0.178761
# 	衝突: 0.154608
# 	実装: 0.149568
# 	リスト: 0.136100
# 625 Olarkを使ったリアルタイムの技術サポート
# 	コマンド: 0.357243
# 	ユーザ: 0.341456
# 	ログ: 0.300776
# 	診断: 0.238432
# 	ルーチン: 0.237187
# 	オペレータ: 0.226611
# 	転送: 0.201955
# 	チャット: 0.169800
# 	感度: 0.154877
# 	録音: 0.151288
# 391 PythonでPostgresデータから決定木を構築する
# 	読み込む: 0.253935
# 	ひとつ: 0.253392
# 	ディシジョン: 0.242050
# 	図表: 0.206130
# 	人口: 0.197958
# 	苦手: 0.176433
# 	分割: 0.156038
# 	予測: 0.149662
# 	手法: 0.146376
# 	データベース: 0.143950
# 143 butterflyを使ってWebブラウザ上でターミナル入力を行う
# 	ターミナル: 0.640475
# 	押す: 0.229188
# 	クイック: 0.202787
# 	ユーザ: 0.189510
# 	選択: 0.170525
# 	サーバ: 0.155531
# 	テキスト: 0.147701
# 	ショートカット: 0.119299
# 	スクロール: 0.109356
# 	シェル: 0.108004
# 399 Pythonにサヨナラを
# 	言語: 0.195049
# 	ツール: 0.168281
# 	コミュニティ: 0.160535
# 	感じる: 0.153712
# 	アイデア: 0.150260
# 	世界: 0.138586
# 	情熱: 0.124640
# 	ライブラリ: 0.123847
# 	ただ: 0.121466
# 	プログラミング: 0.119589
# 157 画期的な起業プロセス
# 	株式: 0.282162
# 	参加: 0.201027
# 	起業: 0.187536
# 	アイデア: 0.173522
# 	友人: 0.169306
# 	人材: 0.163920
# 	プロジェクト: 0.156756
# 	ブランチ: 0.141779
# 	ベンチャー: 0.123708
# 	仲間: 0.122485
# 165 JavaScriptでbind（）を使って部分適用する
# 	引数: 0.371067
# 	関数: 0.368216
# 	ハンドラ: 0.278272
# 	イベント: 0.258397
# 	無名: 0.213729
# 	呼び出す: 0.211187
# 	似かよう: 0.155602
# 	コンテキスト: 0.142825
# 	ショック: 0.135278
# 	スッキリ: 0.135278
# 439 カートゥーン作家のための新たなビジネスモデルを創造する
# 	作品: 0.559455
# 	作家: 0.465449
# 	雑誌: 0.334187
# 	描く: 0.174570
# 	掲載: 0.161437
# 	販売: 0.154148
# 	収入: 0.132797
# 	サイト: 0.122339
# 	利益: 0.121229
# 	収益: 0.098994
# 192 Node.jsのコールバック地獄をPromiseやGeneratorを使って解消する
# 	モジュール: 0.464651
# 	コール: 0.280408
# 	バック: 0.256780
# 	関数: 0.254807
# 	ファイル: 0.242844
# 	アプローチ: 0.203556
# 	ネスト: 0.199890
# 	並列: 0.188457
# 	返す: 0.156581
# 	ディレクトリ: 0.154923
# 235 Yコンビネーター（2013年サマーバッチ）で学んだ9つのこと
# 	デー: 0.395407
# 	銀行: 0.317174
# 	企業: 0.210989
# 	アワー: 0.210349
# 	夕食: 0.206438
# 	チーム: 0.187475
# 	レッスン: 0.161324
# 	ダン: 0.156277
# 	プレゼン: 0.153325
# 	参加: 0.153149
# 500 優れたロゴを作るには?
# 	ロゴ: 0.673926
# 	書体: 0.413803
# 	連想: 0.185704
# 	感情: 0.161464
# 	会社: 0.156450
# 	イメージ: 0.142855
# 	心理: 0.112321
# 	ふさわしい: 0.104662
# 	ブランド: 0.101202
# 	デザイン: 0.093413

# %% [markdown]
# ### TF-IDFを用いた類似文書検索　コサイン類似度

# %%
# 文書集合を元にして各文書中の単語のTF-IDF値を計算
vectorizer = TfidfVectorizer(analyzer='word', max_df=0.5)
vecs = vectorizer.fit_transform(data)
# 類似度の計算
sim = cosine_similarity(vecs)
docs = zip(ids, sim[2])
# コサイン類似度が高い順にソートしてループ
for id, similarity in sorted(docs, key=lambda x: x[1], reverse=True):
    index = [k for k, v in enumerate(find_all_data) if v[columns.index('id')] == id][0]
    entry_title = find_all_data[index][columns.index('entry_title')]
    print(id, entry_title, similarity)
# Out:
# 178 データサイエンティストにおいて、最も需要のあるスキルとは 1.0000000000000002
# 131 データサイエンス・ベン図 0.31670239769403524
# 689 データサイエンティストのためのEmacs 0.2565068205367657
# 674 機械学習とは何か？ – 機械学習の定義と使える言い回し 0.24202258982900401
# 78 機械学習のレベル別学習法 0.22025288233231022
# 82 機械学習に挑んだ一年間 – 機械学習について一から学び、仕事に活用するまでの道のり 0.21421632402573124
# 365 Stack Overflowのデータサイエンティストとしての1年間 0.20480607799580822
# 671 PythonとRuby：ワークシェイプの徹底比較！ 0.20461083455515786
# 664 機械学習はどの分野に属するのか？ 0.20086282336297684
# 573 私を魅了した起業家について 0.19134699186530324
# 585 アカデミアからデータサイエンティストへの転職で、私の時間の使い方がどう変わったか 0.1869927811305414
# 309 コーディングを学ぶこと、それはあなたが考えるよりも大変です 0.1580704789373656
# 60 日常にある機械学習の応用例 0.1564934686628205
# 101 機械学習の用語集：データ、学習とモデリング 0.15549478557957952
# 702 マネージャのためのAngularJSの概要 Part 1 0.14407727796709963
# 753 Haskellのエンジニアは二流なのか？（答えはノーである） 0.14275776463981005
# 121 優秀なJavaScriptの開発者になるための5か条 0.14180117690958993
# 813 機械学習アルゴリズムへの招待 0.1375109655033694
# 308 Amazon Redshiftで顧客分析ソリューションを構築 0.1364613000336475
# 340 なぜ採用される言語とされない言語があるのか 0.13488022205809386
# 608 効率的な統計実践のための、10個のシンプルなルール 0.134853601240836
# 50 Haskellと共に4年間を歩んだ起業家の視点 0.1336110230602503
# 353 プログラミングのサイドプロジェクトを始めたいきさつ 0.13326785202076802
# 211 JavaScriptのフレームワークについて検討してみよう 0.12997498432600468
# 273 気をつけよう：プログラミングのキャリアの話 – 前編 0.1289159793399385
# 675 Javaのマイクロフレームワーク ― この新トレンドは見逃せない 0.12857416452196224
# 682 GitHubのコード検索 : プログラマにとっての宝の山 0.1267907270972819
# 709 最高のプログラミング言語（または私は如何にして心配するのを止めてコードを愛するようになったか） 0.12613217100680793
# 217 データサイエンスのオンラインスクールにて: メンターシップの考察 0.12336187652043673
# 399 Pythonにサヨナラを 0.12216510467027399
# 616 プログラミング言語の選び方、そのやり方を学ぶ 0.12210185747338947
# 323 The 2019 DevOps RoadMap 0.1219767940300062
# 424 気をつけよう：プログラミングのキャリアの話 – 後編 0.11984732582739127
# 811 JavaScriptフレームワークはもうこりごり 0.11867866599434737
# 244 ジョエル･テストは（もはや若干）時代遅れ―今ならこう質問しよう 0.11769071598379742
# 662 JavaScriptフレームワークのコストを考える 0.1173818947786612
# 648 ソフトウェアのための統計学 – 後編 0.11731322348931862
# 537 Pythonコードを使用して、Pythonコードを書く方法を人工知能に学習させる 0.11631105617763969
# 810 データサイエンスのワークフロー ― データ分析を効率に行うために 0.11418441443349174
# 599 define CTO ― CTOとは何かを定義する 0.11133480956950528
# 400 PythonとQGISを使って地理空間を可視化する – UFO目撃情報でのケーススタディ 0.11065788001039423
# 453 Q&A：人工知能の未来(前編) 0.11053737277247601
# 17 JavaScriptフレームワークの寿命 0.1090747019193419
# 806 TypeScript、台頭か 0.10890235105255323
# 166 AngularJSの便利なツール20選 0.10857383871019034
# 204 完璧なJavaScriptフレームワークを求めて Part 1 0.10751480213691898
# 551 エドガー・ダイクストラが綴った「”自然言語プログラミング”の愚かしさについて」 0.10713314127379639
# 329 Angular 2/4が狭量で遅すぎる理由 0.1056598717730641
# 419 OCaml入門の手引 0.10560538964188258
# 548 難しいことを簡単に学ぶ方法 ― 強力なスキルを新たに身に着けるための3つのステップ 0.10518672158000693
# 471 型安全性と統計計算 0.10482637524971002
# 590 R vs Python：データ解析を比較 0.10476480607750588
# 406 Haskellを愛する若者たちへ 0.10432194050297659
# 220 Less is more：プログラミング言語設計の進歩史 0.1033907381380564
# 679 オンライン学習の未来 ー高校生にプログラミングを教えて知り得たこと 0.10302569845859565
# 169 ある中級プログラマの告白 0.10209136971430027
# 54 PHPはもうダメだ、PHP万歳！ 0.10173726432705904
# 582 多種多様な基準から見るプログラマの市場価値 0.10166356250178009
# 336 確率的プログラミング 0.10163746516200418
# 627 酔っ払ってUXレビューをして学んだ10のこと 0.10112862882427551
# 718 2015年 / 2016年、UXの現状と展望 0.10031936090272506
# 607 ソフトウェアエンジニアがたどる成長過程と失敗の行きつく先 0.0993008844882576
# 562 パワフルではない言語が必要 – 表現力と合理性のトレードオフについて、Pythonを例に考える 0.09902985965291904
# 711 Haskell、Scala、ML、Scheme：あなたが次に学ぶ関数型言語 0.09790949072915413
# 476 開発者がビッグデータ分析にPythonを使う時によくやる間違い 0.09784914079511906
# 111 「全てのプログラミング言語は同じだと、ある時気付いたんです」 0.09762949865039193
# 127 大学院に入った時に知っておきたかった、ソフトウェアエンジニアとして学んだ9つのこと 0.09739758741269171
# 20 iOS 10とMac OSにおけるニューラルネットワーク 0.0970758593529294
# 472 ソフトウェアのための統計学 – 前編 0.09549462388658177
# 564 優れたエンジニアを採用できないワケ 0.09251990768025714
# 580 Stack Overflow: 100万人の開発者を手助けするVim終了方法 0.09146873912291854
# 292 すべてのプログラマが読むべき記事10選 0.09044354232878232
# 132 Lispのアイデア 0.0902819163280868
# 506 機械が私たちの偏見を継承する仕組み 0.09001917202134002
# 771 完璧なJavaScriptフレームワークを求めて Part 2 0.0884888091220123
# 457 ピーク期にあるGOOGLE 0.08777406484624023
# 692 深層畳み込みニューラルネットワークを用いた画像スケーリング 0.08750579718260704
# 154 Node6からNode8へのアップデート – 実際のパフォーマンスの比較 0.0868227565801054
# 657 勝利のためのD言語 0.08630890315014494
# 740 「フロントエンド開発者」の終焉 0.08567556767550757
# 3 NoSQLデータベース：調査と決定のガイダンス（その3） 0.08561597121627332
# 37 Railsの基本理念 : Railsの生みの親が掲げる8つの原則 0.0853035330630997
# 231 情報理論を視覚的に理解する (4/4) 0.0847458822452671
# 56 USトップ大学でも関数型プログラミングが余り教えられていない現実 0.08454335280596353
# 436 Scala使用歴5年のプログラマが、この言語とその環境に関する神話を解き明かす 0.08396266636533524
# 32 機械学習とNode.jsを使用してInstagramユーザの性別を知る 0.08381413234618756
# 134 私がTypeScriptについて勘違いしていたこと、そしてその理由 0.08372342446297733
# 595 ディープラーニングの限界 0.08340419884320902
# 385 プログラマーの教訓、採用、業界用語など10月TOP5 0.08296202051513298
# 40 Blue. No! Yellow! : プログラミング言語の進歩史と生産性にまつわる問答 0.0821654131502019
# 767 テクニカルライティングの将来 ー GitHub上のAsciidocで技術書Pro Gitを協働執筆 0.08175917268835478
# 120 専門職の移り変わり（つまりMozilla Labsの閉鎖） 0.08141253331243663
# 483 ディープラーニングのサマースクールで学んだ26のこと 0.08134350123306332
# 139 情報理論を視覚的に理解する (3/4) 0.08068470051603104
# 92 コーディングに対する考え方を変える6つのプログラミングパラダイム 0.08009387887635674
# 732 プログラマ能力指標表 0.07967760062617249
# 327 初段プログラマ  前編 0.0793553012226427
# 242 LLVM上で、LuaのCライブラリを使用して、コンパイラを使わずにソフトウェアを書く（前半） 0.07834359155802641
# 35 Clojureだと生産性が上がるわけ 0.07812786997654579
# 61 なぜPythonはこんなにも遅いのか？ 0.07656169830687437
# 455 Chefはオープンソースではない 0.0758955883137689
# 181 Redditのデータ分析における、20のプログラミング言語とScalaの比較 0.07577949591068572
# 107 誰もあなたの製品を使いたいと思ってはいない : 製品をデザインするための考え方 0.07575795610722946
# 741 Q&A：人工知能の未来(後編) 0.07529377147043273
# 479 車輪の再発明 0.0751399827582758
# 622 D言語はデータサイエンスのためにある 0.07504079753374812
# 289 肩書きに関する問題 0.07462409694056024
# 249 優れたプログラマに対しての、管理職への昇進以外のキャリアパス 0.07453880981028574
# 163 JITコンパイルでの冒険　パート2：x64 JIT 0.07384654849545749
# 529 TypeScriptを使った方がいいケースとは？ 0.0738456473706746
# 456 【翻訳】AngularJSからReactへ: Isomorphicな方法 0.07380571564624488
# 403 Go 実践4日間 0.07370557901555999
# 556 「型」の定義に挑む 0.07328740481699998
# 729 Angular 2で作った最初のアプリの事後分析 : 使ってわかったAngular 2の長所と短所 0.07318570377081679
# 710 D3.jsにあてはまらないこと 0.07277678360380549
# 118 関数型プログラマのためのRust 0.07232400959773228
# 274 現代のCOBOL開発のための3つのオープンソースプロジェクト 0.07157487343445265
# 364 現実世界のSwift ー Duolingo開発者が語るSwiftの強みと弱み 0.07116337678310301
# 569 他人の書いたコードに挑もう – Part 2 0.07106284513954954
# 290 Webフレームワークとは何か 0.07055889257865841
# 552 Pythonや機械学習、そして言語の競争について – 極めて主観的な見地から 0.07024563246731247
# 563 スタートアップや小規模の会社に合ったフリーランサーを雇う方法 0.07013768843583626
# 13 レガシープロトコル向けレガシー検索エンジンの構築 0.07006472000532646
# 818 Web 3.0: Webの移行が始まっている 0.07005664401242938
# 116 HHVMの今後 0.06968693648587394
# 6 大学院生のためのLLVM 0.0696314289517669
# 678 プログラマとして30年以上の経験から得た教訓 0.06941545591941552
# 256 大切な作業に表計算ソフトは使わないように（本当に！） 0.06923912345389598
# 354 プレイブック -プラットフォームの選択- 0.06884927548431008
# 745 分散型システム徹底入門 – Part 2. 0.0685748647773175
# 588 Optimizelyの社員が教えるA/Bテストで試せる71のこと 0.06823025680107098
# 268 フロントエンドのプログラミング言語をゼロから設計した理由 0.06807545830875557
# 287 アジャイルの破綻―原因、そして新たな提案 0.06798411880184467
# 555 リモートワークのストレス 0.06795642973843902
# 777 Angularとの2年間 ー これからAngularを使う人への薦め 0.06786580467116962
# 174 親愛なるGoogleへ 0.06743088108861552
# 330 フリーランスが払う代償について 0.06728193497444204
# 357 Dockerにまつわる誤解とベストプラクティスについて 0.06711061003598745
# 460 ソフトウェア設計が重要である理由 0.06699632130634668
# 201 プログラミング面接を突破する方法 (前編) 0.0668875080950223
# 83 キャリアプランニング: 経験のあるエンジニアはどこへ行ってしまうのか？ 0.06676524133859228
# 285 構造化テキストデータを操作するためのコマンドラインツールリスト 0.0665822467487194
# 432 redditにおける関心事 0.06650597410253245
# 546 Haskellで生産性を高める-Pythonからの移行 0.06632305344514328
# 275 ソフトウェアエンジニアは一般的な人々と比べてどのくらい稼ぐのか : Pythonでのデータ収集・処理・可視化 0.06611618923272873
# 769 Angularチームは、どうかしちゃった？ 0.06604351924100249
# 245 CSSになり損ねた言語たち 0.0660016351391797
# 762 RethinkDBとPostgreSQLの比較:私の個人的な経験より – 後編 0.06595519516186382
# 478 技術ドキュメンテーションのためのreStructuredTextとMarkdownを比較する 0.06586811547376255
# 514 Essential Electron : Electronの簡潔・平易な概要 0.06578120067673003
# 239 Pythonパッケージ間の共起関係を可視化してみる 0.06547818159861908
# 142 全ての授業をハッカソンにしてしまおう 0.06533288564614233
# 344 Word2Vecを用いた研究 : ベクトル空間での操作で、単語から「ジェンダーの2元性」を排除する 0.0646041612316635
# 39 gh-ost：GitHubのMySQL向けオンライン・スキーマ・マイグレーションツール 0.06448681872770316
# 505 GraphQLはWeb APIの次のフロンティアか？ 0.06414726205617072
# 454 プログラミング言語について 0.06414190131935098
# 686 Google I/OがAirbnbの空室状況に及ぼす影響 0.06412386422506315
# 717 The Little Printf : 「我々はなぜプログラミングをするのか？」を追う寓話 0.06407018573212347
# 251 Python 3を使うべきでない場合（なんてない） 0.06405729266348373
# 69 アプリケーションの設定はごめんだ！ : アプリケーションのユーザビリティを考える 0.06355017969132659
# 218 MXNet API入門 パート1 0.0634594220565479
# 397 「有害なgoto」「時期尚早な最適化」、そしてプログラミングにまつわる神話は諸悪の根源である 0.06341091613949652
# 719 確率的プログラミングが重要な理由 0.06314813459354064
# 781 2017年JavaScriptのテスト概論 0.06314191152799406
# 544 React.jsのアプリにNeo4jの日付と空間のタイプを扱う 0.06305740387922619
# 216 私たちはなぜReactではなくVue.jsを選んだのか 0.06251485524747893
# 576 高速なWebサーバアプリケーションを構築するための6つの経験則 0.06236810013876669
# 21 V8エンジンでのJavaScriptの機能と最適化コードの書き方に関する5つのベストプラクティス 0.062333785649070515
# 520 ディープラーニング（深層学習）を用いたビジネスモデル 0.0622578554602098
# 236 Railsアプリを66％スピードアップ ― Railsキャッシュの完全ガイド 0.06223770122454666
# 633 さよなら、Firebug 0.062139626915166786
# 703 Google Analyticsに基づくスタートアップの危険性 0.062057664261210115
# 734 H.264の秘密 0.062004039793967604
# 670 プログラミング面接を突破する方法 (後編) 0.06184984360065855
# 589 デバッグの技術 0.06170789273650345
# 700 SymSpell対BK木：100倍速い文字列のあいまい検索とスペルチェック 0.06148165685750868
# 240 アーキテクチャよりも設計を重視しよう – 米政府18Fチームの提案 0.061379644837072436
# 428 私がどのようにして180日で180個のウェブサイトを作り、YC フェローシップ・ファウンダーになったか 0.061256258709023924
# 115 管理職は孤独だ 0.06113983149641776
# 752 PythonとKerasを使ってAlphaZero AIを自作する 0.06066942821355685
# 644 強固なデータ・インフラストラクチャを構築するためのログの活用（デュアル書き込みがダメな理由）PART 1. 0.060279931966052164
# 304 モバイル上のJSフレームワークの実行可能性 – ReactとRedux 0.05999948564508943
# 88 型安全性とは何か 0.0599015842302311
# 33 深層強化学習：ピクセルから『ポン』 – 前編 0.05986827245627334
# 708 分散型システム徹底入門 – Part 1. 0.0597584399997311
# 314 なぜLispなのか？― “データ” と “コード” 0.059711103754838936
# 658 『茹でたニンジン』 : ソフトウェア開発の失敗と技術について 0.05965881270676386
# 543 パフォーマンス分析の方法論23選 0.05957176998098339
# 228 Goを使い複雑性を回避する 0.05949951239157176
# 733 JavaScriptのデバッグ方法 – JSを嫌いにならないためのTips 0.059376940681557897
# 27 RailsのAPIにHATEOASを散りばめてみる : RESTの拡張、HATEOASの詳解と実装例 0.05933087594014101
# 392 シンプルの心理学 ― 心地良いデザインのために 0.05932007697927766
# 496 動的配列について – JavaのLinkedListとArrayListを分析・比較する 0.059226920013085875
# 196 私のGoogleインターンシップ体験記 0.05920883243474521
# 36 Emacs、Guile、Emacs Lispの未来 0.05887020038782075
# 452 プロダクトデザインからバーチャルリアリティへ – GoogleのVRチームにて 0.05856396319536094
# 615 抽象化と組み合わせができるレイアウト言語があれば、CSSは必要ない 0.05854909044458959
# 98 curlとWgetの比較 0.05848858194552256
# 797 Dropboxが構築したMagic Pocketの中身：エクサバイトのストレージシステムの仕組み 0.05846483212804859
# 591 ソフトウェア・コモンズの経済的な失敗と、今すぐできること 0.058270867036752605
# 291 RustとDNSの1年 0.05822302184035519
# 490 Gitのスケーリング（と、その背景） 0.05818338603654262
# 89 70%の人がフェイクニュースに懸念  — Google の闘い 0.0581567846835705
# 310 Pythonにおけるプロファイリング ― コードの高速化のために 0.05796057292625515
# 776 Redditに潜む害悪をデータ分析 – ネットの深い闇へ続く道 0.05776211778676015
# 319 Go言語がダメな理由 0.057491288787958526
# 759 「たのしい失業生活」入門 0.05748023429645344
# 497 テスト駆動開発（TDD）はもう終わっているのか？ Part 2 0.0571782787189057
# 727 爆速HTML – Elmでの仮想DOM 0.057094670839650544
# 246 ワイヤーフレーム、モックアップ、プロトタイプの違いとは？ 0.05701886735156542
# 601 プレイブック -デザイン- 0.056818335332218105
# 751 JPL（ジェット推進研究所）におけるLispの顛末 0.05674848384569515
# 72 セカンドシステム症候群にまつわる3つの話―Perl 6, Python 3, PHP 6 0.05674010314397679
# 475 JavaScriptベストプラクティス Part 2 0.056719242585685024
# 815 ハッキングされたSEOのバックリンクネットワークの分析 0.0566618145177817
# 26 イーサリアムやEOSよりも優れた仮想マシンの設計過程 0.05647152804695104
# 135 Reactを用いたアプリケーションアーキテクチャ：Fluxを再考する 0.056453518876066616
# 693 どうすればPythonをJuliaと同じくらい速く動かせるのか？ : 様々なやり方で計算の高速化を図る 0.05615716910949214
# 504 より良い製品案を選択するために役立つツール 0.05612439122700649
# 792 LastPassでさえも盗まれうる – LastPassのセキュリティを探る 0.056012736043018437
# 213 Docker，デバッグ，リーダブルコードなど9月のTOP5まとめ 0.05588766492620674
# 570 私はいかにして巨大なセキュリティホールを講義中にたまたま見つけたか 0.05552308455857187
# 446 ソフトウェア開発で得た教訓22箇条 0.05548729148781441
# 177 RethinkDBとPostgreSQLの比較:私の個人的な経験より – 前編 0.05546897934692657
# 447 残りの私たちにとって、Rが最高のプログラミング言語である理由 0.05545065434366604
# 358 ストリーミング検索プラットフォームの構築 0.05543187354170639
# 219 インプリメンタ、ソルバ、ファインダ : プログラマのキャリアに関する3つの肩書きの提唱 0.05542710215272089
# 24 Sublime Textの「あいまい一致」をリバースエンジニアリング 0.055185759577233796
# 162 今すぐ始めるLaTeX 0.054896290140314996
# 502 webpackとRollup：似て非なるもの 0.054813496481606605
# 334 リモートワークチーム用の究極のツールボックス：必須ツール15選 0.05478541671989803
# 62 Pythonに咬まれるな : 注意すべきセキュリティリスクのリスト 0.05472948451206079
# 51 学校では習わないコーディングスキル：オブジェクト所有権 0.054622330795573486
# 458 “型”を語る際の7つの重大な誤り 0.054511503994951326
# 307 他人の書いたコードに挑もう – Part 1 0.05445458636623508
# 5 コードの半減期とテセウスの船 0.05443502631979503
# 391 PythonでPostgresデータから決定木を構築する 0.054411891649326534
# 743 あなたと働くエンジニアの人生を最悪なものにしないために – デザイナーのための3つの提言 0.05433259220658946
# 97 フォーケティング ― 新しいカタチのソーシャル・キャピタル 0.05401935254955003
# 293 スケールするエンジニアチームについてGoogleが教えてくれたこと 0.05395852554998541
# 645 週末にいちばん多く使われるプログラミング言語は？ 0.05379970967280877
# 768 iPhone XのFace IDを、Pythonとディープラーニングで再現する方法 0.05374946841655543
# 650 OSのデバッグ：メモリアロケーション講座 0.053746816988250866
# 372 Unixツールを作成するためのヒント 0.053569811485672636
# 542 2016年、C言語はどう書くべきか (後編) 0.053303778857615405
# 765 Bashアプリケーションをテストする 0.0532524587889933
# 66 なぜGo言語は設計が悪いのか – Go愛好者の見地から 0.05323042691700432
# 463 開発者が、開発者ではない同僚から言われて嬉しい11の言葉 – 「クライアントが、IE6で使えなきゃダメだと言っている」 0.05312364489281354
# 119 効果的なディープラーニング（深層学習）モデルのための10のヒント 0.05308232612750188
# 124 15年目のVim 0.05308191881849475
# 241 1カ月のVRデザイン体験 0.05303216496918243
# 748 優秀な面接者に共通するものとは？　数千の実例を調べてみました。- 前編 0.052960278496278504
# 669 マイクロサービスのトレードオフ 0.05262150981819289
# 565 Web開発の未来 – React、FalcorおよびES6 0.052401621434852705
# 804 深層強化学習：ピクセルから『ポン』 – 後編 0.052331481226641025
# 439 カートゥーン作家のための新たなビジネスモデルを創造する 0.05233062424193177
# 609 あなたは全部知っていますか？プログラミングの業界用語30選 0.05230042616291713
# 247 科学者が書いた質の低いコードが、ベストプラクティスに則ったコードに勝る理由 0.051903586694059346
# 206 恐竜に教える現代のCSS – Part 3 0.05181373269263226
# 418 より良いビジネス意思決定のために、機械学習の閾値を可視化する 0.051733119092301175
# 744 C++11のスレッド、アフィニティ、ハイパースレッディング 0.05166409455477953
# 518 「Erlangを使用して、効率的な決済システムを構築するには？」 0.051526478062498444
# 685 WebAssemblyはなぜ速いのか 0.05146838712383936
# 640 私がどのようにして、ソフトウェア開発とオープンソースへの情熱をパートタイムで博士号を取得することで満たしたか 0.05127185257831661
# 272 スタートアップの起業アイデアを決める方法 0.051270927353081114
# 157 画期的な起業プロセス 0.051262793726734715
# 281 Let’s EncryptとNginx : セキュアなWebデプロイメントの現状 0.05116183506444276
# 398 オブジェクト指向UX 0.05112364766771553
# 793 Webアプリのデプロイメントの悲しい状況 0.05099586608824916
# 532 6年間におけるGoのベストプラクティス 0.05098438621504844
# 643 Python 3誕生の理由　― つまり、なぜunicode/str/bytesの仕様は変更されたのか 0.05098090644405882
# 661 Amazonのソフトウェアエンジニア面接 0.05092520535793304
# 596 非難なき事後分析と公正な企業文化 0.050802857258100347
# 326 まずコードの可読性を最適化しよう 0.050765168151028765
# 796 デベロッパからマネージャへの転向 0.05061924246510292
# 603 プロファイラは本当に必須か？―パフォーマンスについて考える 0.05041830004509614
# 222 プログラミングコンテストで、C++を使って全ての問題を解くのに必要なアルゴリズムは何ですか？ 0.05035064154585152
# 85 ロボットに感情を教える：絵文字と深層学習???? ???? ???? 0.05028296732690276
# 535 デバッグを必修科目にするべき理由 0.050233554849066726
# 197 NoSQLデータベース：調査と決定のガイダンス（その2） 0.050189807093615986
# 158 プレイブック -計画- 0.0501783383152417
# 12 新規SaaS事業における最大の課題 0.05015641861341286
# 441 JavaScriptでx86エミュレータを書く 0.05012185075434889
# 146 100Mにスケーリング：Key-ValueストアとしてMySQLを使い、NoSQL以上のパフォーマンスを出す 0.050068602640916636
# 214 ポール・グレアムによる「スケールしないことをしよう」後編 0.05001026829046996
# 41 ニューラルネットワークの動物園 : ニューラルネットワーク・アーキテクチャのチートシート(後編) 0.04995658409058919
# 652 Rubyにはウンザリ！動的型付け、副作用、およびオブジェクト指向プログラミング全般からの考察 0.049914469143596
# 383 週末の思索：私がローカルISPをハッキングした手順、そしてインターネットで身を守るための一般的なアドバイス、学び 0.04988413227056394
# 360 世界最速のフォントレンダラ、font-rsの内部に迫る 0.0498449392667563
# 199 マイクロサービスの終焉 0.049816946832972615
# 540 「プログラムの書き方は知っているが、何をプログラムしていいか分からない」 0.04967516155162187
# 420 2015年の最優先事項は関数型プログラミング！ 0.04954058756992947
# 47 eコマースにおけるコンバージョンの最適化に関する13のケーススタディ 0.04930349682770494
# 42 大規模な決済システムを構築する際に学んだ分散型アーキテクチャの考え方 – 後編 0.04913100200291028
# 480 2015年に向けたJavaScriptアプリケーションアーキテクチャ Part 1 0.04909095649499971
# 59 PHPエクステンションをRustで作る 0.04907296353265096
# 234 キャッシュフレンドリーな二分探索 ー データ構造を再考する 0.04900819232322794
# 530 技術系スタートアップ企業の共同設立から学んだこと 0.04894164543608211
# 389 全てのJSライブラリはTypeScriptで書かれるべきである 0.04890574562298766
# 691 React Fiberアーキテクチャについて 0.04888588377334988
# 90 毎日文章を書くことのススメ 0.04883378567020101
# 280 ビヘイビア駆動開発 ― ウォーターフォールモデルからのステップ 0.04878123832388684
# 312 視覚障碍者プログラマのためのツール 0.04867502326192325
# 130 C言語アプリケーションにPyPyを埋め込む 0.04839471872541742
# 253 リレーショナルデータベースの仕組み (1/3) 0.0483330120460672
# 9 15分で分かるGTD – 仕事を成し遂げる技術の実用的ガイド 0.04829128379087234
# 459 MapReduceは楽しい：巨大なデータセットのサンプリング 0.04821695523835911
# 626 San Franciscoのアパート探しに役立つSlack bot制作記 0.04819749879494546
# 560 Visual StudioでPythonを書くべき理由 0.04814335067433803
# 145 人間らしいGitのエイリアス 0.04808972059661823
# 394 Redux-Observable Epic vs Redux-Saga: 何が問題なのか 0.04782962838353334
# 528 Gopherの道を歩む – Node.jsからGo言語への移行 0.047524347608456446
# 790 フロントエンドにおいてModel-View-Controllerは死んだのか？ 0.047193241550768775
# 31 プレイブック -開発- 0.04713463134635499
# 468 どのようにして5,000ドルのGoogleマップXSSを発見したか 0.04702928466605557
# 677 Goで使える10のテクニック 0.04682244192040522
# 628 リレーショナルデータベースの仕組み (2/3) 0.04649726164460989
# 449 MediumのCSSはこの上なく最高！ 0.046443432098625156
# 412 数値最適化のインタラクティブ・チュートリアル 0.046431872810216664
# 68 フロントエンドとバックエンド 0.046163034824168385
# 19 Elmでロケット着地ゲームを作ってみた 0.046015516945442876
# 572 シンプルなコンテンツベースのレコメンデーション・エンジンをPythonで実装する 0.04593470235887115
# 386 自分たちの勤務時間を可視化して学んだ、3つの生産性ハック 0.045927063132376746
# 341 ソフトウェア開発における学習性無力感 – 作業環境の改善 0.04591842605546203
# 575 Sublime Textを逆アセンブルする 0.04588773027955198
# 725 サーバの適切な名前の付け方 0.04583540349007816
# 625 Olarkを使ったリアルタイムの技術サポート 0.045639681661096186
# 770 モダンなWebプロジェクトにおけるベストプラクティス 0.045526131744255065
# 81 暗号化と圧縮、どちらを先にするべきか？ 0.045518004479768656
# 742 「感情を売る」ということ : App Storeはソフトウェアのマネタイズをどう変えたか 0.0454155776906998
# 153 Optimizelyを使ってクビになりかけたワケ ~統計学が苦手なマーケターへの薦め~ 0.04539894759724306
# 782 知っておくべきモバイルA/Bテストの用語集42 0.04518046040822334
# 126 JVMはそんなに重くない 0.04517307353588862
# 404 障害の事後分析を読んで得た教訓 ― 「何がシステムを停止させるのか？」 0.045170033787095436
# 485 私たちがAmazon Web ServicesからGoogle Cloud Platformに乗り換えた理由 0.04514360100062517
# 508 テスト駆動開発とは何か、それを気に入っているのは何故か、あなたも使うべきなのは何故か 0.04499994360987507
# 498 機械学習のための仮説検定 0.04498664875355201
# 179 JavaScriptとオブジェクト指向プログラミング 0.044984735143762625
# 343 CryptoWall 3.0のトラフィック分析 ― ランサムウェアの内部に迫る 0.04494386500646041
# 510 Node.jsのセキュリティ・チェックリスト 0.044908696958657124
# 672 ゲームをプレイするアルゴリズムを選択するためのアルゴリズム 0.044876060011087855
# 655 Goのガーベジコレクタを視覚化するツール 0.044861385324149204
# 600 ツールは解決策ではない 0.044842493956562965
# 495 Java 8とScala ‐アプローチの違いと相互イノベーション 0.044615164890249075
# 683 Dockerコンテナが遅くなるもう一つの原因 0.04458651959230287
# 808 私がブログにMaxCDNとGhostを利用するワケ 0.044505571561864236
# 263 React Nativeを用いた初めてのiOSアプリ開発 : 選んだ理由と、開発で学んだこと 0.0444980574042382
# 362 “キャッシュ”が新しいRAMとなる 0.04443162194862795
# 522 最も重要なプロダクション・コードにLuaを使う : PythonからLuaへの移行 0.044370502911952485
# 318 超高速なJSON APIをElixirフレームワークのPhoenixでビルドしてテストしよう 0.044173481245068855
# 680 恐竜に教える現代のCSS – Part 2 0.04409190509330807
# 160 ディープラーニング－畳み込みニューラルネットワークとPythonによる特徴抽出 0.04408563101392219
# 413 CQRSとイベントソーシングの使用法、または「CRUDに何か問題でも？」 0.04375019261782231
# 70 60 (フレーム・パー・) セカンズ：Pinterestの描画パフォーマンス最適化のケーススタディ 0.04343584305972049
# 324 バッドUIを改善する方法 ― UIの「5つの状態」を考える 0.04341424910617952
# 128 なぜリフレクションは遅いのか 0.04334578440315339
# 137 Haskell製サービスを本番投入 0.043288440657638406
# 694 興味深いデータ構造：BK木 0.04326442418659184
# 493 コードレビューのベストプラクティス 0.043219889923608375
# 198 Bit Torrentを使ってWebアプリでのサーバレスのデータ同期 0.04302565370054814
# 801 JavaScriptユーザのための関数型プログラミング(前編) 0.0427758181825866
# 474 コードの品質を維持したまま開発スピードを上げる 0.04274134113107974
# 619 Go言語で利用するLLVM入門 0.04267348104415565
# 373 楽しく役に立つCSSのプロファイリング 0.042490971336745675
# 579 Heroku元CTOによる『ベルリンのスタートアップシーンへの旅』 0.04240912122072195
# 647 Git活用法 ー コードはいつも1行ごとにドキュメント化されている 0.0423647662367085
# 164 オープンソースプロジェクトでバグを修正する方法 : あるNodeJSモジュールへの修正を例に 0.04229537092556264
# 321 NginxでHTTPS：ゼロから始めてSSLの評価をA+にするまで Part 2 – 設定、Ciphersuite、パフォーマンス 0.04223667992546424
# 757 Amazon AWSでユーザ数1100万以上にスケーリングするためのビギナーズ・ガイド 0.04211631715776272
# 45 多くの若きプログラマたちが学ぶべきこと 0.04210689460083377
# 186 Node.jsのClusterをセットアップして、処理を並列化・高速化する 0.042087484135316405
# 620 LLVM上で、LuaのCライブラリを使用して、コンパイラを使わずにソフトウェアを書く（後編） 0.042002831300293156
# 370 生産性を測るための4つの便利なメソッド 0.041858563048668716
# 707 CSSコーディングテクニック : 詳細度、単位、flexbox、mixin 0.04180613601546935
# 606 Promiseはどう動作するのか – Promiseを実装してみる 0.04179643225041871
# 271 ソフトウェアエンジニアリングにおける認知バイアス5つ 0.04175568384674693
# 384 プレイブック -計測- 0.0415468865132687
# 501 オープンソースソフトウェアを開発する日々をハッピーに ― あるいは、OSSコントリビュータに感謝を伝えるためにできること 0.04138901547274154
# 749 GoogleがWebでのSHA-1の利用停止を急ぐ理由 0.04136288267702977
# 462 会話型UIの未来はハイブリッドインターフェースだ 0.04135872854737875
# 773 分散型メッセージングミドルウェアの詳細比較 0.04129780581052941
# 93 いかにしてGoogleは他の企業では成し得ないような驚くべきデータセンターネットワークを作り上げたか 0.041278599687741585
# 415 眼鏡なしのコードレビュー 0.041039091166877394
# 451 映画制作におけるPython 0.04098504938332389
# 138 Vim-Galore : Vimについて知っておくべき全てのこと (3/5) 0.04084894156684707
# 238 さあGoを始めよう！環境構築，”Hello World”から簡単なバックエンドサーバーまで 0.04075156215954259
# 738 Go言語Internal パート2：名前付き戻り値の魅力的な利点 0.04061717687308254
# 388 役立つコードレビュー　8つのヒント 0.04058148986058927
# 48 プログラマの採用面接で聞かれる、データ構造とアルゴリズムに関する50以上の質問 0.040501934027353526
# 235 Yコンビネーター（2013年サマーバッチ）で学んだ9つのこと 0.040459153449226376
# 634 JITコンパイルでの冒険　パート1：インタプリタ 0.0404545785012615
# 349 grepでログ解析をするなんてひどい話だ 0.04044743558109139
# 172 モダンミニマリズムという選択―フラットデザインはデザイナーを堕落させたか？ 0.04039215076222961
# 697 Webページのスクロールに関する実験 0.04032028651574431
# 227 私の人生を変えた2度目のハッカソンへの参加 0.040289365306417635
# 754 組み込みシステム上でのC++ 0.04026179556371126
# 788 JavaScriptでニューラルネットワーク : synaptic.jsですぐに作れる手書き数字分類器 0.04023208955879044
# 681 Spotifyのモニタリング part 1：これまでの経緯 0.04022108888804221
# 465 “ノー”と言おう、Facebook社のソースコントロール転換期で理解したこと 0.04021834570093724
# 387 Slack、君と別れようと思う。 0.04011473615346633
# 382 スレッド処理は慎重に – PHPでのスレッド処理 : 後編 0.04010543897110316
# 202 セレブたちのデータ盗難から学ぶセキュリティ 0.04007252554712214
# 136 ユーザー数をグロースさせるための数少ない手法リスト 0.040008841085011466
# 375 コマンドラインでPostgreSQLを操作する – psqlで効率を上げる 0.039960152562806404
# 155 モノモーフィズム（単相性）について – JavaScriptのパフォーマンスを例に 0.039512978424807665
# 110 Swype式キーボードを改良する 0.03930343149517406
# 492 大規模な決済システムを構築する際に学んだ分散型アーキテクチャの考え方 – 前編 0.03919114619185956
# 427 本当に有意義なエラーメッセージを書くには 0.03910920379644107
# 129 私が選ぶ2015年の”新しい”Pythonモジュール トップ5 0.03908911091284019
# 2 あなたのアイデアは他の誰かが最初に思いついている 0.038969762204294774
# 659 私がコーディングで垂直方向にそろえるインデントをとる理由 0.03896398209989006
# 259 私たちはいかにして環状線で”悪さをする列車”を捕まえたか 0.038905381657359406
# 817 分散型システム徹底入門 Part 3. 0.03888091899452443
# 578 Linux ワークステーションのためのセキュリティチェックリスト 0.038869171420487084
# 435 スレッド処理は慎重に – PHPでのスレッド処理 : 前編 0.03878326251758112
# 156 Go言語でモンキーパッチ 0.0387640675334576
# 269 リーダブル・コードを書く 0.038578093163468934
# 64 #/usr/binとその同種の周辺を探る 0.03849586184152126
# 30 WebSocketには注意が必要 0.03843676030847516
# 663 Riotのオンラインサービス運用：第1部 0.03841758472935555
# 809 私が挫折を繰り返したのちにコーディングを習得するに至った経緯 0.03828066440585386
# 766 Python 2.7.x と 3.x の決定的な違いを例とともに 0.0380716751045077
# 673 NoSQLデータベース：調査と決定のガイダンス（その1） 0.03801926299261187
# 393 バックグラウンドジョブの改善によってRailsのパフォーマンスを高める 0.03800719990704987
# 102 邪魔をしないでください 0.03798761659950656
# 254 固有ベクトル、主成分分析、共分散、エントロピー入門 0.03792137464550402
# 704 ニューラルネットワークの動物園 : ニューラルネットワーク・アーキテクチャのチートシート(前編) 0.03791312136980254
# 283 Goで毎分100万リクエストを処理する 0.03790640312055191
# 96 インターフェースプレビューを利用した非ブロッキングユーザインターフェース 0.03787160314726909
# 79 DockerでのNodeアプリ構築で学んだこと 0.03775627555806154
# 515 プログラマを悩ませること Top 10 0.03772718101782293
# 171 コードレビューのレビューはマネージャーの仕事 0.03767308315893126
# 348 CSSモジュール ― 明るい未来へようこそ 0.03752703571029051
# 84 AWSでWordPressを使用したスムーズで簡単な構築 0.03748218571740882
# 525 エンジニア向け技術書購入の裏側 0.03737388223733676
# 46 2015年に向けたJavaScriptアプリケーションアーキテクチャ Part 2 0.03730909212503535
# 617 iOSインディーズゲームはApp storeでは勝てない？数字データから見えるもの 0.0372419459642513
# 780 開発者の仕事が遅いわけではない！納期が遅れるホントの原因 0.03721244725669902
# 539 Railsアプリケーションを、Heroku上で1分間125,000リクエストに対応できるようにスケーリングする 0.037171286470702475
# 574 この世で最も識別しやすいもの ― デスクトップ用Webサイトのハンバーガーメニューを使った、アイトラッキング研究 0.037021322017764854
# 531 NginxでHTTPS : ゼロから始めてSSLの評価をA+にするまで Part 1 0.03686004056950805
# 4 テストすること自体がデザインの一部だとしたら？ 0.03656955416391873
# 233 サーバレスはより安く、より複雑だ 0.036125359441806996
# 785 畳み込みニューラルネットワークの仕組み 0.03593725745919392
# 473 ひどいユーザインターフェースを一目で見極める 0.03590836789311704
# 509 AWSで避けるべき5つの間違い 0.03589409675371663
# 605 拡張現実（AR）ロボット工学 0.03588804883341985
# 366 IRCは死んだ。IRCよ栄えよ。 0.03580925229667101
# 714 ケーススタディ: アプリ “OneShot” をデザインした1週間 0.035748319723926364
# 294 ReactのHigher Order Components詳解 : 実装の2つのパターンと、親Componentとの比較 0.03572080616775837
# 8 分散システムについて語るときに我々の語ること ― 分散システムにまつわる重要な概念について 0.03562328283259185
# 369 Sqwiggleが最初の課金ユーザを獲得した3つの方法 0.03562245628963779
# 538 マルチモデルデータベースを用いたデータモデリング 0.03554453323173318
# 368 OSを書く：初歩から一歩ずつ 0.03547773280524174
# 266 C/C++中規模プロジェクトのための超シンプルなMakefile 0.03542389806077934
# 305 Node.jsフロー制御 Part 2 – FiberとGenerator 0.03541164618180967
# 438 MOSSプログラムがwebpackに約1400万円の助成金を支給 0.03539709086849775
# 91 Pythonの内部構造::PyObject ― CPythonの実装から内部に迫る 0.03531914773856608
# 676 Chrome開発者ツールの小技集 0.03524847420282998
# 351 Unixコマンド”yes”についてのちょっとした話 0.03508361469797645
# 610 ジョエル・スポルスキによる『Trello, Inc.について』 0.035020809825738984
# 57 13年分の未熟なゲームのコード 0.03497582875569529
# 23 なぜDockerとCoreOSの決裂は予測できたか 0.03495492190151379
# 34 コーディング ファスト＆スロー: 開発者と自信過剰の心理 0.03491684358744338
# 464 逆畳み込みネットワークによる顔の生成 0.03467077255460903
# 109 よいA/Bテストとは何か？ – 2014年に行ったEメールのA/Bテストからの教訓 0.03466028114969489
# 352 今までで最高の仕事を私が辞める理由 0.0346230911217455
# 778 オーバーエンジニアリングの正体とその向き合い方 0.03461749427292238
# 29 JavaScriptユーザのための関数型プログラミング(後編) 0.034563512415546976
# 278 DDoS攻撃の対処法 : FastMailがDDoS攻撃にとった対策と事後分析 0.0345360696113599
# 494 Riotのオンラインサービス運用：第2部 0.03449647979572825
# 598 プレイブック -プロダクション- 0.03434760800911107
# 639 ポール・グレアムによる「経験することと自覚について」 0.034319868711592726
# 715 マルコフモデル ～概要から原理まで～ (後編) 0.034256179318603655
# 547 Classy CSS: Sassスタイルシートへのプログラマティックアプローチ 0.03423770596177263
# 49 CSS Variables(カスタムプロパティ)： なぜ、関心を持つべきか？ 0.034219074376714745
# 635 オーディオアプリ開発でありがちな4つの間違い 0.033984055733706504
# 316 自分で行うセキュリティ管理、パート1：エアギャップ・コンピュータ、GPG、スマートカード(YubiKey) 0.03388740518435593
# 150 サーバの負荷テストのための、何百万ものHTTPリクエストを発生させる方法 0.033839165402546625
# 159 スパマのスパムスクリプトを解析してみる : 難読化されたPHPスクリプトに挑む 0.03374864625576777
# 363 Webデベロッパのためのセキュリティ・チェックリスト 0.033532778030434786
# 117 Reactを使ったモジュラーCSS : CSS-in-JSとCSS Module 0.033461500766450374
# 541 スタートアップ向け法務の完全入門ガイド 0.033424172876400635
# 229 Angular 2アプリケーションをimmutable.jsとReduxで構築する 0.033303655680905514
# 325 ソフトウェアエンジニアを目指す人へのコードに関するアドバイス 0.03326119749118045
# 799 Goでクリーンアーキテクチャを試す 0.033196645986895104
# 43 Reduxのパターンとアンチパターン 0.03316137984014968
# 260 JavaScriptのコメントは不要か？ 0.033145918087271055
# 503 なぜUber EngineeringはPostgresからMySQLに切り替えたのか 0.03313584181549828
# 173 Web Componentsの現状 0.033115783679641124
# 191 生のReactを知ろう – JSX、Flux、ES6、Webpackを使わず… 0.033021663126539966
# 632 ポール・グレアムによる「スケールしないことをしよう」前編 0.03290452984684113
# 641 色彩心理学：マーケティング担当者のための完全ガイド 0.03290263230396713
# 15 型クラスはインターフェースとどう違うのか 0.03288917277911655
# 149 無限スクロール：あなたのビジネスでは役に立つ？それとも厄介者になる？ 0.03287995043750329
# 405 モノリシックなRubyからGoによるマイクロサービスへ 0.032879594790038325
# 706 Angular 1.xコンポーネントを、Angular 2にアップグレードする 0.03283231969787861
# 760 Node.jsでのJavaScriptメモリリークを発見するための簡単ガイド 0.032790280222977974
# 151 ファイルシステムよりも35％高速に 0.03277058241366956
# 651 Goはオブジェクト指向言語だろうか？ 0.03270779813129489
# 523 恐竜に教える現代のCSS – Part 1 0.03265543355752298
# 592 グラフィックスプログラミングに泣かされる : OpenGLが抱える問題について 0.03253760174001891
# 378 不慣れなコードベースで短期間に生産性を高めるための7つの方法 0.03251184252366571
# 296 最も割高なアンチパターン : 構造化されたデータを文字列関数で操作する「printfアンチパターン」について 0.03239574318136663
# 402 Travis CIでコンテナベースのインフラストラクチャとDockerでより高速なビルドを 0.03237546462274639
# 524 部分文字列とRegExpの領域の冒険 0.03235949738319722
# 18 RubyとPythonにおけるガベージコレクションの視覚化 0.03234813450979294
# 566 スタートアップ vs 大企業 0.03232047649106379
# 795 現実世界のマイクロサービス：サービスに陰りが見え始め、いよいよ本気になるとき 0.03223171530893257
# 11 単一のAWSアカウントに潜む重大な危険 0.03220792538073287
# 255 ブラックリストは役立たない 0.03213372848249104
# 342 効率的にゲームを更新する 0.032060027847926734
# 695 Go言語の並行性を映像化する 0.032046127431053124
# 192 Node.jsのコールバック地獄をPromiseやGeneratorを使って解消する 0.032020122270558074
# 299 テスト駆動開発（TDD）はもう終わっているのか？ Part 1 0.03198522180390237
# 517 Web Storage: セッショントークンのマシな手段 ― cookieとセキュリティ面を比較してみる 0.03195426176029596
# 656 UIBezierPathのパフォーマンスとAPIの改善 0.031842457027209004
# 567 チームでコンポーネントを構築する : 開発者間でコンポーネントの一貫性を保つための、シンプルな練習問題 0.0318248619398911
# 168 もしもディスプレイが壊れたら（ヒマラヤで） 0.031816940859451685
# 434 くだらないAPIなんていらないよ – 2016年のウェブスクレイピング事情 0.031811865687028554
# 77 GitトラブルをGetしてしまったら：バージョン管理のお話 0.031738290244220424
# 232 Vim-Galore : Vimについて知っておくべき全てのこと (4/5) 0.03157224209289495
# 176 PythonのJSONパーサのメモリ使用量と処理時間を比較してみる 0.03145464519035694
# 103 Pingの発展版 : httping, dnsping, smtpping 0.03144483814546925
# 416 StripeダッシュボードiPhone版のプロダクトデザイン探究 0.03143370625553687
# 763 スクラムで失敗する5大理由とその対策としてできること 0.031122020616362857
# 374 #Anthony Calandra / モダンC++の機能 0.03110861397001606
# 668 Q. なぜ’x’ in (‘x’,)が’x’ == ‘x’より速い？ 0.031069494904493133
# 739 Kotlinの隠れたコストについてのベンチマーク 0.03091800286851651
# 519 なぜSwiftの文字列APIは難しいのか 0.030772327055485098
# 536 倒産した技術系スタートアップ企業から学ぶ7つの教訓 0.03071838294547575
# 411 制限付きボルツマンマシンの初心者向けガイド 0.0306608587186387
# 726 Webサイト開発にCSS in JavaScriptを使うのはやめよう 0.030622821261911758
# 450 HTTPレスポンスのgzip圧縮による日時リーク : Torの秘匿ネットワークの秘匿性を脅かす仕様・実装について 0.030591964172610783
# 250 私がscriptタグについて知っていること全て : 知られていない属性や実行順序など 0.030487888371915222
# 444 C90, C99, C11, C++98, C++11で異なる動作をするコード 0.030479934045647805
# 557 WebkitがES6の機能を完備 : RegExpを例に、パフォーマンスのための取り組みを詳解する 0.030478216254026375
# 807 【翻訳】いいDockerイメージを構築するには？ ーDockerfileのベストプラクティス 0.030462874343296698
# 488 アジャイルな開発には安全性が不可欠 : 現実世界の安全機構との3つのアナロジー 0.03037071071766873
# 125 マルコフモデル ～概要から原理まで～ （前編） 0.030322029629987562
# 549 Node.jsのマイクロサービスの構築を通してDockerを学ぶ – 後編 0.030230877499471034
# 38 Go言語のリアルタイムGC　理論と実践 0.03020588119007914
# 646 検索エンジン経由のユーザを獲得する戦略 0.030151816814297024
# 140 ユーザ・インターフェースのためのイージングカーブをつくる 0.030133665052443817
# 322 AsyncとAwait : コールバック地獄を避けるための最新のやり方、そしてその未来 0.0301330669837123
# 350 型付けを活用してテストを減らす：静的型を使ったTDD Part 1 0.03009770814764401
# 380 『なぜUber EngineeringはPostgresからMySQLに切り替えたのか』について : RavenDB創始者の見地から 0.030074954555787695
# 167 珍しいワークフロー：Atomic Designの原則とSketchでデザインからプログラミングまで 0.030001803865679907
# 653 スタンフォード大学の並列プログラミング・コース用AWSインフラストラクチャ 0.02990217538411634
# 784 MITライセンスを1行1行読んでいく 0.029870223411614317
# 791 JavaScript モジュールの現状 0.029818177040031372
# 487 @extendを使うべき時、@mixinを使うべき時 0.02975928784429964
# 301 Vimの生産性を高める12の方法 0.029319476011791742
# 311 私がどのようにしてキーロガーをクラックし、最終的に第三者の受信トレイに行きついたか 0.029262583698658574
# 16 パーリンノイズを理解する 0.0290142184265676
# 747 情報理論を視覚的に理解する (1/4) : 0.028962252751267223
# 328 『DOOM』（2016）-グラフィックス研究 – 前編 0.028946433685663256
# 421 ページネーションのベストプラクティス 0.028925659412792036
# 76 Q. （関数型）リアクティブプログラミングとは何ですか？ 0.028898213304687163
# 286 ES6 チートシート 0.028883879064058798
# 558 JavaScriptにおける継承のパターン4種類の概要と対比 0.028862757372720576
# 698 APIデザインにおける七つの大厄介 0.02875022981936987
# 10 Go言語の低レイテンシGC実現のための取り組み 0.028698907550063813
# 73 なぜsystemdなのか？ 0.0286933950072038
# 687 Dockerの本番運用 0.02867596430691523
# 367 強固なデータ・インフラストラクチャを構築するためのログの活用（デュアル書き込みがダメな理由）PART 2 0.028668041285854432
# 466 画像処理入門講座 : OpenCVとPythonで始める画像処理 0.02863727948169468
# 262 Pythonを教えるためのいくつかの提案 0.028624079569063536
# 730 Haskell、OCaml、RacketでGCのレイテンシを測る 0.028445325292077994
# 604 WebSocket大合戦：Clojure、C++、Elixir、Go、NodeJS、Ruby 0.028385815927448096
# 230 CSS will-changeプロパティについて知っておくべきこと 0.028349455537003836
# 306 RESTのベストプラクティス 0.028295009848277246
# 390 さらに多くのことが変化する – Fluxは新しい”WndProc”である 0.028271973995413452
# 284 Node.jsのマイクロサービスの構築を通してDockerを学ぶ – 前編 0.028228780594961634
# 182 すばらしいビット 0.028172942871707286
# 613 信頼性の高いパスワードの生成 0.02810614236647627
# 243 ReactをjQueryの数行に要約する 0.028078572219239404
# 95 IPFS入門 : 新たなP2Pハイパーメディア分散プロトコル 0.028068548666611296
# 735 ReactでTDD（テスト駆動開発）を始めよう : 環境構築からテスト作成、機能実装までの詳解ガイド 0.027984516290980487
# 477 製品ロードマップの使用をやめて、GISTプランニングを試すべき理由 0.02793061282569322
# 712 バージョンの充足可能性問題 0.027872652280281327
# 361 開発者が知っておくべきSOLIDの原則 0.027806316523140563
# 188 プログラミングスタックをEveはどのように統合するのか 0.02775929389602515
# 723 超高速エンジンの内部：Quantum CSS（別名Stylo）- 前編 0.027714962459266877
# 58 DRYと不当な抽象化によるコストについて 0.02769741404285306
# 800 コードの可読性、ハッカビリティ、抽象化 0.02758219051706157
# 721 Pythonのオブジェクトとクラスのビジュアルガイド – 全てがオブジェクトであるということ 0.027413736335848572
# 208 デジタルノマドの旅で僕が学んだこと 0.027313528974240036
# 722 Mac OS X Yosemite のデザイン 0.027290011341906607
# 764 100万回のWebSocket接続とGo 0.027060950532112816
# 44 Node.jsフロー制御 Part 1 – コールバック地獄 vs. Async vs. Highland 0.026932645037825803
# 224 プレイブック -プロダクトデザインスプリント- 0.026915396876492834
# 207 Pythonの新しい文字列フォーマット : %記号、str.format()から文字列補完へ 0.026714654403058605
# 94 視覚化による5つのガベージコレクションアルゴリズム入門 0.026678936557665667
# 511 超高速エンジンの内部：Quantum CSS（別名Stylo）- 後編 0.026586564264072004
# 559 正規表現：悪い表現、いい表現、最良の表現 0.026548832136472255
# 533 30日間で300回のプログラミング面接をしてわかったこと 0.026494380711393966
# 445 Rust開発者のためのC++入門書：所有権と借用について 0.026489334064801296
# 755 可変性の回避 ― Rubyへの関数型プログラミングスタイルの適用 0.026487925185885667
# 561 システムのI/Oに必要な時間の大部分はカーネルにあった 0.02646824637025801
# 816 Scalaで型レベル”だけ”でクイックソート 0.026459960570714088
# 63 Spotifyのモニタリング part 2：Heroicの紹介 0.02641547756896065
# 746 Vim-Galore : Vimについて知っておくべき全てのこと (1/5) 0.026397097865237775
# 513 優秀な面接者に共通するものとは？　数千の実例を調べてみました。- 後編 0.026396176695712203
# 195 SDL2を使い、Nimで2Dのプラットフォーム・ゲームを書く 0.026177520142586785
# 469 イベントループなしでのハイパフォーマンス – C10K問題へのGoの回答 0.026173256387762498
# 422 モノリシックなバージョン管理の利点 0.02608569687020609
# 295 JavaScript ベストプラクティス Part 1 0.02604963470945528
# 618 Makefileを自己文書化する 0.026004760667415753
# 28 1995年、セガサターンでのプログラミング 0.025806456301196865
# 303 40行以内で正規表現エンジンを構築 0.025774545131483105
# 133 関数型プログラミング入門 0.025709950723375563
# 802 あまり知られていないCSSの12の事実(続編) 0.025572246347292805
# 212 C言語パズル集：Cにまつわる興味深い問題あれこれ 0.025564007924079663
# 649 シリコンバレーとEdTech革命 0.02547430608734669
# 257 Makeについて知っておくべき7つのこと 0.025458535217287175
# 209 HTTPステータスコードを適切に選ぶためのフローチャート : 難しく考えるのをやめよう 0.025270961012559115
# 205 JavaScriptのデバッグのコツと技 0.02521855865368926
# 787 クライアントとデザイナのためのUX/UIデザインの手引き 0.025215693641256864
# 65 仮想DOMの内部の動き 0.025045550987516232
# 545 パイプとフィルタ ~ソフトウェア工学における有用なアーキテクチャ~ 0.025037968289983205
# 86 Nordnetにおける、デザインと開発のためのアトミックワークフロー : BEMとGitの力を借りて 0.025033859180871698
# 516 そのJavaScriptの関数は本当に純粋関数？ 0.02500974883815768
# 789 GitHubでの”Merge pull request”の弊害 0.025003399768867476
# 333 コードは方法を語り、コメントは理由を語る 0.024954090619980357
# 803 C++11スマートポインタで避けるべき過ち Top10 0.024847402500255147
# 170 就職面接でプログラムの解読を求められた！ 0.024844036319963212
# 221 Airbnbのメインデータベースをどうやって2週間で分割したか 0.024628459740740172
# 359 モバイルナビゲーションを考察する – ハンバーガーメニューに代わるもの 0.024623017202224953
# 568 Reactの新しいバージョニングスキームについて 0.024574500816547367
# 408 Vim-Galore : Vimについて知っておくべき全てのこと (5/5) 0.02457092733797679
# 74 Vim-Galore : Vimについて知っておくべき全てのこと (2/5) 0.024558961987235606
# 396 パスワードリセット・リンクが漏れていませんか？ 0.024422774665169553
# 313 私がsystemdを嫌う理由 0.024391617862675144
# 332 依存関係をなくそう : Rubyアプリ・Gemの開発者への提言 0.024352134421915896
# 104 あなたのアプリの読み込みが加速したとユーザに感じてもらうには 0.024222874655446175
# 210 jQueryは有害なのか 0.024160833758879084
# 355 8つのDocker開発パターン 0.02403478783200297
# 527 Dockerコンテナ内でsshdを実行してはいけない理由 0.023848421568240834
# 491 『DOOM』（2016）-グラフィックス研究 – 後編 0.023767653540099302
# 705 NPMとleft-pad : 私たちはプログラミングのやり方を忘れてしまったのか？ 0.023565109832969586
# 112 コーディング面接とSnakeゲームに唯一共通すること 0.02338777316233855
# 147 計算グラフの微積分：バックプロパゲーションを理解する 0.023378583868761463
# 431 公開鍵ピンニングについて 0.023370531213024365
# 614 Linuxシステムコール徹底ガイド 0.0233612494352736
# 814 高速なハッシュテーブルを設計する 0.023323580644430256
# 114 OCamlの簡単な手引き 0.023255263198111064
# 429 なぜタイポグラフィにおいてVertical Rhythm（バーティカルリズム）は重要な手法なのか？ 0.023255120958172268
# 724 GoogleのQUICプロトコル：TCPからUDPへWebを移行する 0.02324393662297734
# 554 AlphaGo Zeroの動作方法と理由 0.0232418204215913
# 395 私が書いた最速のハッシュテーブル – PART 3 0.023142864906872722
# 265 PostgreSQLウィンドウ関数のTips 0.023129863961644154
# 660 クラスの「継承」より「合成」がよい理由とは？ゲーム開発におけるコードのフレキシビリティと可読性の向上 0.022999861425001832
# 611 マイクロサービス – 分散された大きな泥だんご 0.02299808616410098
# 409 Googleのバグ発見報奨金 – 5千ドルのエラーページ 0.022824552893598547
# 621 Web開発者が恐らく知らない、SSLについて知っておくべきこと 0.02271311755174483
# 183 SaaSのメトリクス：チャーン率のベンチマーキング ― 1500社以上のSaaS企業のチャーン率を分析 0.0226684769114364
# 521 コンピュータービジョン症候群 0.02262940582108094
# 699 ゲームボーイアドバンスのゲームを書こう 0.022574533063268013
# 108 勾配降下法の最適化アルゴリズムを概観する 0.022481679496832652
# 587 ブロックチェ－ンを構築しながら学ぶ 0.022199347794235016
# 728 ハードウェアのスタートアップが国内生産をすべき5つの理由 0.022140726665245275
# 443 PHP7における内部値の表現―パート1 : PHP5とPHP7のzvalの仕組み 0.02214027649270149
# 461 C言語、知ってるつもり？ 0.022104885576294912
# 71 浮動小数点計算の基本的事実 – 「浮動小数点数は実数ではない」ということ 0.02203690826991381
# 417 ノンデザイナーのための25のグラフィックデザインのコツ 0.021971849856274598
# 288 アスペクト指向プログラミング入門 0.021885632580344008
# 261 ひどいダッシュボードの法則 0.021880963856040905
# 805 マジックカーネル – 画像のリサンプリングのメソッド 0.0217032066381248
# 577 色：ヘキサコードから眼球まで – Part 3. 0.021644271189597025
# 25 TCPを（少しは）理解しておくべきその理由 0.02161964920416887
# 264 有効期限切れになる前に！RakeタスクでSSL証明書を更新する方法 0.02158006081417629
# 317 ブラウザのキャッシュをクリアする 0.021488385463250055
# 80 三目並べで学ぶミニマックス法 0.02141899800704164
# 185 ソフトウェアのスケーラビリティについてスターバックスが教えてくれること 0.02139412418517236
# 161 処理速度の遅いcurrentTimeMillis() – 前編 0.02138365466727853
# 298 初心者のためのSQLガイド???? : SQLを直感的に理解しよう 0.021373265521811267
# 731 カオステストでHTTP/2の問題を見つけ出す 0.021347808689937832
# 99 私がどのようにしてAtomの奇妙なバグを修正したか : 正規表現が暴走を起こすとき 0.021341033687926673
# 297 Gitコマンドラインショートカット 0.02132317937102085
# 430 システムコールを経由する生のLinuxスレッド 0.021287131504370515
# 794 プログラミングの名言をもう少し 0.02128364522394166
# 123 DHHはどのようにRailsのコントローラを書くのか 0.021245797956742033
# 761 本当にCSSの詳細度は必要なのか 0.02117336924062084
# 252 MongoDBのクエリは必ずしもマッチするすべてのドキュメントを返すわけではない 0.021120002515737164
# 716 どれだけ速く文字列からスペースを削除できるのか 0.021110230330813256
# 14 Q. AngularJSとjQueryの違いは何でしょうか？ 0.021093469126981804
# 347 ピアコードレビューの実践的レッスン 0.020991591076162632
# 426 正式リリースされたES8の主な新機能 ???? 0.02085228389715691
# 713 チュートリアル – システムコールの書き方 0.02085054892585903
# 684 「Hooked」の著者が教える新規ユーザーの関心を獲得する方法 0.020780954345795185
# 175 ファミコンのグラフィックスの省メモリ化テクニックとは？ 0.020595661696039144
# 481 RustにおけるfutureとgRPC 0.020472694885117503
# 638 Atomの重要なプリミティブの最適化 0.020444058855163687
# 512 あなたにWebSocketは必要ないかも 0.020396399643491728
# 758 JOSE（JavaScriptオブジェクトへの署名と暗号化）は、絶対に避けるべき悪い標準規格である 0.020357429891745025
# 571 あなたはCSSプロパティ”display”をどのぐらい知っているだろうか？ 0.020336807704483633
# 696 処理速度の遅いcurrentTimeMillis() – 後編 0.02032979466551735
# 507 横柄なパスワード – パスワード認証に関する改善策 0.020324639938700668
# 376 Gitのコミットメッセージの書き方 0.020322746279231245
# 315 asyncioを用いたpythonの高速なスクレイピング 0.02027094596352321
# 87 私が書いた最速のハッシュテーブル – PART 4 0.020203810913854616
# 7 開発者の生産性：Noと言える技術 0.020102564931508433
# 467 –cap-dropオプションを使ったDockerコンテナの安全性を高める工夫 0.020074781576983124
# 775 500バイトの画像：Haikuのベクターアイコン形式 – 前編 0.019891359667107908
# 750 Servoにおける単位系の静的チェック 0.01988626224451532
# 215 JavaScriptのモナド 0.019865482982829544
# 122 デザインの視覚調整 ― 人間の認知に適合するデザインのために 0.01981172027233688
# 200 ZFSがあればGitなんか要らない？ 0.019746327422223372
# 701 SVGアニメーションの現状 0.019668456202963164
# 602 『モンスターワールドII ドラゴンの罠』1989年オリジナル版のリバースエンジニアリング：正確性の探究 0.019613586044700038
# 67 Linux Insides : カーネル起動プロセス part2 0.019601732489716497
# 226 FlyWeb―Mozillaによる、完全Web型のクロスデバイス・インタラクションの実験プロジェクト 0.019513340202593658
# 141 Linux Insides : カーネル起動プロセス part3 0.01930759428602732
# 581 Node.jsのイベントループを理解する 0.01897893403344885
# 586 VagrantとDocker: Mac OS X上でPostgres、Elasticsearch、Redisをセットアップする方法 0.018882388763273538
# 550 効果的なフォームをデザインする：構造、入力、ラベルおよびアクション 0.018752793569165784
# 720 Return-Oriented Programmingで64ビットLinuxを攻撃する手法 0.01869554751246797
# 786 私のURLはあなたのURLとは違う : curl作者の語る、URLの仕様にまつわる苦言 0.018631585474489076
# 335 Capybaraを使って、Rails+JavaScriptの非同期な統合テストを書く 0.01858394834470738
# 666 Y combinatorのサム・アルトマンによる『ボードメンバー』 0.01857088844276109
# 338 定まらない”共有”のアイコン 0.018500165846720314
# 437 リレーショナルデータベースの仕組み (3/3) 0.01848289393158814
# 225 SQLトランザクション分離 実践ガイド 0.018471708521306286
# 248 エンコード方式　base-122 0.018389884043875853
# 407 紙と鉛筆でビットコインをマイニング：1日に0.67ハッシュ 0.018356602302326476
# 470 トーマス・ジェファーソンから学ぶスタートアップ創始者のための8つの教訓 0.018307733393566727
# 433 できる動的計画法：ロッド切り出し問題 0.01823725675074264
# 194 ポール・グレアムによる「意地の悪い人は失敗する」 0.018231758619763852
# 665 GPUでボロノイ図を描画する : WebGLを用いてスムーズに描画できる高速アルゴリズム 0.018214008252748312
# 737 Linux Insides : カーネル起動プロセス part1 0.018153397087813286
# 423 ディープラーニングにおけるセマンティックセグメンテーションのガイド2017年版 0.01807876267571305
# 756 モジュロ演算の替わりとなる高速処理 0.017995571147917833
# 75 情報理論を視覚的に理解する (2/4) 0.017979530435854055
# 276 2016年、C言語はどう書くべきか (前編) 0.017769298548481405
# 22 分岐予測の簡単な歴史 – Part 3 0.01773929531166189
# 440 PythonでTCPスタックを記述するとどうなる？ 0.017592145662238493
# 203 JavaScriptの読み込みにおける非同期スクリプト注入の悪影響 0.01729722141391643
# 300 色弱のユーザーにもやさしいランディングページのデザイン 0.01728535745533679
# 812 Angular Router : そのAPIとメンタルモデル、設計理念について 0.017280278415336817
# 597 たった1バイトの書き込みが引き起こすルート権限での実行の脆弱性 0.01720984494805807
# 277 分かりやすいWeb入力フォームのための十戒 0.017102592281756392
# 148 英政府デジタルサービスのPaaSチームが採っている、公平な会議進行のためのアプローチ 0.017059211181518506
# 270 Q. なぜ”B”と表示するのは”#”と表示するよりも著しく遅いのか？ 0.017055882680272902
# 187 JavaScriptのクロージャは内部でどう機能するのか 0.017030447498500904
# 52 Uberを信用していいのか？ 0.016976356510007475
# 180 FacebookのFluxアーキテクチャの始め方 Part 1 0.016958603722994285
# 267 Goのワークスティーリング型スケジューラ 0.016887942681585576
# 425 ハミング符号 : データの誤り検知/訂正をインタラクティブに学ぶ 0.016808044364530293
# 410 糸が紡ぎ出す明暗 0.016722847475190747
# 144 2018ワールドカップのGraphQL APIを作りました 0.016700537126505818
# 553 Node.jsのパフォーマンス最適化を阻むものの見つけ方 0.01651146240032951
# 448 分岐予測の簡単な歴史 – Part 1 0.016250329986180343
# 593 思考実験によるより良いコーディングへのヒント 0.016117584258941716
# 381 Androidの10ms問題？解決しました！ : Superpowered Media Serverの紹介 0.016112443284033964
# 688 大規模Reactアプリケーションを構築するためのベストプラクティス 0.015934741554444104
# 320 手続き型のダンジョン生成アルゴリズム 0.015753044313112953
# 442 モーションデザインはUIの未来 0.015460966088288218
# 783 Web認証におけるせめぎ合い – 2人のセキュリティ専門家によるやりとり 0.015402388099058896
# 623 私が書いた最速のハッシュテーブル – PART 1 0.015252298883516808
# 337 6つの簡単なステップで改善するアイコンデザイン 0.014904448317170575
# 583 何でもSSHでやってしまいませんか？ 0.01483128584836443
# 379 Node Inspectorを用いてDockerでnode.jsをデバッグする方法 0.014758783696589846
# 736 Androidの10ms問題：Androidオーディオパスレイテンシ解説 0.014714173886408277
# 774 色：ヘキサコードから眼球まで – Part 1. 0.014692538426816686
# 486 色：ヘキサコードから眼球まで – Part 2. 0.01448478588337024
# 258 オーストラリアのスタートアップが成功しにくい理由 0.014357901349552305
# 654 Fasttracker 2の.XMファイルをJavaScriptで再生 0.01429969557604965
# 100 Webページレンダリングについて知っておくべきこと: ピクセルは高コスト 0.014268765143778568
# 53 クレジットカードフォームの解剖学 0.014267665156218003
# 371 React、Redux、D3を用いたアニメーション 0.014238406647475303
# 594 Gitを学んでいて「なるほど！」となる瞬間 0.014226070867357164
# 401 私が書いた最速のハッシュテーブル – PART 2 0.014120670387065904
# 534 MediaRecorder APIを使った簡単なオーディオキャプチャ 0.014044634337724642
# 356 Clojureで学ぶデータ構造：ハッシュテーブル 0.014015997250167939
# 377 ジェダイ流・Pythonの内包表記 0.013948855522948923
# 237 Dockerを用いたGUIアプリケーションの実行 0.013909009439615858
# 624 確率的データ構造の比較：カッコウフィルタ対ブルームフィルタ 0.013871880810171593
# 772 プログラマとしてのキャリアを脅かす反復運動過多損傷の痛みをどう解消したか 0.013816340450341528
# 630 C++でブルームフィルタを実装する方法 0.013641312176512632
# 636 ディープラーニングのための線形代数入門：一般的演算の初学者向けガイド 0.013577071468855742
# 500 優れたロゴを作るには？ 0.01317494484767776
# 690 Bluebirdの高速化を可能にする、3つのJavaScriptパフォーマンスの基礎 0.013154359255573844
# 484 200行のコードへのブロックチェーンの実装 0.013086737500142226
# 152 プログラマの三大美徳の啓発の勧め : 怠惰、短気、傲慢 ― JavaScriptで遅延評価 0.013034891554224297
# 106 SMSインタラクションのテスト 0.012967523728911311
# 345 恐竜とLisp : Chromeの「インターネット接続がありません」画面をLispでプレイする 0.012663972921199109
# 584 RxJavaのレシピ：Androidのイベントをストリームに変換する 0.012608990343807974
# 798 TwilioとAWS IoTボタンを使った子供のトイレ訓練 0.012608416531643574
# 279 「ほとんどのユニットテストが役に立たない理由」を読んで 0.012560707542319197
# 1 500バイトの画像：Haikuのベクターアイコン形式 – 後編 0.012372385873632796
# 105 若手開発者の後悔 0.012326554060186781
# 223 Linux Insides : カーネル起動プロセス part4 0.012199459641154611
# 189 GPUとセルオートマトンで経路探索問題を解いてみる 0.012092093539118269
# 526 開発経験ゼロのイラストレーターがゲーム制作 – Alto’s Adventure制作記 0.01187985035995685
# 190 GitLab flowから学ぶワークフローの実践 0.011714670640669578
# 482 CPUマスク 0.011616977154961801
# 193 IPをQRコードで実現する 0.011588541497710984
# 667 FacebookのFluxアーキテクチャの始め方 Part 2 0.01150051967518249
# 779 Uncle Bobのリトル・モッカー 0.011420517179464917
# 631 UIデザインにおけるボタン:スタイルの進化とベストプラクティス 0.011345395736375493
# 113 Git Undo エイリアスを定義する 0.011320139504008687
# 331 それでも独自のCSVを書くつもりですか？ 0.011276243838353999
# 637 グラフ代数 0.01107743188749747
# 346 より良いプログラムを書くための究極の奇策 – 「Data first, not code first」 0.011074525628144661
# 489 Pythonのジェネレータ、コルーチン、ネイティブコルーチン、そしてasync/await 0.010837286633650186
# 339 プルリクエストをより使いこなす 0.010803487561797226
# 629 チームの習慣を助長する：マネージャーのための3つの科学的ヒント 0.010205404468139025
# 499 私はC言語を知らない 0.009524235602316702
# 143 butterflyを使ってWebブラウザ上でターミナル入力を行う 0.009012381877401473
# 414 Linux Insides : カーネル起動プロセス part5(終) 0.008094946581229612
# 184 整数の公式でフィボナッチ数列を求める 0.007855364962364338
# 612 分岐予測の簡単な歴史 – Part 2 0.007208980636458473
# 165 JavaScriptでbind()を使って部分適用する 0.006781467736299328
# 282 try { return } finally {} 0.006563390887991036
# 302 POSTD Podcast #3 F8(Facebook Developer Conference)に参加してきました 0.004487473075806719
# 642 一から学ぶベジェ曲線 0.002288452858477315
# 55 POSTD Podcast #4 POSTDの原著者に話を聞きました – James K Nelson on React.js 0.0014595161938985102

# %% [markdown]
# ### 類似文書検索 同一タグが含まれているもののみ

# %%
# 文書集合を元にして各文書中の単語のTF-IDF値を計算
vectorizer = TfidfVectorizer(analyzer='word', max_df=0.9)
vecs = vectorizer.fit_transform(data)
# 類似度の計算
sim = cosine_similarity(vecs)
for i in range(0, len(sim)):
    target_id = find_all_data[i][columns.index('id')]
    target_tag = find_all_data[i][columns.index('tag')]
    if target_tag is None:
        continue
    target_tag_set = set(target_tag.split(','))
    docs = zip(ids, sim[i])
    count = 0
    similaritys = []
    # コサイン類似度が高い順にソートしてループ
    for id, similarity in sorted(docs, key=lambda x: x[1], reverse=True):
        if target_id == id:
            continue
        
        index = [k for k, v in enumerate(find_all_data) if v[columns.index('id')] == id][0]
        entry_title = find_all_data[index][columns.index('entry_title')]
        tag = find_all_data[index][columns.index('tag')]
        # 同一タグが含まれるかの判定
        if tag is None:
            continue
        tag_set = set(tag.split(','))
        if len(set(target_tag_set) - set(tag_set)) != 0:
            continue
        
        similaritys.append({'id': id, 'similarity': similarity})
        if count >= 4:
            break
        count += 1
    # コサイン類似度が高い記事IDを最大5件登録
    try:
        if(len(similaritys) > 0):
            mysql_class.set_article_by_id('similarity', target_id, similaritys)
    except:
        import traceback
        traceback.print_exc()
        mysql_class.disconnect()

# %% [markdown]
# ### 対象の記事と類似する記事を出力

# %%
# 検索タイトル
target_title = 'PHPはもうダメだ、PHP万歳！'
article = mysql_class.find_article_by_entry_title(columns, target_title)
if (article is not None):
    print('--- 関連タイトル ---')
    for similarity in json.loads(article[columns.index('similarity')]):
        similarity_article = mysql_class.find_article_by_id(columns, similarity['id'])
        print(similarity_article[columns.index('entry_title')])
# Out:
# --- 関連タイトル ---
# ある中級プログラマの告白
# HHVMの今後
# セカンドシステム症候群にまつわる3つの話―Perl 6, Python 3, PHP 6
# 高速なWebサーバアプリケーションを構築するための6つの経験則
# 最も割高なアンチパターン : 構造化されたデータを文字列関数で操作する「printfアンチパターン」について
